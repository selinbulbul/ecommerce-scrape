# %%
import pandas as pd

# %%
df = pd.read_json("product_output.jsonl")

# %%
df
# Out:
#                                                    name product_summary  \
# 0                                                  None            None
# 1                                                  None            None
# 2                                                  None            None
# 3                                                  None            None
# 4                                                  None            None
# ...                                                 ...             ...
# 2040                                               None            None
# 2041  AOC G2590PX 62.2 cm (24.5") WLED LCD Monitor -...            None
# 2042                                               None            None
# 2043                                               None            None
# 2044                                               None            None
#
#      product_tech_spec                                  product_addl_info  \
# ...

# %%
df = df.dropna(subset=['name'])

# %%
#df = df.reset_index()
#df

# %%
df
# Out:
#                                                    name product_summary  \
# 15                                    Computer Monitors            None
# 27                    24 MONITOR S2421HN -60.45CM(23.8)            None
# 34    BenQ BL2780T 68,58 cm (27 Zoll) Monitor (Full ...            None
# 43    LG 27GL63T-B Monitor Piatto per PC 68,6 cm (27...            None
# 44                            Portable Monitor 15.8inch            None
# ...                                                 ...             ...
# 2027  ICY BOX External USB-C Docking Station with Tr...            None
# 2028  19 inch AntiSpy Privacy Screen | 19.0 Monitor ...            None
# 2030                                 AOC 24G2U (EEK: A)            None
# 2036  Iiyama Prolite 34 UWQHD AH-IPS LED 3440 x 1440...            None
# 2041  AOC G2590PX 62.2 cm (24.5") WLED LCD Monitor -...            None
#
#                                       product_tech_spec  \
# ...

# %%
#df["price"]= pd.to_numeric(df["price"])

# %%
df.to_csv('Monitors_product.csv')

# %%
df.to_excel('Monitors_product.xlsx')

# %%
df.to_json('Monitors_product.jsonl')
