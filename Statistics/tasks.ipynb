# %%
import pandas as pd

# %% [markdown]
# # •	Top 3 selling products in each product segment by customer rating.

# %% [markdown]
# ## DSLR_Cameras

# %%
df = pd.read_excel("DSLR_sample_cleaned.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0                                      product title  \
# 0           0  Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1           1  Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2           2  Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3           3  Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4           4  Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
#
#                                                  url   rating  price €  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  284.00
# 1  https://www.amazon.com/gp/slredirect/picassoRe...  4.5 / 5  194.00
# 2  https://www.amazon.com/Canon-4000D-Camera-18-5...  4.7 / 5  438.00
# 3  https://www.amazon.com/Canon-Camera-2000D-18-5...  4.7 / 5  417.60
# 4  https://www.amazon.com/Canon-850D-DSLR-Digital...  4.7 / 5  849.00
#
#    review_count      product
# 0        23.000  DSLR_Camera
# 1       211.000  DSLR_Camera
# 2         1.637  DSLR_Camera
# 3         1.284  DSLR_Camera
# 4        28.000  DSLR_Camera

# %%
#price = df["review_count"].replace('.','DOT').replace(',','.').replace('DOT',',')
#price

# %%
df = df.drop(columns="Unnamed: 0")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1933 entries, 0 to 1932
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product title  1933 non-null   object
#  1   url            1933 non-null   object
#  2   rating         1933 non-null   object
#  3   price €        1933 non-null   object
#  4   review_count   1933 non-null   float64
#  5   product        1933 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 90.7+ KB

# %%
df['review_count'] = df['review_count'].astype(str)
#df['review_count'] = df['review_count'].str.replace('.0', '')
#df

# %%
#df["review_count"] = df["review_count"].replace({'.':','}, regex = True)
#df

# %%
#df['review_count'] = df['review_count'].str.replace('.', ',')

# %%
#df

# %%
#df["review_count"] = df["review_count"].replace({'\xa0':''}, regex = True)
#df

# %%
#df_1= df.loc[(df.review_count.str.find('.') == 1), 'review_count']

# %%
#df_1

# %%
#df["review_count"]= pd.to_numeric(df["review_count"])

# %% [markdown]
# ### trial

# %%
df.sort_values(by= "review_count", ascending = False)
# Out:
#                                           product title  \
# 76    Panasonic Lumix DMC-FZ300EGK premium bridge ca...
# 662                   Amazon Basics - Camera hand strap
# 1600  Neewer Pro Waterproof Shockproof Adjustable Pa...
# 120   Neewer Kit Flash Pofessionnel i-TTL sur Caméra...
# 103   Neewer Kit Flash Pofessionnel i-TTL sur Caméra...
# ...                                                 ...
# 1714  KIWIFOTOS 360° Rotating Mini Ball Head Tripod ...
# 1729  Vaxis Atom 500 Wireless HDMI SDI Video Transmi...
# 1861  Czemo Microfono de Solapa Mini Micrófono de So...
# 1321  HAFOKO MT-16 Table Camera Vlog Tripod Mini Sel...
# 56    Feelworld T7 7 Inch Camera Field Monitor 4K 19...
#
#                                                     url   rating price €  \
# 76    https://www.amazon.com/-/en/Panasonic-DMC-FZ30...  4.7 / 5  379.26
# 662   https://www.amazon.com/-/en/Amazon-Basics-Came...  4.1 / 5    9.89
# 1600  https://www.amazon.com/-/en/Waterproof-Shockpr...  4.6 / 5   99.99
# 120   https://www.amazon.com/-/en/Neewer-Pofessionne...  4.6 / 5  109.99
# 103   https://www.amazon.com/-/en/Neewer-Pofessionne...  4.6 / 5  109.99
# ...                                                 ...      ...     ...
# 1714  https://www.amazon.com/-/en/KIWIFOTOS-Rotating...  5.0 / 5   18.99
# 1729  https://www.amazon.com/-/en/Wireless-Transmiss...  5.0 / 5  435.00
# 1861  https://www.amazon.com/-/en/Omnidirectional-Co...  5.0 / 5   10.99
# 1321  https://www.amazon.com/-/en/Extendable-Compati...  5.0 / 5   19.95
# 56    https://www.amazon.com/-/en/Feelworld-Monitor-...  5.0 / 5  149.99
#
#      review_count      product
# 76          998.0  DSLR_Camera
# 662         996.0  DSLR_Camera
# 1600        990.0  DSLR_Camera
# 120          99.0  DSLR_Camera
# 103          99.0  DSLR_Camera
# ...           ...          ...
# 1714          1.0  DSLR_Camera
# 1729          1.0  DSLR_Camera
# 1861          1.0  DSLR_Camera
# 1321          1.0  DSLR_Camera
# 56            1.0  DSLR_Camera
#
# [1933 rows x 6 columns]

# %%
df_1 = df[(df["rating"] >= "4.0 / 5") & ( df['rating'] <= "5.0 / 5")]

# %%
df_2 = df_1.sort_values (by = "review_count", ascending= False)
df_2
# Out:
#                                           product title  \
# 76    Panasonic Lumix DMC-FZ300EGK premium bridge ca...
# 662                   Amazon Basics - Camera hand strap
# 1600  Neewer Pro Waterproof Shockproof Adjustable Pa...
# 103   Neewer Kit Flash Pofessionnel i-TTL sur Caméra...
# 120   Neewer Kit Flash Pofessionnel i-TTL sur Caméra...
# ...                                                 ...
# 1256  Replacement for Sony VG-C4EM Function Handgrip...
# 1394                                       Shoulder Rig
# 1559  Perfk 5 Pieces Hot Shoe Cover Protective Cap f...
# 1678  Protective Film for Sony Alpha a6600 DSLR Came...
# 1729  Vaxis Atom 500 Wireless HDMI SDI Video Transmi...
#
#                                                     url   rating price €  \
# 76    https://www.amazon.com/-/en/Panasonic-DMC-FZ30...  4.7 / 5  379.26
# 662   https://www.amazon.com/-/en/Amazon-Basics-Came...  4.1 / 5    9.89
# 1600  https://www.amazon.com/-/en/Waterproof-Shockpr...  4.6 / 5   99.99
# 103   https://www.amazon.com/-/en/Neewer-Pofessionne...  4.6 / 5  109.99
# 120   https://www.amazon.com/-/en/Neewer-Pofessionne...  4.6 / 5  109.99
# ...                                                 ...      ...     ...
# 1256  https://www.amazon.com/-/en/Replacement-Functi...  5.0 / 5   59.49
# 1394  https://www.amazon.com/-/en/Shoulder-Rig/dp/B0...  5.0 / 5   35.79
# 1559  https://www.amazon.com/-/en/Perfk-Pieces-Cover...  5.0 / 5    3.59
# 1678  https://www.amazon.com/-/en/Protective-Anti-Sc...  5.0 / 5   13.99
# 1729  https://www.amazon.com/-/en/Wireless-Transmiss...  5.0 / 5  435.00
#
#      review_count      product
# 76          998.0  DSLR_Camera
# 662         996.0  DSLR_Camera
# 1600        990.0  DSLR_Camera
# 103          99.0  DSLR_Camera
# 120          99.0  DSLR_Camera
# ...           ...          ...
# 1256          1.0  DSLR_Camera
# 1394          1.0  DSLR_Camera
# 1559          1.0  DSLR_Camera
# 1678          1.0  DSLR_Camera
# 1729          1.0  DSLR_Camera
#
# [1822 rows x 6 columns]

# %%
df_3= df_2[(df_2["review_count"] > "1.0") & ( df['review_count'] < "9.0") ]
df_3
# Out:
# <ipython-input-127-14e89abcc60e>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_3= df_2[(df_2["review_count"] > "1.0") & ( df['review_count'] < "9.0") ]
#                                           product title  \
# 131     Neewer Tripod Monopod with 360 Degree Ball Head
# 111     Neewer Tripod Monopod with 360 Degree Ball Head
# 211   Neewer Aluminium Alloy 158 cm Camera Tripod wi...
# 1660  Neoprene Camera Wrist Strap Extra Wide Red Gen...
# 1797  Neoprene camera wrist strap, extra wide, click...
# ...                                                 ...
# 785   Docooler Waterproof Multifunctional Breathable...
# 437             Neewer Aluminium Camera Tripod Monopod.
# 482                   Corsair Elgato cam link 4K, Black
# 1606                               Amazon Stückliste VI
# 533   Neewer NW-670 TTL Flash Unit with LCD Display Set
#
#                                                     url   rating price €  \
# 131   https://www.amazon.com/-/en/Neewer-Tripod-Mono...  4.4 / 5  105.99
# 111   https://www.amazon.com/-/en/Neewer-Tripod-Mono...  4.4 / 5  105.99
# 211   https://www.amazon.com/-/en/Neewer-Aluminium-R...  4.6 / 5   47.99
# 1660  https://www.amazon.com/-/en/Neoprene-Genuine-L...  4.5 / 5   14.90
# 1797  https://www.amazon.com/-/en/Neoprene-closure-g...  4.5 / 5   14.90
# ...                                                 ...      ...     ...
# 785   https://www.amazon.com/-/en/Docooler-Waterproo...  4.3 / 5   21.99
# 437   https://www.amazon.com/-/en/Neewer-Aluminium-C...  4.3 / 5   97.99
# 482   https://www.amazon.com/-/en/Corsair-Elgato-cam...  4.6 / 5  119.99
# 1606  https://www.amazon.com/-/en/20209-Amazon-St%C3...  4.6 / 5  121.84
# 533   https://www.amazon.com/-/en/Neewer-NW-670-Flas...  4.4 / 5   92.94
#
#      review_count      product
# 131         897.0  DSLR_Camera
# 111         897.0  DSLR_Camera
# 211         891.0  DSLR_Camera
# 1660         89.0  DSLR_Camera
# 1797         89.0  DSLR_Camera
# ...           ...          ...
# 785         1.073  DSLR_Camera
# 437         1.039  DSLR_Camera
# 482         1.025  DSLR_Camera
# 1606        1.011  DSLR_Camera
# 533          1.01  DSLR_Camera
#
# [1702 rows x 6 columns]

# %%
df_3.loc[(df_3.review_count.str.find('.') == 1), 'review_count']
# Out:
# 377    8.761
# Name: review_count, dtype: object

# %%
df_2.sort_values (by = "price €", ascending= False)
# Out:
#                                           product title  \
# 218   Canon EOS 80D SLR digital camera (24.2 megapix...
# 16    Feelworld FW759 7 Zoll Kamera DSLR Field Monit...
# 1055  Fotopro Professional Camera Tripod Compact Alu...
# 1600  Neewer Pro Waterproof Shockproof Adjustable Pa...
# 1490  Yongnuo YN-300 III YN300 III Pro LED Video Lig...
# ...                                                 ...
# 701   Canon EOS 6D Mark II Full Format SLR Digital C...
# 1779              Sony DSC-RX10M4 Premium Bridge Camera
# 1264  Canon EOS 6D Mark II Full Format SLR Digital C...
# 603   Canon EOS 90D Single Lens Reflex Camera, 32.5 ...
# 12    Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
#
#                                                     url   rating    price €  \
# 218   https://www.amazon.com/-/en/digital-camera-meg...  4.7 / 5     999.00
# 16    https://www.amazon.com/Feelworld-Kamera-Monito...  4.4 / 5     99.99
# 1055  https://www.amazon.com/-/en/Fotopro-Profession...  4.1 / 5      99.99
# 1600  https://www.amazon.com/-/en/Waterproof-Shockpr...  4.6 / 5      99.99
# 1490  https://www.amazon.com/-/en/III-YN300-Temperat...  4.1 / 5      99.99
# ...                                                 ...      ...        ...
# 701   https://www.amazon.com/-/en/Digital-Megapixels...  4.7 / 5   1.869.00
# 1779  https://www.amazon.com/-/en/Sony-DSC-RX10M4-Pr...  4.5 / 5   1.599.00
# 1264  https://www.amazon.com/-/en/Digital-Megapixels...  4.7 / 5   1.389.00
# 603   https://www.amazon.com/-/en/Canon-90D-Single-R...  4.8 / 5   1.272.95
# 12    https://www.amazon.com/Canon-850D-DSLR-Digital...  4.8 / 5  1.149.00
#
#      review_count      product
# 218         265.0  DSLR_Camera
# 16          187.0  DSLR_Camera
# 1055         26.0  DSLR_Camera
# 1600        990.0  DSLR_Camera
# 1490        183.0  DSLR_Camera
# ...           ...          ...
# 701         327.0  DSLR_Camera
# 1779        197.0  DSLR_Camera
# 1264        327.0  DSLR_Camera
# 603          44.0  DSLR_Camera
# 12           10.0  DSLR_Camera
#
# [1822 rows x 6 columns]

# %% [markdown]
# ### rating average - •	What are the average ratings for each product type

# %%
df_1['rating'] = df_1['rating'].astype(str)
df_1['rating'] = df_1['rating'].str.replace('/ 5', '')
df_1
# Out:
#                                           product title  \
# 0     Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1     Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2     Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3     Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4     Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# ...                                                 ...
# 1928  Neewer 18 Piece Metallic Camera Lens Filter Ri...
# 1929  MOSHUSO Camera Mount Clamp with 360° Ball Head...
# 1930  Andoer W49 A7 Mini Interlock Camera LED Panel ...
# 1931                             Cullmann Malaga Series
# 1932  sourcing map Pack of 5 Plastic Dgital DSLR Cam...
#
#                                                     url rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...   4.7   284.00
# 1     https://www.amazon.com/gp/slredirect/picassoRe...   4.5   194.00
# 2     https://www.amazon.com/Canon-4000D-Camera-18-5...   4.7   438.00
# 3     https://www.amazon.com/Canon-Camera-2000D-18-5...   4.7   417.60
# 4     https://www.amazon.com/Canon-850D-DSLR-Digital...   4.7   849.00
# ...                                                 ...    ...      ...
# 1928  https://www.amazon.com/-/en/Neewer-Metallic-Ca...   4.7     22.99
# 1929  https://www.amazon.com/-/en/MOSHUSO-Camera-Mou...   4.7     11.99
# 1930  https://www.amazon.com/-/en/W49-A7-Mini-Interl...   5.0     13.99
# 1931  https://www.amazon.com/-/en/90363-Cullmann-Mal...   4.5     33.90
# 1932  https://www.amazon.com/-/en/sourcing-Plastic-D...   4.6      5.79
#
#       review_count      product
# 0           23.000  DSLR_Camera
# 1          211.000  DSLR_Camera
# 2            1.637  DSLR_Camera
# 3            1.284  DSLR_Camera
# 4           28.000  DSLR_Camera
# ...            ...          ...
# 1928       458.000  DSLR_Camera
# 1929       252.000  DSLR_Camera
# 1930         2.000  DSLR_Camera
# 1931       247.000  DSLR_Camera
# 1932         7.000  DSLR_Camera
#
# [1933 rows x 6 columns]

# %%
df_1["rating"]= pd.to_numeric(df["rating"])

# %%
df_1["rating"].mean()
# Out:
# 4.454009311950341

# %%
df_rating = df[(df["rating"] == "5.0 / 5")] 
df_rating
# Out:
# Empty DataFrame
# Columns: [product title, url, rating, price €, review_count, product]
# Index: []

# %%
df_rating.sort_values(by= "review_count", ascending = False).head(3)
# Out:
# Empty DataFrame
# Columns: [product title, url, rating, price €, review_count, product]
# Index: []

# %%
####they are not the most reviewed

# %% [markdown]
# ### Median

# %%
df.describe()
# Out:
#             rating  review_count
# count  1933.000000   1933.000000
# mean      4.454009    158.016767
# std       0.314226    209.755996
# min       1.000000      1.000000
# 25%       4.300000     16.000000
# 50%       4.500000     57.000000
# 75%       4.600000    211.000000
# max       5.000000    998.000000

# %% [markdown]
# ## Headphones

# %%
df = pd.read_excel("headphones_sample_cleaned.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0                                      product title  \
# 0           0                           Puro BT2200 (Lime Green)
# 1           1                              Puro BT2200 (Magenta)
# 2           2   Sony MDR-ZX110 faltbarer Bügelkopfhörer, schwarz
# 3           3  Sony WH-CH710N kabellose Bluetooth Noise Cance...
# 4           4  JBL Tune500BT On-Ear Bluetooth-Kopfhörer in Sc...
#
#                                                  url   rating price €  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  94.99
# 1  https://www.amazon.com/gp/slredirect/picassoRe...  4.6 / 5  94.99
# 2  https://www.amazon.com/Sony-MDR-ZX110-faltbare...  4.5 / 5  11.45
# 3  https://www.amazon.com/Sony-Cancelling-Akkulau...  4.4 / 5  89.99
# 4  https://www.amazon.com/JBL-Tune500BT-Ear-Bluet...  4.6 / 5  29.99
#
#    review_count    product
# 0        28.000  Headphone
# 1        81.000  Headphone
# 2        21.656  Headphone
# 3        10.757  Headphone
# 4        19.944  Headphone

# %%
df = df.drop(columns="Unnamed: 0")

# %% [markdown]
# ### rating

# %%
df_1= df

# %%
df_1['rating'] = df_1['rating'].astype(str)
df_1['rating'] = df_1['rating'].str.replace('/ 5', '')
df_1
# Out:
#                                           product title  \
# 0                              Puro BT2200 (Lime Green)
# 1                                 Puro BT2200 (Magenta)
# 2      Sony MDR-ZX110 faltbarer Bügelkopfhörer, schwarz
# 3     Sony WH-CH710N kabellose Bluetooth Noise Cance...
# 4     JBL Tune500BT On-Ear Bluetooth-Kopfhörer in Sc...
# ...                                                 ...
# 2045        Urbanista San Francisco In-Ear Headset blau
# 2046  Motorola Vervebuds, Wireless Bluetooth In-Ear ...
# 2047  Moxking Earbuds with Mic and Volume Control, S...
# 2048  Urbanista Paris True Wireless Headphones In-ea...
# 2049  Amazon Basics - Over-ear headphones for childr...
#
#                                                     url rating price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...   4.3   94.99
# 1     https://www.amazon.com/gp/slredirect/picassoRe...   4.6   94.99
# 2     https://www.amazon.com/Sony-MDR-ZX110-faltbare...   4.5   11.45
# 3     https://www.amazon.com/Sony-Cancelling-Akkulau...   4.4   89.99
# 4     https://www.amazon.com/JBL-Tune500BT-Ear-Bluet...   4.6   29.99
# ...                                                 ...    ...     ...
# 2045  https://www.amazon.com/-/en/Urbanista-Francisc...   4.3    10.99
# 2046  https://www.amazon.com/-/en/Vervebuds-Bluetoot...   4.0    33.77
# 2047  https://www.amazon.com/-/en/Moxking-Earbuds-Co...   4.0     8.49
# 2048  https://www.amazon.com/-/en/Urbanista-Paris-Tr...   3.7    64.99
# 2049  https://www.amazon.com/-/en/Amazon-Basics-Over...   4.2    25.40
#
#       review_count    product
# 0           28.000  Headphone
# 1           81.000  Headphone
# 2           21.656  Headphone
# 3           10.757  Headphone
# 4           19.944  Headphone
# ...            ...        ...
# 2045        71.000  Headphone
# 2046         2.264  Headphone
# 2047       632.000  Headphone
# 2048         1.324  Headphone
# 2049       192.000  Headphone
#
# [2050 rows x 6 columns]

# %%
df_1["rating"]= pd.to_numeric(df["rating"])

# %%
df_1["rating"].mean()
# Out:
# 4.329560975609737

# %%
df_1.describe()
# Out:
#             rating  review_count
# count  2050.000000   2050.000000
# mean      4.329561    152.468444
# std       0.289467    241.346593
# min       1.000000      1.000000
# 25%       4.200000      3.662750
# 50%       4.400000     26.046000
# 75%       4.500000    205.000000
# max       5.000000    995.000000

# %%
df.sort_values(by= "rating", ascending = False)
# Out:
#                                           product title  \
# 1041  Children's Headphones, Headphones with 85/94 d...
# 1670  Bluetooth headphones in ear, wireless Bluetoot...
# 518   Bloothooth Wireless Bluetooth Headphones in Ea...
# 1240  BronaGrand Aeroplane Headphone Adaptor, Pack o...
# 589   Hikig Headphone Jack Extraction Tool - Headpho...
# ...                                                 ...
# 878   VBESTLIFE Magnetic Wireless Bluetooth Sport He...
# 856   FITOYA Bluetooth Wireless Headphones, Waterpro...
# 1405  ZERKAR USB C Kopfhörer, In-Ear Typ C Kopfhörer...
# 1537  Bluetooth Headphones, 3D Stereo In-Ear Headpho...
# 1362  Headphone Adapter for iPhone to 3.5 mm Jack Ad...
#
#                                                     url   rating price €  \
# 1041  https://www.amazon.com/-/en/Childrens-Headphon...  5.0 / 5   13.99
# 1670  https://www.amazon.com/-/en/Bluetooth-headphon...  5.0 / 5   16.99
# 518   https://www.amazon.com/-/en/Bloothooth-Wireles...  5.0 / 5   26.99
# 1240  https://www.amazon.com/-/en/BronaGrand-Aeropla...  5.0 / 5    7.99
# 589   https://www.amazon.com/-/en/Hikig-Headphone-Ja...  5.0 / 5   10.99
# ...                                                 ...      ...     ...
# 878   https://www.amazon.com/-/en/VBESTLIFE-Magnetic...  3.0 / 5    7.99
# 856   https://www.amazon.com/-/en/Bluetooth-Headphon...  3.0 / 5   11.99
# 1405  https://www.amazon.com/-/en/Black/dp/B0921N12X...  3.0 / 5    9.99
# 1537  https://www.amazon.com/-/en/Bluetooth-Headphon...  2.8 / 5   26.99
# 1362  https://www.amazon.com/-/en/Headphone-Adapter-...  1.0 / 5    9.99
#
#       review_count    product
# 1041           2.0  Headphone
# 1670           1.0  Headphone
# 518            2.0  Headphone
# 1240           1.0  Headphone
# 589            2.0  Headphone
# ...            ...        ...
# 878          132.0  Headphone
# 856           29.0  Headphone
# 1405          19.0  Headphone
# 1537           4.0  Headphone
# 1362           1.0  Headphone
#
# [2050 rows x 6 columns]

# %%
df["review_count"].value_counts()
# Out:
# 5.685      77
# 26.046     77
# 350.000    73
# 1.215      71
# 95.000     71
#            ..
# 2.094       1
# 551.000     1
# 415.000     1
# 7.423       1
# 126.000     1
# Name: review_count, Length: 711, dtype: int64

# %%
df_rating = df[(df["rating"] == "5.0 / 5")] 
df_rating
# Out:
#                                           product title  \
# 78    BCMASTER Bluetooth In-Ear Headphones Wireless ...
# 108   Children's Headphones, Headphones with 85/94 d...
# 205   Blackview AirBuds 2 Bluetooth Headphones, TWS ...
# 250   POWERADD Bluetooth Headphones Sport Headphones...
# 255   Rpanle In-Ear Headphones, Cable Earphones with...
# 340   Jelone Bluetooth Headphones In Ear, Noise Canc...
# 382   Blackview AirBuds 2 Bluetooth Headphones, TWS ...
# 435   AXLOIE Wireless Headphones - Wireless Bluetoot...
# 457   Marshall Mode II True Wireless Headphones - Black
# 463   Headphone Adapter for iPhone 12 Adoptor Dongle...
# 518   Bloothooth Wireless Bluetooth Headphones in Ea...
# 521   Bluetooth Headphones, Blackview AirBuds 2 TWS ...
# 526   Headphone Adapter for iPhone 12 Adoptor Dongle...
# 554   Bluetooth Headphones, IPX7 Waterproof Headphon...
# 564   Bluetooth Headphones In-Ear Headphones Wireles...
# 589   Hikig Headphone Jack Extraction Tool - Headpho...
# 598   Vogek Earbuds, Tangle-free, Flat Cable, Ergono...
# 623   auvisio Wireless headphones for TV: digital st...
# 631   Vogek Earbuds, Tangle-free, Flat Cable, Ergono...
# 653   HUAWEI FreeBuds 4i True Wireless Headphones wi...
# 660   Bluetooth Headphones In Ear Otium Headphones B...
# 693   Hikig Headphone Jack Extraction Tool - Headpho...
# 701   【Apple MFi Certified】Headphone adapter for App...
# 723   Torteco A20 True Wireless Earbuds, Bluetooth 5...
# 795   Jelone Bluetooth Headphones In Ear, Noise Canc...
# 1041  Children's Headphones, Headphones with 85/94 d...
# 1159  Bluetooth Headphones, In-Ear Wireless Headphon...
# 1200  Xiaomi Mi 11i 5G Smartphone + Headphones (6.81...
# 1211  Bluetooth 5.1 Headphones Sport Wireless Headph...
# 1240  BronaGrand Aeroplane Headphone Adaptor, Pack o...
# 1279  JBL Tune 660 BTNC On-Ear Active Noise Cancelli...
# 1370  Bluetooth Headset V5.1,Wireless Headset 18 Hrs...
# 1402  HONOR Sports Bluetooth Headphones AM61 Magneti...
# 1408  Philips LFH7177/06 Playback Set Ergonomic USB ...
# 1485  Bluetooth 5.0 Headphones, In-Ear Earphones wit...
# 1556  Headphone Stand, Headset Holder, Walnut Wood &...
# 1592  HONOR Sports Bluetooth Headphones AM61 Magneti...
# 1620  KINGSTAR Gaming Wireless Earbuds Bluetooth 5.0...
# 1634  Bluetooth 5.0 Headphones, In-Ear Earphones wit...
# 1670  Bluetooth headphones in ear, wireless Bluetoot...
# 1741  B39 Bluetooth over-ear headphones, wireless fo...
# 1789  Bluetooth Headphones, BCMASTER In-Ear Headphon...
# 1790  TinyGeeks Neo - SGS Certified 83 dB + CPSIA Ce...
# 1851  2021 Bluetooth Headphones, Wireless Headphones...
# 1868  Bluetooth Headphones, Real Wireless Stereo Blu...
# 1910  Bluetooth Headphones 5.0 Sport Wireless Audio ...
# 1942  PC Headset mit Mikrofon, Plug & Play, Stereo U...
# 1943  BeatsBuddy - Black I Headphone Stand I Bottle ...
# 1978  Neuestes Modell Bluetooth Kopfhörer in Ear Wir...
#
#                                                     url   rating price €  \
# 78    https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   39.99
# 108   https://www.amazon.com/-/en/Childrens-Headphon...  5.0 / 5   13.99
# 205   https://www.amazon.com/-/en/Blackview-AirBuds-...  5.0 / 5   24.99
# 250   https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   36.99
# 255   https://www.amazon.com/-/en/Headphones-Earphon...  5.0 / 5    7.99
# 340   https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   19.95
# 382   https://www.amazon.com/-/en/Blackview-AirBuds-...  5.0 / 5   24.99
# 435   https://www.amazon.com/-/en/AXLOIE-Wireless-He...  5.0 / 5   69.99
# 457   https://www.amazon.com/-/en/Marshall-Mode-True...  5.0 / 5  179.00
# 463   https://www.amazon.com/-/en/Headphone-Connecti...  5.0 / 5    9.99
# 518   https://www.amazon.com/-/en/Bloothooth-Wireles...  5.0 / 5   26.99
# 521   https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   24.99
# 526   https://www.amazon.com/-/en/Headphone-Connecti...  5.0 / 5    9.99
# 554   https://www.amazon.com/-/en/Headphones-Waterpr...  5.0 / 5   19.99
# 564   https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   19.99
# 589   https://www.amazon.com/-/en/Hikig-Headphone-Ja...  5.0 / 5   10.99
# 598   https://www.amazon.com/-/en/Earbuds-Tangle-fre...  5.0 / 5    4.99
# 623   https://www.amazon.com/-/en/auvisio-Wireless-h...  5.0 / 5   62.99
# 631   https://www.amazon.com/-/en/Earbuds-Tangle-fre...  5.0 / 5    4.99
# 653   https://www.amazon.com/-/en/FreeBuds-Headphone...  5.0 / 5   85.00
# 660   https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   33.99
# 693   https://www.amazon.com/-/en/Hikig-Headphone-Ja...  5.0 / 5   10.99
# 701   https://www.amazon.com/-/en/Certified%E3%80%91...  5.0 / 5    9.49
# 723   https://www.amazon.com/-/en/A20-Wireless-Bluet...  5.0 / 5   12.99
# 795   https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   19.95
# 1041  https://www.amazon.com/-/en/Childrens-Headphon...  5.0 / 5   13.99
# 1159  https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   24.99
# 1200  https://www.amazon.com/-/en/Xiaomi-Smartphone-...  5.0 / 5  649.90
# 1211  https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   37.99
# 1240  https://www.amazon.com/-/en/BronaGrand-Aeropla...  5.0 / 5    7.99
# 1279  https://www.amazon.com/-/en/Tune-Active-Noise-...  5.0 / 5   86.99
# 1370  https://www.amazon.com/-/en/dp/B093L8W6VP/ref=...  5.0 / 5   29.99
# 1402  https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   34.90
# 1408  https://www.amazon.com/-/en/LFH7177-06-Headpho...  5.0 / 5  135.66
# 1485  https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   11.99
# 1556  https://www.amazon.com/-/en/Headphone-Headset-...  5.0 / 5   21.99
# 1592  https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   34.90
# 1620  https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   36.99
# 1634  https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   11.99
# 1670  https://www.amazon.com/-/en/Bluetooth-headphon...  5.0 / 5   16.99
# 1741  https://www.amazon.com/-/en/Bluetooth-headphon...  5.0 / 5   18.99
# 1789  https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   29.99
# 1790  https://www.amazon.com/-/en/TinyGeeks-Neo-Cert...  5.0 / 5   19.97
# 1851  https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   19.99
# 1868  https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   17.19
# 1910  https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   12.30
# 1942  https://www.amazon.com/-/en/MHP682/dp/B092MBBQ...  5.0 / 5   29.99
# 1943  https://www.amazon.com/-/en/BeatsBuddy-Black-H...  5.0 / 5    7.99
# 1978  https://www.amazon.com/-/en/M8-earphone/dp/B07...  5.0 / 5    9.98
#
#       review_count    product
# 78             1.0  Headphone
# 108            2.0  Headphone
# 205           62.0  Headphone
# 250            5.0  Headphone
# 255            6.0  Headphone
# 340            1.0  Headphone
# 382           62.0  Headphone
# 435            1.0  Headphone
# 457            1.0  Headphone
# 463            2.0  Headphone
# 518            2.0  Headphone
# 521           62.0  Headphone
# 526            2.0  Headphone
# 554            1.0  Headphone
# 564            1.0  Headphone
# 589            2.0  Headphone
# 598            2.0  Headphone
# 623            2.0  Headphone
# 631            2.0  Headphone
# 653            1.0  Headphone
# 660           19.0  Headphone
# 693            2.0  Headphone
# 701            1.0  Headphone
# 723            1.0  Headphone
# 795            1.0  Headphone
# 1041           2.0  Headphone
# 1159           1.0  Headphone
# 1200           2.0  Headphone
# 1211          19.0  Headphone
# 1240           1.0  Headphone
# 1279           1.0  Headphone
# 1370           1.0  Headphone
# 1402           1.0  Headphone
# 1408           5.0  Headphone
# 1485           1.0  Headphone
# 1556           1.0  Headphone
# 1592           1.0  Headphone
# 1620          29.0  Headphone
# 1634           1.0  Headphone
# 1670           1.0  Headphone
# 1741           1.0  Headphone
# 1789           1.0  Headphone
# 1790           6.0  Headphone
# 1851           2.0  Headphone
# 1868           1.0  Headphone
# 1910           1.0  Headphone
# 1942          40.0  Headphone
# 1943          13.0  Headphone
# 1978           3.0  Headphone

# %%
df_rating.sort_values(by= "review_count", ascending = False).head(3)
# Out:
#                                          product title  \
# 205  Blackview AirBuds 2 Bluetooth Headphones, TWS ...
# 382  Blackview AirBuds 2 Bluetooth Headphones, TWS ...
# 521  Bluetooth Headphones, Blackview AirBuds 2 TWS ...
#
#                                                    url   rating price €  \
# 205  https://www.amazon.com/-/en/Blackview-AirBuds-...  5.0 / 5   24.99
# 382  https://www.amazon.com/-/en/Blackview-AirBuds-...  5.0 / 5   24.99
# 521  https://www.amazon.com/-/en/Bluetooth-Headphon...  5.0 / 5   24.99
#
#      review_count    product
# 205          62.0  Headphone
# 382          62.0  Headphone
# 521          62.0  Headphone

# %%
####they are not the most reviewed

# %% [markdown]
# ## Keyboards

# %%
df = pd.read_excel("Keyboard_sample_cleaned.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0                                      product title  \
# 0           0  J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1           1  Logitech K835 Wired Mechanical TKL aluminum ke...
# 2           2  PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3           3  Microsoft Wired Keyboard 600 - German - black ...
# 4           4  Logitech K280e Pro Wired Business Keyboard for...
#
#                                                  url   rating price €  \
# 0  https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5   37.99
# 1  https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   57.99
# 2  https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   22.99
# 3  https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 / 5    8.99
# 4  https://www.amazon.com/-/en/Logitech-Business-...  4.5 / 5   23.79
#
#    review_count   product
# 0       462.000  Keyboard
# 1       861.000  Keyboard
# 2         3.000  Keyboard
# 3         1.631  Keyboard
# 4         4.869  Keyboard

# %%
df = df.drop(columns="Unnamed: 0")

# %% [markdown]
# ### rating

# %%
df_1= df

# %%
df_1['rating'] = df_1['rating'].astype(str)
df_1['rating'] = df_1['rating'].str.replace('/ 5', '')
df_1
# Out:
#                                           product title  \
# 0     J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1     Logitech K835 Wired Mechanical TKL aluminum ke...
# 2     PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3     Microsoft Wired Keyboard 600 - German - black ...
# 4     Logitech K280e Pro Wired Business Keyboard for...
# ...                                                 ...
# 1495  ENHANCE Galaxy Gaming Keyboard Wrist Rest Pad ...
# 1496  MoKo Universal Foldable Keyboard, Ultra Thin P...
# 1497  Fintie Keyboard Case for Lenovo Tab P11 11 Inc...
# 1498  WisFox Keyboard Mouse Set Wireless 2.4 GHz Ful...
# 1499  HUAWEI Display 23.8 inches, 60 cm (23.8 inches...
#
#                                                     url rating price €  \
# 0     https://www.amazon.com/-/en/gp/slredirect/pica...   4.2    37.99
# 1     https://www.amazon.com/-/en/gp/slredirect/pica...   4.6    57.99
# 2     https://www.amazon.com/-/en/gp/slredirect/pica...   4.6    22.99
# 3     https://www.amazon.com/-/en/Microsoft-Wired-Ke...   4.6     8.99
# 4     https://www.amazon.com/-/en/Logitech-Business-...   4.5    23.79
# ...                                                 ...    ...     ...
# 1495  https://www.amazon.com/-/en/Keyboard-Keyboards...   4.5    24.99
# 1496  https://www.amazon.com/-/en/Universal-Recharge...   4.4    23.97
# 1497  https://www.amazon.com/-/en/Keyboard-Protectiv...   4.0    44.99
# 1498  https://www.amazon.com/-/en/gp/slredirect/pica...   4.5    20.39
# 1499  https://www.amazon.com/-/en/gp/slredirect/pica...   4.7   129.00
#
#       review_count   product
# 0          462.000  Keyboard
# 1          861.000  Keyboard
# 2            3.000  Keyboard
# 3            1.631  Keyboard
# 4            4.869  Keyboard
# ...            ...       ...
# 1495       181.000  Keyboard
# 1496       612.000  Keyboard
# 1497         1.000  Keyboard
# 1498         7.000  Keyboard
# 1499        14.000  Keyboard
#
# [1500 rows x 6 columns]

# %%
df_1["rating"]= pd.to_numeric(df["rating"])

# %%
df_1["rating"].mean()
# Out:
# 4.362800000000003

# %%
df_1.describe()
# Out:
#             rating  review_count
# count  1500.000000   1500.000000
# mean      4.362800    158.468492
# std       0.366332    234.722603
# min       1.700000      1.000000
# 25%       4.100000      7.000000
# 50%       4.400000     44.000000
# 75%       4.600000    228.000000
# max       5.000000    997.000000

# %%
df.sort_values(by= "rating", ascending = False)
# Out:
#                                           product title  \
# 407   Seenda Wireless Keyboard Illuminated with Whit...
# 379   Seenda Wireless Keyboard Illuminated with Whit...
# 1296  Mini Keyboard, Smart Wireless Keyboard Air Mou...
# 1294  Seenda Wireless Keyboard Illuminated with Whit...
# 842   Seenda Wireless Keyboard Illuminated with Whit...
# ...                                                 ...
# 1281  Microsoft Comfort Desktop 5050 Keyboard RF Wir...
# 519   Zienstar - 2.4 GHz slim mini wireless keyboard...
# 1304  Microsoft Comfort Desktop 5050 Keyboard RF Wir...
# 1339  Small Bluetooth Keyboard, Ultra Slim Wireless ...
# 784   Matias FK308PCBB-DE Aluminium Tenkeyless USB K...
#
#                                                     url   rating price €  \
# 407   https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   35.99
# 379   https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   35.99
# 1296  https://www.amazon.com/-/en/Keyboard-Wireless-...  5.0 / 5   25.09
# 1294  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   35.99
# 842   https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   35.99
# ...                                                 ...      ...     ...
# 1281  https://www.amazon.com/-/en/Microsoft-Comfort-...  3.0 / 5   70.96
# 519   https://www.amazon.com/-/en/Zienstar-wireless-...  3.0 / 5   18.99
# 1304  https://www.amazon.com/-/en/Microsoft-Comfort-...  3.0 / 5   70.96
# 1339  https://www.amazon.com/-/en/Bluetooth-Keyboard...  2.8 / 5   18.69
# 784   https://www.amazon.com/-/en/FK308PCBB-Aluminiu...  1.7 / 5   69.99
#
#       review_count   product
# 407            1.0  Keyboard
# 379            1.0  Keyboard
# 1296           1.0  Keyboard
# 1294           1.0  Keyboard
# 842            1.0  Keyboard
# ...            ...       ...
# 1281           1.0  Keyboard
# 519            2.0  Keyboard
# 1304           1.0  Keyboard
# 1339           6.0  Keyboard
# 784            3.0  Keyboard
#
# [1500 rows x 6 columns]

# %%
df["review_count"].value_counts()
# Out:
# 1.000      95
# 7.000      71
# 120.000    52
# 44.000     50
# 14.000     45
#            ..
# 1.925       1
# 237.000     1
# 497.000     1
# 2.135       1
# 56.000      1
# Name: review_count, Length: 426, dtype: int64

# %%
df_rating = df[(df["rating"] == "5.0 / 5")] 
df_rating
# Out:
#                                           product title  \
# 13    Seenda Wireless Keyboard Illuminated with Whit...
# 33    Seenda Wireless Keyboard Illuminated with Whit...
# 51    Joyaccess Wireless Bluetooth Keyboard Multi-De...
# 60    Seenda Wireless Keyboard Illuminated with Whit...
# 63    Joyaccess Wireless Bluetooth Keyboard Multi-De...
# ...                                                 ...
# 1450  Seenda Wireless Keyboard Illuminated with Whit...
# 1472  TELLUR Basic Wireless Keyboard and Mouse Kit, ...
# 1474  Logitech K360 Wireless Keyboard, 2.4 GHz conne...
# 1478  Koolertron Programmable Split Keyboard, Mechan...
# 1482  Seenda Wireless Keyboard Illuminated with Whit...
#
#                                                     url   rating price €  \
# 13    https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   35.99
# 33    https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   35.99
# 51    https://www.amazon.com/-/en/Joyaccess-Bluetoot...  5.0 / 5   39.00
# 60    https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   35.99
# 63    https://www.amazon.com/-/en/Joyaccess-Bluetoot...  5.0 / 5   39.00
# ...                                                 ...      ...     ...
# 1450  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   35.99
# 1472  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   17.99
# 1474  https://www.amazon.com/-/en/Logitech-Wireless-...  5.0 / 5   55.88
# 1478  https://www.amazon.com/-/en/Koolertron-Program...  5.0 / 5  117.99
# 1482  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   35.99
#
#       review_count   product
# 13             1.0  Keyboard
# 33             1.0  Keyboard
# 51             1.0  Keyboard
# 60             1.0  Keyboard
# 63             1.0  Keyboard
# ...            ...       ...
# 1450           1.0  Keyboard
# 1472           1.0  Keyboard
# 1474           1.0  Keyboard
# 1478           2.0  Keyboard
# 1482           1.0  Keyboard
#
# [98 rows x 6 columns]

# %%
df_rating.sort_values(by= "review_count", ascending = False).head(3)
# Out:
#                                          product title  \
# 375  FUHLEN G610 Wireless Mechanical Gaming Keyboar...
# 366  FUHLEN G610 Wireless Mechanical Gaming Keyboar...
# 926    Glorious Pc Gaming Race Keyboard Wrist Rest (Fu
#
#                                                    url   rating price €  \
# 375  https://www.amazon.com/-/en/FUHLEN-Wireless-Me...  5.0 / 5   59.99
# 366  https://www.amazon.com/-/en/FUHLEN-Wireless-Me...  5.0 / 5   59.99
# 926  https://www.amazon.com/-/en/Glorious-Gaming-Ra...  5.0 / 5   31.90
#
#      review_count   product
# 375          22.0  Keyboard
# 366          22.0  Keyboard
# 926          12.0  Keyboard

# %%
####they are not the most reviewed

# %% [markdown]
# ## Laptops

# %%
df = pd.read_excel("Laptops_sample_cleaned.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0                                      product title  \
# 0           0  Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1           1  BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2           2  HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3           3  Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 4           5  Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
#
#                                                  url   rating  price €  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5  379.00
# 1  https://www.amazon.com/gp/slredirect/picassoRe...  3.8 / 5  459.00
# 2  https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  699.90
# 3  https://www.amazon.com/Acer-Chromebook-Convert...  4.7 / 5  415.95
# 4  https://www.amazon.com/Acer-Chromebook-CB314-1...  4.4 / 5  249.99
#
#    review_count  product
# 0       216.000  Laptops
# 1       687.000  Laptops
# 2       496.000  Laptops
# 3        32.000  Laptops
# 4         1.702  Laptops

# %%
df = df.drop(columns="Unnamed: 0")

# %% [markdown]
# ### rating

# %%
df_1= df

# %%
df_1['rating'] = df_1['rating'].astype(str)
df_1['rating'] = df_1['rating'].str.replace('/ 5', '')
df_1
# Out:
#                                           product title  \
# 0     Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1     BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2     HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3     Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 4     Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
# ...                                                 ...
# 1466  Laptop Stand, Laptop Stand, Notebook Stand, Mu...
# 1467  Laptop Stand, Height-Adjustable Notebook Stand...
# 1468  Voova 17 17.3 Inch Laptop Bag Laptop Sleeve No...
# 1469  Misott Vertical Laptop Stand, Space-Saving Com...
# 1470                               Phone charging cable
#
#                                                     url rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...   4.2   379.00
# 1     https://www.amazon.com/gp/slredirect/picassoRe...   3.8   459.00
# 2     https://www.amazon.com/gp/slredirect/picassoRe...   4.7   699.90
# 3     https://www.amazon.com/Acer-Chromebook-Convert...   4.7   415.95
# 4     https://www.amazon.com/Acer-Chromebook-CB314-1...   4.4   249.99
# ...                                                 ...    ...      ...
# 1466  https://www.amazon.com/-/en/gp/slredirect/pica...   5.0     16.99
# 1467  https://www.amazon.com/-/en/gp/slredirect/pica...   4.0     25.99
# 1468  https://www.amazon.com/-/en/gp/slredirect/pica...   4.6     19.54
# 1469  https://www.amazon.com/-/en/gp/slredirect/pica...   4.2     16.98
# 1470  https://www.amazon.com/-/en/gp/slredirect/pica...   4.4      8.99
#
#       review_count  product
# 0          216.000  Laptops
# 1          687.000  Laptops
# 2          496.000  Laptops
# 3           32.000  Laptops
# 4            1.702  Laptops
# ...            ...      ...
# 1466        21.000  Laptops
# 1467         3.000  Laptops
# 1468       920.000  Laptops
# 1469        32.000  Laptops
# 1470         5.889  Laptops
#
# [1471 rows x 6 columns]

# %%
df_1["rating"]= pd.to_numeric(df["rating"])

# %%
df_1["rating"].mean()
# Out:
# 4.369272603670954

# %%
df_1.describe()
# Out:
#             rating  review_count
# count  1471.000000   1471.000000
# mean      4.369273    112.851434
# std       0.552909    210.999979
# min       1.000000      1.000000
# 25%       4.200000      5.190000
# 50%       4.500000     17.000000
# 75%       4.700000     86.000000
# max       5.000000    999.000000

# %%
df.sort_values(by= "rating", ascending = False)
# Out:
#                                           product title  \
# 938   USB HUB 8 in 1, 4 USB 3.0 HUB Data Hub 5Gbps +...
# 138   XMG Core 17 - M20kzh - 17.3" Full HD IPS 144 H...
# 518   Laptop Stand, Laptop Stand, Notebook Stand, Mu...
# 516   USB HUB 8 in 1, 4 USB 3.0 HUB Data Hub 5Gbps +...
# 1154  Laptop Stand, Laptop Stand, Notebook Stand, Mu...
# ...                                                 ...
# 719   HP EliteBook 820 G3 (12.5") - Intel Core i5 (6...
# 687   Hakeeta SADA Mini USB 2.1 Desktop Speaker Soun...
# 741   External Multifunctional Rechargeable Sound Ca...
# 587       Blade Stealth 13 (L5P/FHD-120Hz/i7/GTX/512GB)
# 160   Redxiao 【Clear for durability】 High-quality CD...
#
#                                                     url   rating   price €  \
# 938   https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5     49.99
# 138   https://www.amazon.com/-/en/XMG-Core-17-GeForc...  5.0 / 5  1.439.00
# 518   https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5     16.99
# 516   https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5     49.99
# 1154  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5     16.99
# ...                                                 ...      ...       ...
# 719   https://www.amazon.com/-/en/EliteBook-820-12-5...  2.9 / 5    552.00
# 687   https://www.amazon.com/-/en/Hakeeta-Desktop-Su...  2.8 / 5     35.39
# 741   https://www.amazon.com/-/en/External-Multifunc...  1.0 / 5     32.94
# 587   https://www.amazon.com/-/en/Blade-Stealth-13-F...  1.0 / 5  1.999.99
# 160   https://www.amazon.com/-/en/durability%E3%80%9...  1.0 / 5     10.09
#
#       review_count  product
# 938            4.0  Laptops
# 138            1.0  Laptops
# 518           21.0  Laptops
# 516            4.0  Laptops
# 1154          21.0  Laptops
# ...            ...      ...
# 719           14.0  Laptops
# 687            3.0  Laptops
# 741            1.0  Laptops
# 587            1.0  Laptops
# 160            1.0  Laptops
#
# [1471 rows x 6 columns]

# %%
df["review_count"].value_counts()
# Out:
# 21.000     100
# 11.000      80
# 3.000       69
# 4.000       66
# 1.000       60
#           ...
# 999.000      1
# 194.000      1
# 2.409        1
# 679.000      1
# 861.000      1
# Name: review_count, Length: 307, dtype: int64

# %%
df_rating = df[(df["rating"] == "5.0 / 5")] 
df_rating
# Out:
#                                           product title  \
# 41    Asus F Series - 15.6 Inch FHD - Intel Celeron ...
# 44    ORICO 3 Port USB 3.0 Hub USB Extension USB 3.0...
# 75    XIDU Laptop Ständer, Ergonomisch Notebook Stän...
# 87    Notebook VivoBook K712 - Intel Core i7-1065G7 ...
# 101   GECEN Mini Wireless Keyboard, Wireless Mini Ke...
# ...                                                 ...
# 1436  USB HUB 8 in 1, 4 USB 3.0 HUB Data Hub 5Gbps +...
# 1438  Laptop Stand, Laptop Stand, Notebook Stand, Mu...
# 1459  USB HUB 8 in 1, 4 USB 3.0 HUB Data Hub 5Gbps +...
# 1462  19.5V 9.23A 180W Laptop Charger AC Power Suppl...
# 1466  Laptop Stand, Laptop Stand, Notebook Stand, Mu...
#
#                                                     url   rating price €  \
# 41    https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5  469.00
# 44    https://www.amazon.com/-/en/ORICO-Extension-Sp...  5.0 / 5    9.99
# 75    https://www.amazon.com/-/en/SH4/dp/B091JVCHSL/...  5.0 / 5   76.99
# 87    https://www.amazon.com/-/en/Notebook-VivoBook-...  5.0 / 5  949.00
# 101   https://www.amazon.com/-/en/Wireless-Keyboard-...  5.0 / 5   13.99
# ...                                                 ...      ...     ...
# 1436  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   49.99
# 1438  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   16.99
# 1459  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   49.99
# 1462  https://www.amazon.com/-/en/Laptop-Charger-Sup...  5.0 / 5   47.00
# 1466  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   16.99
#
#       review_count  product
# 41             1.0  Laptops
# 44             7.0  Laptops
# 75             3.0  Laptops
# 87             2.0  Laptops
# 101            1.0  Laptops
# ...            ...      ...
# 1436           4.0  Laptops
# 1438          21.0  Laptops
# 1459           4.0  Laptops
# 1462           1.0  Laptops
# 1466          21.0  Laptops
#
# [170 rows x 6 columns]

# %%
df_rating.sort_values(by= "review_count", ascending = False).head(3)
# Out:
#                                           product title  \
# 274   Fujitsu Lifebook - 15.6 Inch - Intel Core i5 1...
# 1466  Laptop Stand, Laptop Stand, Notebook Stand, Mu...
# 982   Laptop Stand, Laptop Stand, Notebook Stand, Mu...
#
#                                                     url   rating price €  \
# 274   https://www.amazon.com/-/en/Fujitsu-Lifebook-1...  5.0 / 5  899.00
# 1466  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   16.99
# 982   https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   16.99
#
#       review_count  product
# 274           26.0  Laptops
# 1466          21.0  Laptops
# 982           21.0  Laptops

# %%
####they are not the most reviewed

# %% [markdown]
# ## Monitors

# %%
df = pd.read_excel("Monitors_sample_cleaned.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0                                      product title  \
# 0           0  Philips 275E2FAE - 27 Zoll QHD Gaming Monitor,...
# 1           1  AOC Gaming 24G2U - 24 Zoll FHD Monitor, 144 Hz...
# 2           2  BenQ GW2480 60,45cm (23,8 Zoll) LED Monitor (F...
# 3           3  Lenovo L27q-30 68,58 cm (27 Zoll, 2560x1440, W...
# 4           4  Dell S2421HGF, 24 Zoll, Gaming Monitor, Full H...
#
#                                                  url   rating  price €  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4.5 / 5  269.99
# 1  https://www.amazon.com/gp/slredirect/picassoRe...  4.6 / 5  218.50
# 2  https://www.amazon.com/BenQ-GW2480-IPS-Panel-T...  4.7 / 5  132.17
# 3  https://www.amazon.com/Lenovo-L27q-30-2560x144...  4.5 / 5  209.00
# 4  https://www.amazon.com/Dell-S2421HGF-Gaming-Mo...  4.6 / 5  180.90
#
#    review_count  product
# 0       177.000  Monitor
# 1         4.767  Monitor
# 2        12.199  Monitor
# 3       443.000  Monitor
# 4       699.000  Monitor

# %%
df = df.drop(columns="Unnamed: 0")

# %% [markdown]
# ### rating

# %%
df_1= df

# %%
df_1['rating'] = df_1['rating'].astype(str)
df_1['rating'] = df_1['rating'].str.replace('/ 5', '')
df_1
# Out:
#                                           product title  \
# 0     Philips 275E2FAE - 27 Zoll QHD Gaming Monitor,...
# 1     AOC Gaming 24G2U - 24 Zoll FHD Monitor, 144 Hz...
# 2     BenQ GW2480 60,45cm (23,8 Zoll) LED Monitor (F...
# 3     Lenovo L27q-30 68,58 cm (27 Zoll, 2560x1440, W...
# 4     Dell S2421HGF, 24 Zoll, Gaming Monitor, Full H...
# ...                                                 ...
# 1845  Adwits 4K 2K 1080P 30Hz to 60Hz Support HDMI D...
# 1846                              AOC G2260VWQ6, Silver
# 1847  FITUEYES DT204206WO Wooden Monitor Stand Heigh...
# 1848  Philips 328B1 00 32 inch VA 2 x HDMI, DP 3840 ...
# 1849  RICOO TS0311 Ergonomic Monitor Table Stand Key...
#
#                                                     url rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...   4.5   269.99
# 1     https://www.amazon.com/gp/slredirect/picassoRe...   4.6   218.50
# 2     https://www.amazon.com/BenQ-GW2480-IPS-Panel-T...   4.7   132.17
# 3     https://www.amazon.com/Lenovo-L27q-30-2560x144...   4.5   209.00
# 4     https://www.amazon.com/Dell-S2421HGF-Gaming-Mo...   4.6   180.90
# ...                                                 ...    ...      ...
# 1845  https://www.amazon.com/-/en/Support-Display-Em...   4.6      6.99
# 1846  https://www.amazon.com/-/en/G2590PX-AOC-G2260V...   4.5    244.90
# 1847  https://www.amazon.com/-/en/FITUEYES-DT204206W...   4.5     32.99
# 1848  https://www.amazon.com/-/en/Philips-328B1-00-i...   4.5    593.63
# 1849  https://www.amazon.com/-/en/TS0311-Ergonomic-K...   5.0    129.99
#
#       review_count  product
# 0          177.000  Monitor
# 1            4.767  Monitor
# 2           12.199  Monitor
# 3          443.000  Monitor
# 4          699.000  Monitor
# ...            ...      ...
# 1845       224.000  Monitor
# 1846       622.000  Monitor
# 1847        24.000  Monitor
# 1848        94.000  Monitor
# 1849         4.000  Monitor
#
# [1850 rows x 6 columns]

# %%
df_1["rating"]= pd.to_numeric(df["rating"])

# %%
df_1["rating"].mean()
# Out:
# 4.386594594594613

# %%
df_1.describe()
# Out:
#             rating  review_count
# count  1850.000000   1850.000000
# mean      4.386595    168.024620
# std       0.414507    235.525083
# min       2.500000      1.000000
# 25%       4.300000      4.767000
# 50%       4.500000     39.000000
# 75%       4.600000    281.000000
# max       5.000000    997.000000

# %%
df.sort_values(by= "rating", ascending = False)
# Out:
#                                           product title  \
# 1849  RICOO TS0311 Ergonomic Monitor Table Stand Key...
# 1739  Acer B246WLA 61 cm (24 Inch) IPS Monitor (16: ...
# 1715                                 Deck Link Mini 4 K
# 1719  Miberakom Privacy Screen Filter/Privacy Filter...
# 1151  KFD Monitor Power Supply 19 V Charger for Phil...
# ...                                                 ...
# 1589  CHiQ LED IPS monitor 5 ms, 3-sided, frameless ...
# 1368  CHiQ LED IPS monitor 5 ms, 3-sided, frameless ...
# 1643  Shumo 10.1-Inch Small Portable Laptop Computer...
# 534                                 Samsung S24A310NHU.
# 1564  ELECROW Portable Monitor Compatible with Windo...
#
#                                                     url   rating price €  \
# 1849  https://www.amazon.com/-/en/TS0311-Ergonomic-K...  5.0 / 5  129.99
# 1739  https://www.amazon.com/-/en/Acer-B246WLA-24-In...  5.0 / 5  238.97
# 1715  https://www.amazon.com/-/en/OB02398-Deck-Link-...  5.0 / 5  204.55
# 1719  https://www.amazon.com/-/en/Miberakom-Protecto...  5.0 / 5   24.95
# 1151  https://www.amazon.com/-/en/Monitor-Charger-24...  5.0 / 5   20.99
# ...                                                 ...      ...     ...
# 1589  https://www.amazon.com/-/en/gp/slredirect/pica...  3.0 / 5  149.99
# 1368  https://www.amazon.com/-/en/gp/slredirect/pica...  3.0 / 5  149.99
# 1643  https://www.amazon.com/-/en/10-1-Inch-Portable...  2.8 / 5   71.32
# 534   https://www.amazon.com/-/en/LS24A310NHUXEN-Sam...  2.6 / 5  119.67
# 1564  https://www.amazon.com/-/en/ELECROW-Portable-M...  2.5 / 5  199.90
#
#       review_count  product
# 1849           4.0  Monitor
# 1739           5.0  Monitor
# 1715           2.0  Monitor
# 1719           3.0  Monitor
# 1151           3.0  Monitor
# ...            ...      ...
# 1589           3.0  Monitor
# 1368           3.0  Monitor
# 1643           2.0  Monitor
# 534            7.0  Monitor
# 1564           2.0  Monitor
#
# [1850 rows x 6 columns]

# %%
df["review_count"].value_counts()
# Out:
# 3.000      99
# 4.767      72
# 328.000    70
# 6.044      70
# 1.732      64
#            ..
# 1.023       1
# 686.000     1
# 263.000     1
# 166.000     1
# 415.000     1
# Name: review_count, Length: 496, dtype: int64

# %%
df_rating = df[(df["rating"] == "5.0 / 5")] 
df_rating
# Out:
#                                           product title  \
# 10    Thomson M24FC33202 24“ (60 cm) Full HD VA Moni...
# 42    THOMSON M24FC33202 24" (60 cm) Full HD VA Moni...
# 197                          AWOW Portable monitor T15A
# 206   LG 43BN70U-B LED Monitor, Black, UltraHD/4K, U...
# 244   Thinlerain 13.3 Inch CCTV Monitor Portable 136...
# ...                                                 ...
# 1747  Acer V226WLbmd Monitor 55.8 cm (22 Inch) VGA D...
# 1755  MPIO Wireless HDMI Display Dongle Adapter, 4K ...
# 1818  ASUS VY249HE 60.5 cm (23.8 Inch) Eye-Care Moni...
# 1836  ASUS ZenScreen MB16AH 39.62 cm (15.6 inch) por...
# 1849  RICOO TS0311 Ergonomic Monitor Table Stand Key...
#
#                                                     url   rating  price €  \
# 10    https://www.amazon.com/Thomson-M24FC33202-Moni...  5.0 / 5  112.00
# 42    https://www.amazon.com/-/en/THOMSON-M24FC33202...  5.0 / 5   112.00
# 197   https://www.amazon.com/-/en/AWOW-Portable-moni...  5.0 / 5   189.99
# 206   https://www.amazon.com/-/en/43BN70U-B-Monitor-...  5.0 / 5   617.76
# 244   https://www.amazon.com/-/en/Thinlerain-Monitor...  5.0 / 5    95.99
# ...                                                 ...      ...      ...
# 1747  https://www.amazon.com/-/en/Acer-V226WLbmd-Mon...  5.0 / 5   157.90
# 1755  https://www.amazon.com/-/en/Wireless-Streaming...  5.0 / 5    29.99
# 1818  https://www.amazon.com/-/en/VY249HE-Eye-Care-M...  5.0 / 5   139.99
# 1836  https://www.amazon.com/-/en/ZenScreen-MB16AH-p...  5.0 / 5   284.90
# 1849  https://www.amazon.com/-/en/TS0311-Ergonomic-K...  5.0 / 5   129.99
#
#       review_count  product
# 10             2.0  Monitor
# 42             2.0  Monitor
# 197            8.0  Monitor
# 206            8.0  Monitor
# 244            3.0  Monitor
# ...            ...      ...
# 1747           1.0  Monitor
# 1755           6.0  Monitor
# 1818           2.0  Monitor
# 1836           4.0  Monitor
# 1849           4.0  Monitor
#
# [75 rows x 6 columns]

# %%
df_rating["review_count"].value_counts()
# Out:
# 1.0     26
# 2.0     18
# 3.0     11
# 5.0      4
# 8.0      4
# 6.0      4
# 4.0      3
# 7.0      3
# 15.0     1
# 12.0     1
# Name: review_count, dtype: int64

# %%
df_rating.sort_values(by= "review_count", ascending = False).head(3)
# Out:
#                                           product title  \
# 1273  Computer Monitor Lamp, Wodgreat LED USB Lamp E...
# 633   ASUS VA249DQLB-W 60.5 cm (23.8 Inch) EyeCare M...
# 197                          AWOW Portable monitor T15A
#
#                                                     url   rating price €  \
# 1273  https://www.amazon.com/-/en/Computer-Wodgreat-...  5.0 / 5   27.99
# 633   https://www.amazon.com/-/en/VA249DQLB-W-EyeCar...  5.0 / 5  197.90
# 197   https://www.amazon.com/-/en/AWOW-Portable-moni...  5.0 / 5  189.99
#
#       review_count  product
# 1273          15.0  Monitor
# 633           12.0  Monitor
# 197            8.0  Monitor

# %%
####they are not the most reviewed

# %% [markdown]
# ## Mouse

# %%
df = pd.read_excel("Mouse_sample_cleaned.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0                                      product title  \
# 0           0  INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1           1  QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2           2  Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3           3  Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4           4  seenda Maus mit Kabel, PC Laptop Computer Maus...
#
#                                                  url   rating price €  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  11.04
# 1  https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5   8.99
# 2  https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.19
# 3  https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.99
# 4  https://www.amazon.com/seenda-Laptop-Computer-...  4.6 / 5   7.35
#
#    review_count product
# 0         7.398   Mouse
# 1       837.000   Mouse
# 2        28.219   Mouse
# 3        28.219   Mouse
# 4       191.000   Mouse

# %%
df = df.drop(columns="Unnamed: 0")

# %% [markdown]
# ### rating

# %%
df_1= df

# %%
df_1['rating'] = df_1['rating'].astype(str)
df_1['rating'] = df_1['rating'].str.replace('/ 5', '')
df_1
# Out:
#                                           product title  \
# 0     INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1     QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2     Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3     Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4     seenda Maus mit Kabel, PC Laptop Computer Maus...
# ...                                                 ...
# 1885                               Apple Magic Keyboard
# 1886     Glorioso PC Racing Game GW-E Mouse Mat - White
# 1887                          Microsoft Arc Touch Mouse
# 1888  ITNRSIIET Ergonomic Mouse Mat Gel Wrist Rest G...
# 1889  Lenovo 530 Wireless Mouse Ambidextrous Nano US...
#
#                                                     url rating price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...   4.3   11.04
# 1     https://www.amazon.com/gp/slredirect/picassoRe...   4.2    8.99
# 2     https://www.amazon.com/Logitech-M185-Maus-schn...   4.7    9.19
# 3     https://www.amazon.com/Logitech-M185-Maus-schn...   4.7    9.99
# 4     https://www.amazon.com/seenda-Laptop-Computer-...   4.6    7.35
# ...                                                 ...    ...     ...
# 1885  https://www.amazon.com/-/en/MRMH2D-A-Apple-Mag...   4.8   131.77
# 1886  https://www.amazon.com/-/en/Glorioso-Racing-Ga...   4.4    34.90
# 1887  https://www.amazon.com/-/en/RVF-00050-Microsof...   4.1    52.90
# 1888  https://www.amazon.com/-/en/ITNRSIIET-Ergonomi...   4.7     7.99
# 1889  https://www.amazon.com/-/en/Wireless-Ambidextr...   4.4    28.52
#
#       review_count product
# 0            7.398   Mouse
# 1          837.000   Mouse
# 2           28.219   Mouse
# 3           28.219   Mouse
# 4          191.000   Mouse
# ...            ...     ...
# 1885         2.731   Mouse
# 1886         7.412   Mouse
# 1887       282.000   Mouse
# 1888        50.000   Mouse
# 1889       381.000   Mouse
#
# [1890 rows x 6 columns]

# %%
df_1["rating"]= pd.to_numeric(df["rating"])

# %%
df_1["rating"].mean()
# Out:
# 4.464497354497336

# %%
df_1.describe()
# Out:
#             rating  review_count
# count  1890.000000   1890.000000
# mean      4.464497    124.288761
# std       0.343007    203.237093
# min       2.000000      1.000000
# 25%       4.400000      2.763000
# 50%       4.500000     20.000000
# 75%       4.700000    143.191750
# max       5.000000    998.000000

# %%
df.sort_values(by= "rating", ascending = False)
# Out:
#                                           product title  \
# 413   AOTEHU Mouse Pads Office Mouse Pad Premium Tex...
# 1726  KVM Switch Box 2-Port PC Monitor Switch Box + ...
# 1425  Office and Gaming Mouse Pad, Washable Mousepad...
# 555   IWILCS RGB Gaming Mouse Pad, Larger Gaming Mou...
# 428   Gaming Mouse Mat with Stitched Edges - Mouse P...
# ...                                                 ...
# 1698                        Penclic Wired Mouse - Black
# 876   White Black Gold Marble Mouse Pad, Office Mous...
# 1245  Gaming Mouse Mat - Stitched Edges - Waterproof...
# 1825  Gaming Mouse Pad, Office Mouse Pad, Mousepad P...
# 1732  Hakeeta 68 x 33 cm Large Mouse Mat Soft Dustpr...
#
#                                                     url   rating price €  \
# 413   https://www.amazon.com/-/en/Premium-Textured-M...  5.0 / 5    4.92
# 1726  https://www.amazon.com/-/en/Switch-2-Port-Moni...  5.0 / 5   12.99
# 1425  https://www.amazon.com/-/en/Washable-Mousepad-...  5.0 / 5    6.82
# 555   https://www.amazon.com/-/en/Mousepad-Lighting-...  5.0 / 5   12.99
# 428   https://www.amazon.com/-/en/Gaming-Mouse-Mat-S...  5.0 / 5    4.82
# ...                                                 ...      ...     ...
# 1698  https://www.amazon.com/-/en/PENCLIC2021-Pencli...  2.1 / 5   55.00
# 876   https://www.amazon.com/-/en/Mousepad-Washable-...  2.0 / 5    5.99
# 1245  https://www.amazon.com/-/en/Gaming-Mouse-Mat-W...  2.0 / 5    4.82
# 1825  https://www.amazon.com/-/en/Mousepad-Underlay-...  2.0 / 5    4.52
# 1732  https://www.amazon.com/-/en/Dustproof-Antistat...  2.0 / 5    6.09
#
#       review_count product
# 413            3.0   Mouse
# 1726           1.0   Mouse
# 1425           1.0   Mouse
# 555            2.0   Mouse
# 428            4.0   Mouse
# ...            ...     ...
# 1698           7.0   Mouse
# 876            1.0   Mouse
# 1245           1.0   Mouse
# 1825           2.0   Mouse
# 1732           1.0   Mouse
#
# [1890 rows x 6 columns]

# %%
df["review_count"].value_counts()
# Out:
# 1.594      75
# 1.229      73
# 136.000    68
# 2.497      64
# 301.000    56
#            ..
# 93.000      1
# 555.000     1
# 353.000     1
# 274.000     1
# 4.937       1
# Name: review_count, Length: 613, dtype: int64

# %%
df_rating = df[(df["rating"] == "5.0 / 5")] 
df_rating
# Out:
#                                           product title  \
# 76    Memzuoix Wireless Mouse, Upgraded 2.4G Wireles...
# 249   Leegicst USB Wired Optical Computer Mouse - M1...
# 251   Gaming Mouse Mat - Stitched Edges Mouse Pad - ...
# 275   Mousepad Small Mouse Mat with Slogan Not Today...
# 287   Memzuoix Wireless Mouse, Upgraded 2.4G Wireles...
# ...                                                 ...
# 1848  Gaming Mouse Mat - Stitched Edges Mouse Pad - ...
# 1867  DJFT Mouse Pads Advanced Gaming Mouse Pad Marv...
# 1870  Kafuty Pink Optical Mouse 3200DPI High Sensiti...
# 1871  Mouse Mat with Marble Motif, 24 x 20 cm Gaming...
# 1873  Eintracht Frankfurt Mouse Mat PC DIY Mouse Mat...
#
#                                                     url   rating price €  \
# 76    https://www.amazon.com/-/en/Memzuoix-Wireless-...  5.0 / 5   21.99
# 249   https://www.amazon.com/-/en/Leegicst-Wired-Opt...  5.0 / 5    7.99
# 251   https://www.amazon.com/-/en/Gaming-Mouse-Mat-S...  5.0 / 5    4.62
# 275   https://www.amazon.com/-/en/Mousepad-Stitched-...  5.0 / 5    7.99
# 287   https://www.amazon.com/-/en/Memzuoix-Wireless-...  5.0 / 5   21.99
# ...                                                 ...      ...     ...
# 1848  https://www.amazon.com/-/en/Gaming-Mouse-Mat-S...  5.0 / 5    4.62
# 1867  https://www.amazon.com/-/en/Advanced-Superhero...  5.0 / 5   23.86
# 1870  https://www.amazon.com/-/en/Optical-3200DPI-Se...  5.0 / 5   13.09
# 1871  https://www.amazon.com/-/en/Non-Slip-Mousepad-...  5.0 / 5    6.90
# 1873  https://www.amazon.com/-/en/Eintracht-Frankfur...  5.0 / 5   11.82
#
#       review_count product
# 76             7.0   Mouse
# 249            1.0   Mouse
# 251            4.0   Mouse
# 275            4.0   Mouse
# 287            7.0   Mouse
# ...            ...     ...
# 1848           4.0   Mouse
# 1867           1.0   Mouse
# 1870           2.0   Mouse
# 1871           3.0   Mouse
# 1873           1.0   Mouse
#
# [105 rows x 6 columns]

# %%
df_rating["review_count"].value_counts()

# %%
df_rating.sort_values(by= "review_count", ascending = False).head(3)
# Out:
#                                           product title  \
# 1358  Viper Gaming V550 Amidextrous RGB Optical Gami...
# 1370  Patriot Viper V551 RGB Gaming Mouse, 12000 DPI...
# 1428         Cougar Gaming Minos XT 4000 DPI Mouse Pink
#
#                                                     url   rating price €  \
# 1358  https://www.amazon.com/-/en/Viper-Gaming-Amide...  5.0 / 5   38.71
# 1370  https://www.amazon.com/-/en/Patriot-Lighting-P...  5.0 / 5   39.90
# 1428  https://www.amazon.com/-/en/Cougar-Gaming-Mino...  5.0 / 5   29.74
#
#       review_count product
# 1358           8.0   Mouse
# 1370           8.0   Mouse
# 1428           8.0   Mouse

# %%
####they are not the most reviewed

# %% [markdown]
# ## processor

# %%
df = pd.read_excel("Processors_sample_cleaned.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0                                      product title  \
# 0           0  MINIS FORUM Mini PC, Intel Celeron Processor J...
# 1           2  AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 2           4  INTEL BXTS15A Thermal Solution TS15A for Intel...
# 3           5  AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 4           6  Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
#
#                                                  url   rating  price €  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  249.99
# 1  https://www.amazon.com/AMD-Ryzen-3700X-Prozess...  4.8 / 5  262.70
# 2  https://www.amazon.com/BXTS15A-Solution-Intel-...  4.4 / 5   28.91
# 3  https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...  4.8 / 5  209.99
# 4  https://www.amazon.com/gp/slredirect/picassoRe...  4.1 / 5  320.99
#
#    review_count    product
# 0       106.000  Processor
# 1        20.484  Processor
# 2        13.000  Processor
# 3        33.386  Processor
# 4       205.000  Processor

# %%
df = df.drop(columns="Unnamed: 0")

# %% [markdown]
# ### rating

# %%
df_1= df

# %%
df_1['rating'] = df_1['rating'].astype(str)
df_1['rating'] = df_1['rating'].str.replace('/ 5', '')
df_1
# Out:
#                                           product title  \
# 0     MINIS FORUM Mini PC, Intel Celeron Processor J...
# 1     AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 2     INTEL BXTS15A Thermal Solution TS15A for Intel...
# 3     AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 4     Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
# ...                                                 ...
# 1564  MoneyQiu HY-700 (50 g) > 3.14 W/m.K, CPU Therm...
# 1565                             MSI Gaming Motherboard
# 1566  ACEPC Mini PC, Intel Celeron J3455, AK1 4GB RA...
# 1567  Intel Nuc Mini Complete PC, Intel i5-10210U Qu...
# 1568  Intel Nuc Mini Complete PC, Intel Quad Core 4 ...
#
#                                                     url rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...   4.3   249.99
# 1     https://www.amazon.com/AMD-Ryzen-3700X-Prozess...   4.8   262.70
# 2     https://www.amazon.com/BXTS15A-Solution-Intel-...   4.4    28.91
# 3     https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...   4.8   209.99
# 4     https://www.amazon.com/gp/slredirect/picassoRe...   4.1   320.99
# ...                                                 ...    ...      ...
# 1564  https://www.amazon.com/-/en/MoneyQiu-HY-700-Th...   4.5     16.99
# 1565  https://www.amazon.com/-/en/7C37-001R-MSI-Gami...   4.6    174.90
# 1566  https://www.amazon.com/-/en/Celeron-Windows-Bl...   3.8    159.90
# 1567  https://www.amazon.com/-/en/Complete-i5-10210U...   4.0    429.99
# 1568  https://www.amazon.com/-/en/Complete-2-30GHz-G...   4.7    469.00
#
#       review_count    product
# 0          106.000  Processor
# 1           20.484  Processor
# 2           13.000  Processor
# 3           33.386  Processor
# 4          205.000  Processor
# ...            ...        ...
# 1564       424.000  Processor
# 1565         2.467  Processor
# 1566       175.000  Processor
# 1567         2.000  Processor
# 1568        48.000  Processor
#
# [1569 rows x 6 columns]

# %%
df_1["rating"]= pd.to_numeric(df["rating"])

# %%
df_1["rating"].mean()
# Out:
# 4.200318674314862

# %%
df_1.describe()
# Out:
#             rating  review_count
# count  1569.000000   1569.000000
# mean      4.200319    113.894927
# std       0.627439    198.221787
# min       1.000000      1.000000
# 25%       4.000000      4.000000
# 50%       4.300000     28.000000
# 75%       4.600000    124.000000
# max       5.000000    999.000000

# %%
df.sort_values(by= "rating", ascending = False)
# Out:
#                                           product title  \
# 1289  Lenovo ThinkPad X1 Yoga 2, Intel i7 2 x 2.8 GH...
# 892   MEDION P66089 Desktop Computer (Intel Core i5-...
# 79    Intel Core i7-10700 Desktop Processor 8 Cores ...
# 745   Acer Aspire 4830 4830T 4830TG Laptop CPU Cooli...
# 194   HP ProDesk 600 G1 Desktop Mini Intel Core i5 P...
# ...                                                 ...
# 958   Lenovo ThinkPad W540, Intel i7, 2.7 GHz – 8–16...
# 1349  Intel Xeon W-2123 Processor 3.60 GHz Box 8.3 M...
# 1285  Intel Celeron G4930 Desktop Processor 2 Core 3...
# 1383  Intel Xeon W-2123 Processor 3.60 GHz Box 8.3 M...
# 560   Intel Core i5 7400 3,00GHZ LGA1151 6 MB Cache ...
#
#                                                     url   rating   price €  \
# 1289  https://www.amazon.com/-/en/dp/B0847LY62R/ref=...  5.0 / 5  1.285.00
# 892   https://www.amazon.com/-/en/P66089-Desktop-Com...  5.0 / 5    799.99
# 79    https://www.amazon.com/-/en/i7-10700-Desktop-P...  5.0 / 5    327.03
# 745   https://www.amazon.com/-/en/Aspire-4830-4830T-...  5.0 / 5      8.90
# 194   https://www.amazon.com/-/en/ProDesk-Processor-...  5.0 / 5    256.00
# ...                                                 ...      ...       ...
# 958   https://www.amazon.com/-/en/Lenovo-ThinkPad-W5...  1.7 / 5    949.00
# 1349  https://www.amazon.com/-/en/Intel-Xeon-W-2123-...  1.0 / 5    331.57
# 1285  https://www.amazon.com/-/en/Intel-Celeron-Desk...  1.0 / 5     85.53
# 1383  https://www.amazon.com/-/en/Intel-Xeon-W-2123-...  1.0 / 5    331.57
# 560   https://www.amazon.com/-/en/Intel-i5-7400-00GH...  1.0 / 5    220.97
#
#       review_count    product
# 1289           2.0  Processor
# 892            1.0  Processor
# 79            15.0  Processor
# 745            1.0  Processor
# 194            1.0  Processor
# ...            ...        ...
# 958            3.0  Processor
# 1349           1.0  Processor
# 1285           1.0  Processor
# 1383           1.0  Processor
# 560            2.0  Processor
#
# [1569 rows x 6 columns]

# %%
df["review_count"].value_counts()
# Out:
# 3.000      100
# 12.000      78
# 205.000     72
# 44.000      71
# 2.000       70
#           ...
# 5.931        1
# 1.580        1
# 574.000      1
# 10.602       1
# 54.000       1
# Name: review_count, Length: 396, dtype: int64

# %%
df_rating = df[(df["rating"] == "5.0 / 5")] 
df_rating
# Out:
#                                           product title  \
# 47    Intel Core i9-11900K Desktop Processor (Base C...
# 70    Intel Core™ i9-BX8070110900KF Desktop Processo...
# 72    Lenovo ThinkPad X1 Carbon 5 Mobile Notebook In...
# 79    Intel Core i7-10700 Desktop Processor 8 Cores ...
# 115   Laptop YITAOERA 13.3" IPS Display, Intel 64-bi...
# ...                                                 ...
# 1457  Mini PC, Minisforum GK50 Intel Pentium N5030 4...
# 1460  Topiky Single Fan Radiator 3Pin 4 Heat Pipe CP...
# 1469  Supermicro SNK P0068AP4 – Processor cooler – (...
# 1507  HP EliteDesk 800 G2 SFF 3 Year Warranty Intel ...
# 1555  Lenovo ThinkPad T490s 14 Inch FHD (1920x1080) ...
#
#                                                     url   rating   price €  \
# 47    https://www.amazon.com/-/en/Intel-i9-11900K-De...  5.0 / 5    615.14
# 70    https://www.amazon.com/-/en/i9-BX8070110900KF-...  5.0 / 5    463.98
# 72    https://www.amazon.com/-/en/ThinkPad-Notebook-...  5.0 / 5  1.199.00
# 79    https://www.amazon.com/-/en/i7-10700-Desktop-P...  5.0 / 5    327.03
# 115   https://www.amazon.com/-/en/YITAOERA-Display-C...  5.0 / 5    318.00
# ...                                                 ...      ...       ...
# 1457  https://www.amazon.com/-/en/Minisforum-GK50-Pe...  5.0 / 5    329.00
# 1460  https://www.amazon.com/-/en/Topiky-Single-Radi...  5.0 / 5     25.99
# 1469  https://www.amazon.com/-/en/Supermicro-P0068AP...  5.0 / 5     51.42
# 1507  https://www.amazon.com/-/en/EliteDesk-Warranty...  5.0 / 5    218.99
# 1555  https://www.amazon.com/-/en/ThinkPad-T490s-192...  5.0 / 5  1.601.09
#
#       review_count    product
# 47             2.0  Processor
# 70             2.0  Processor
# 72             6.0  Processor
# 79            15.0  Processor
# 115            2.0  Processor
# ...            ...        ...
# 1457           1.0  Processor
# 1460           1.0  Processor
# 1469           1.0  Processor
# 1507           1.0  Processor
# 1555           1.0  Processor
#
# [105 rows x 6 columns]

# %%
df_rating["review_count"].value_counts()
# Out:
# 1.0     34
# 2.0     19
# 7.0     12
# 3.0     11
# 6.0     11
# 4.0      7
# 14.0     4
# 8.0      3
# 36.0     2
# 15.0     1
# 5.0      1
# Name: review_count, dtype: int64

# %%
df_rating.sort_values(by= "review_count", ascending = False).head(3)
# Out:
#                                           product title  \
# 910   Tablet 10 Inch Android 10.0 - Yumkem Tablets 4...
# 1297  Tablet 10 Inch Android 10.0 - Yumkem Tablets 4...
# 79    Intel Core i7-10700 Desktop Processor 8 Cores ...
#
#                                                     url   rating price €  \
# 910   https://www.amazon.com/-/en/Tablet-Inch-Androi...  5.0 / 5  134.98
# 1297  https://www.amazon.com/-/en/Tablet-Inch-Androi...  5.0 / 5  134.98
# 79    https://www.amazon.com/-/en/i7-10700-Desktop-P...  5.0 / 5  327.03
#
#       review_count    product
# 910           36.0  Processor
# 1297          36.0  Processor
# 79            15.0  Processor

# %%
####they are not the most reviewed

# %% [markdown]
# ## Smartphones

# %%
df = pd.read_excel("Smartphones_sample_cleaned.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0                                      product title  \
# 0           1  DOOGEE N30 Smartphone ohne Vertrag Gebogenes G...
# 1           2  Outdoor Handy, IIIF150 B2021 Outdoor Smartphon...
# 2           3  Samsung Galaxy S20 FE, Android Smartphone ohne...
# 3           4  Nokia 8.3 5G – Vierfach-Kamera mit ZEISS-Optik...
# 4           5  Xiaomi Redmi Note 10 Pro Smartphone + Kopfhöre...
#
#                                                  url   rating  price €  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5  159.99
# 1  https://www.amazon.com/gp/slredirect/picassoRe...  4.4 / 5  179.99
# 2  https://www.amazon.com/Samsung-Android-Smartph...  4.6 / 5  625.00
# 3  https://www.amazon.com/Nokia-8-3-Vierfach-Kame...  4.3 / 5  359.00
# 4  https://www.amazon.com/Xiaomi-Smartphone-Kopfh...  4.5 / 5  279.90
#
#    review_count     product
# 0       358.000  Smartphone
# 1        64.000  Smartphone
# 2         1.601  Smartphone
# 3       371.000  Smartphone
# 4       396.000  Smartphone

# %%
df = df.drop(columns="Unnamed: 0")

# %% [markdown]
# ### rating

# %%
df_1= df

# %%
df_1['rating'] = df_1['rating'].astype(str)
df_1['rating'] = df_1['rating'].str.replace('/ 5', '')
df_1
# Out:
#                                           product title  \
# 0     DOOGEE N30 Smartphone ohne Vertrag Gebogenes G...
# 1     Outdoor Handy, IIIF150 B2021 Outdoor Smartphon...
# 2     Samsung Galaxy S20 FE, Android Smartphone ohne...
# 3     Nokia 8.3 5G – Vierfach-Kamera mit ZEISS-Optik...
# 4     Xiaomi Redmi Note 10 Pro Smartphone + Kopfhöre...
# ...                                                 ...
# 2171  Xiaomi Redmi 9 smartphone + headphones (16.59 ...
# 2172  Samsung Galaxy S20 FE, Android SIM Free Smartp...
# 2173  Outdoor Mobile Phone, IIIF150 B2021 Outdoor Sm...
# 2174               SPC 2350116N Apolo Senior 5 16GB 1GB
# 2175  Ulefone Note 9P Smartphone Without Contract, A...
#
#                                                     url rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...   4.2   159.99
# 1     https://www.amazon.com/gp/slredirect/picassoRe...   4.4   179.99
# 2     https://www.amazon.com/Samsung-Android-Smartph...   4.6   625.00
# 3     https://www.amazon.com/Nokia-8-3-Vierfach-Kame...   4.3   359.00
# 4     https://www.amazon.com/Xiaomi-Smartphone-Kopfh...   4.5   279.90
# ...                                                 ...    ...      ...
# 2171  https://www.amazon.com/-/en/smartphone-headpho...   4.7    178.67
# 2172  https://www.amazon.com/-/en/Samsung-Android-Sm...   4.6    625.00
# 2173  https://www.amazon.com/-/en/gp/slredirect/pica...   4.4    179.99
# 2174  https://www.amazon.com/-/en/gp/slredirect/pica...   2.9     89.90
# 2175  https://www.amazon.com/-/en/gp/slredirect/pica...   4.3    154.99
#
#       review_count     product
# 0          358.000  Smartphone
# 1           64.000  Smartphone
# 2            1.601  Smartphone
# 3          371.000  Smartphone
# 4          396.000  Smartphone
# ...            ...         ...
# 2171       288.000  Smartphone
# 2172         1.601  Smartphone
# 2173        64.000  Smartphone
# 2174       124.000  Smartphone
# 2175         2.383  Smartphone
#
# [2176 rows x 6 columns]

# %%
df_1["rating"]= pd.to_numeric(df["rating"])

# %%
df_1["rating"].mean()
# Out:
# 4.2428768382352935

# %%
df_1.describe()
# Out:
#             rating  review_count
# count  2176.000000   2176.000000
# mean      4.242877    166.337852
# std       0.476959    230.568887
# min       1.000000      1.000000
# 25%       4.100000     11.000000
# 50%       4.300000     65.000000
# 75%       4.500000    198.500000
# max       5.000000    994.000000

# %%
df.sort_values(by= "rating", ascending = False)
# Out:
#                                           product title  \
# 104   Cubot Note 20 Pro Smartphone, 6.5 Inch HD Disp...
# 994   Samsung Galaxy A32 5G Smartphone Blue 64GB Dua...
# 2001  vivo X60 Pro 5G, Midnight Black, 12 + 256 GB, ...
# 1364  Black Shark 4 [5G] Smartphone 6 + 128GB, Scree...
# 445   Outdoor Mobile Phone with Night Vision, DOOGEE...
# ...                                                 ...
# 1828  Samsung Galaxy A32 5G Smartphone 128GB, 4GB RA...
# 2103  SXXDERTY 4G Mobile Phone SIM Card Free Unlocke...
# 1806  Samsung Galaxy A32 5G Smartphone 128GB, 4GB RA...
# 1612  Outdoor Smartphone No Contract, Poptel P60 Rob...
# 2054  PNAYK S20 4G Smartphone without Contract, Chea...
#
#                                                     url   rating price €  \
# 104   https://www.amazon.com/-/en/Note-20-Pro-Smartp...  5.0 / 5  169.99
# 994   https://www.amazon.com/-/en/Samsung-Galaxy-Sma...  5.0 / 5  244.24
# 2001  https://www.amazon.com/-/en/Midnight-Fingerpri...  5.0 / 5  875.54
# 1364  https://www.amazon.com/-/en/Smartphone-Snapdra...  5.0 / 5  429.00
# 445   https://www.amazon.com/-/en/Outdoor-6350mAh-Wa...  5.0 / 5  319.99
# ...                                                 ...      ...     ...
# 1828  https://www.amazon.com/-/en/Samsung-Galaxy-Sma...  2.0 / 5  337.90
# 2103  https://www.amazon.com/-/en/SXXDERTY-Unlocked-...  2.0 / 5   75.01
# 1806  https://www.amazon.com/-/en/Samsung-Galaxy-Sma...  2.0 / 5  337.90
# 1612  https://www.amazon.com/-/en/Smartphone-Poptel-...  1.0 / 5  299.99
# 2054  https://www.amazon.com/-/en/Smartphone-without...  1.0 / 5  121.02
#
#       review_count     product
# 104            5.0  Smartphone
# 994            1.0  Smartphone
# 2001           5.0  Smartphone
# 1364           2.0  Smartphone
# 445           31.0  Smartphone
# ...            ...         ...
# 1828           1.0  Smartphone
# 2103           1.0  Smartphone
# 1806           1.0  Smartphone
# 1612           1.0  Smartphone
# 2054           1.0  Smartphone
#
# [2176 rows x 6 columns]

# %%
df["review_count"].value_counts()
# Out:
# 124.000    76
# 92.000     75
# 846.000    71
# 3.365      71
# 2.369      68
#            ..
# 457.000     1
# 731.000     1
# 1.069       1
# 1.030       1
# 134.000     1
# Name: review_count, Length: 533, dtype: int64

# %%
df_rating = df[(df["rating"] == "5.0 / 5")] 
df_rating
# Out:
#                                           product title  \
# 104   Cubot Note 20 Pro Smartphone, 6.5 Inch HD Disp...
# 119   Ulefone Armor 8 Pro Android 11 Outdoor Smartph...
# 150   Motorola Moto G30 (6.5" Screen, 64MP Camera, 4...
# 196   Redmi Note 10S Smartphone RAM 6 GB ROM 64 GB 6...
# 236   DOOGEE S59 Android 10, 10050 mAh Battery, Outd...
# ...                                                 ...
# 2060  Xiaomi Redmi Note 10S Smartphone + Headphones ...
# 2113  Rugged Smartphone Doogee S59 Android 10 4GB + ...
# 2119              Audi Sport Smartphone Case 3222000300
# 2149  Sony Xperia E5 Unlocked 4G Smartphone – 5 Inch...
# 2160                                 Samsung Galaxy S20
#
#                                                     url   rating price €  \
# 104   https://www.amazon.com/-/en/Note-20-Pro-Smartp...  5.0 / 5  169.99
# 119   https://www.amazon.com/-/en/Ulefone-Smartphone...  5.0 / 5  219.99
# 150   https://www.amazon.com/-/en/Motorola-Screen-50...  5.0 / 5  175.99
# 196   https://www.amazon.com/-/en/Smartphone-DotDisp...  5.0 / 5  204.00
# 236   https://www.amazon.com/-/en/Android-Battery-Sm...  5.0 / 5  189.99
# ...                                                 ...      ...     ...
# 2060  https://www.amazon.com/-/en/Smartphone-Headpho...  5.0 / 5  249.90
# 2113  https://www.amazon.com/-/en/Smartphone-Android...  5.0 / 5  350.51
# 2119  https://www.amazon.com/-/en/Audi-Sport-Smartph...  5.0 / 5   29.90
# 2149  https://www.amazon.com/-/en/Xperia-E5-Unlocked...  5.0 / 5  119.00
# 2160  https://www.amazon.com/-/en/SM-G986BZADEUB-Sam...  5.0 / 5  719.99
#
#       review_count     product
# 104            5.0  Smartphone
# 119           10.0  Smartphone
# 150            4.0  Smartphone
# 196            4.0  Smartphone
# 236           11.0  Smartphone
# ...            ...         ...
# 2060           1.0  Smartphone
# 2113           5.0  Smartphone
# 2119           5.0  Smartphone
# 2149           1.0  Smartphone
# 2160           1.0  Smartphone
#
# [85 rows x 6 columns]

# %%
df_rating["review_count"].value_counts()
# Out:
# 1.0     20
# 2.0     17
# 3.0     10
# 4.0      9
# 5.0      8
# 11.0     8
# 10.0     5
# 31.0     2
# 8.0      2
# 6.0      2
# 13.0     1
# 9.0      1
# Name: review_count, dtype: int64

# %%
df_rating.sort_values(by= "review_count", ascending = False).head(3)
# Out:
#                                           product title  \
# 473   Outdoor Mobile Phone with Night Vision, DOOGEE...
# 445   Outdoor Mobile Phone with Night Vision, DOOGEE...
# 1773  Mobile Phone Tripod, Portable Octopus Tripod w...
#
#                                                     url   rating price €  \
# 473   https://www.amazon.com/-/en/Outdoor-6350mAh-Wa...  5.0 / 5  319.99
# 445   https://www.amazon.com/-/en/Outdoor-6350mAh-Wa...  5.0 / 5  319.99
# 1773  https://www.amazon.com/-/en/Portable-Bluetooth...  5.0 / 5   17.68
#
#       review_count     product
# 473           31.0  Smartphone
# 445           31.0  Smartphone
# 1773          13.0  Smartphone

# %%
####they are not the most reviewed
