# %%
import pandas as pd

# %% [markdown]
# # •	Top 3 selling products in each product segment by customer rating.

# %% [markdown]
# ## DSLR_Cameras

# %%
df = pd.read_csv("DSLR_sample.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-ba17a8912f97> in <module>
# ----> 1 df = pd.read_csv("DSLR_sample.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...

# %%
df = df.drop(columns="Unnamed: 0")

# %%
df
# Out:
#                                                   name product_summary  \
# 0    Wireless Lavalier Microphone 2.4G Dual-Channel...             NaN
# 1    Canon EOS 2000D (Rebel T7) DSLR Camera + 18-55...             NaN
# 2    Canon EOS 850D EF-S 18-55mm is STM Kit (Intern...             NaN
# 3    Canon EOS 2000D DSLR Camera and EF-S 18-55 mm ...             NaN
# 4    Sony Boîtier ILC plein format 7 II uniquement ...             NaN
# ..                                                 ...             ...
# 504     SAMTIAN 3960 Lux Bi-Color Photography Lighting             NaN
# 505  Lowepro Toploader Zoom 55 AW II Camera Case fo...             NaN
# 506  Neewer Extendable Camera Carbon Fiber Monopod ...             NaN
# 507  Neewer 18 Pieces Metal Camera Lens Filter Ring...             NaN
# 508  MOSHUSO Camera Mount Clamp with 360° Ballhead ...             NaN
#
#     product_tech_spec                                  product_addl_info  \
# ...
