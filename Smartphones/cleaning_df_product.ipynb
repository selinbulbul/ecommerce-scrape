# %%
import pandas as pd

# %%
df = pd.read_json("product_output.jsonl")

# %%
df
# Out:
#                                                    name product_summary  \
# 0                                                  None            None
# 1                                                  None            None
# 2     Rugged Smartphone, F150 Unlocked Phones 8000mA...            None
# 3                                                  None            None
# 4                                                  None            None
# ...                                                 ...             ...
# 2470                                               None            None
# 2471                                               None            None
# 2472                                               None            None
# 2473                                               None            None
# 2474                                               None            None
#
#      product_tech_spec product_addl_info seller seller_link  freq_bought  \
# ...

# %%
df = df.dropna(subset=['name'])

# %%
#df = df.reset_index()
#df

# %%
df
# Out:
#                                                    name  \
# 2     Rugged Smartphone, F150 Unlocked Phones 8000mA...
# 18    Find X2 Neo - Smartphone 256GB, 12GB RAM, Sing...
# 19    Gigaset GS4 Smartphone - Made in Germany - lei...
# 52    OUKITEL Dual-SIM Android10 Smartphone 6,4 Zoll...
# 55                                Bluetooth Speakers-23
# ...                                                 ...
# 2439  Topeak Bike Bags Handlebar Smartphone DryBag 5...
# 2442  Sony Mobile Communications Xperia E5 (f3311) B...
# 2453  Wireless Lavalier Microphone 2.4G Dual-Channel...
# 2454  Moto G9 Power 2021 XT2091, 4G LTE, Internation...
# 2466                            Huawei P8 titanium grau
#
#                                         product_summary  \
# 2                                                  None
# 18                                                 None
# 19                                                 None
# 52                                                 None
# ...

# %%
#df["price"]= pd.to_numeric(df["price"])

# %%
df.to_csv('smartphones_product.csv')

# %%
df.to_excel('smartphones_product.xlsx')

# %%
df.to_json('smartphones_product.jsonl')
