# %%
import pandas as pd

# %%
df_1 = pd.read_csv("DSLR_sample_cleaned.csv")

# %%
df_2 = pd.read_csv("headphones_sample_cleaned.csv")

# %%
df_3 = pd.read_csv("Keyboard_sample_cleaned.csv")

# %%
df_4 = pd.read_csv("Laptops_sample_cleaned.csv")

# %%
df_5 = pd.read_csv("Monitors_sample_cleaned.csv")

# %%
df_6 = pd.read_csv("Mouse_sample_cleaned.csv")

# %%
df_7 = pd.read_csv("Processors_sample_cleaned.csv")

# %%
df_8 = pd.read_csv("Smartphones_sample_cleaned.csv")

# %%
df = pd.concat([
	df_1, 
	df_2, 
	df_3,
	df_4,
	df_5,
	df_6,
	df_7,
	df_8,
])

# %%
df
# Out:
#       Unnamed: 0                                      product title  \
# 0              0  Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1              1  Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2              2  Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3              3  Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4              4  Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# ...          ...                                                ...
# 2171        2470  Xiaomi Redmi 9 smartphone + headphones (16.59 ...
# 2172        2471  Samsung Galaxy S20 FE, Android SIM Free Smartp...
# 2173        2472  Outdoor Mobile Phone, IIIF150 B2021 Outdoor Sm...
# 2174        2473               SPC 2350116N Apolo Senior 5 16GB 1GB
# 2175        2474  Ulefone Note 9P Smartphone Without Contract, A...
#
#                                                     url   rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  284.00
# ...

# %%
df["review_count"] = df["review_count"].replace({'.000':''}, regex = True)

# %%
df
# Out:
#       Unnamed: 0                                      product title  \
# 0              0  Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1              1  Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2              2  Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3              3  Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4              4  Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# ...          ...                                                ...
# 2045        2124        Urbanista San Francisco In-Ear Headset blau
# 2046        2125  Motorola Vervebuds, Wireless Bluetooth In-Ear ...
# 2047        2126  Moxking Earbuds with Mic and Volume Control, S...
# 2048        2127  Urbanista Paris True Wireless Headphones In-ea...
# 2049        2129  Amazon Basics - Over-ear headphones for childr...
#
#                                                     url   rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  284.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3983 entries, 0 to 2049
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     3983 non-null   int64
#  1   product title  3983 non-null   object
#  2   url            3983 non-null   object
#  3   rating         3983 non-null   object
#  4   price €        3983 non-null   object
#  5   review_count   3983 non-null   float64
#  6   product        3983 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 248.9+ KB

# %%
df["review_count"]= df["review_count"].astype(object)
df
# Out:
#       Unnamed: 0                                      product title  \
# 0              0  Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1              1  Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2              2  Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3              3  Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4              4  Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# ...          ...                                                ...
# 2045        2124        Urbanista San Francisco In-Ear Headset blau
# 2046        2125  Motorola Vervebuds, Wireless Bluetooth In-Ear ...
# 2047        2126  Moxking Earbuds with Mic and Volume Control, S...
# 2048        2127  Urbanista Paris True Wireless Headphones In-ea...
# 2049        2129  Amazon Basics - Over-ear headphones for childr...
#
#                                                     url   rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  284.00
# ...

# %%
df.drop(columns = "Unnamed: 0")
# Out:
#                                           product title  \
# 0     Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1     Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2     Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3     Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4     Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# ...                                                 ...
# 2045        Urbanista San Francisco In-Ear Headset blau
# 2046  Motorola Vervebuds, Wireless Bluetooth In-Ear ...
# 2047  Moxking Earbuds with Mic and Volume Control, S...
# 2048  Urbanista Paris True Wireless Headphones In-ea...
# 2049  Amazon Basics - Over-ear headphones for childr...
#
#                                                     url   rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  284.00
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  4.5 / 5  194.00
# ...

# %%
df.to_csv('Combined.csv')

# %%
df.to_excel('Combined.xlsx')
