# %%
import pandas as pd

# %%
df = pd.read_json("product_output.jsonl")

# %%
df
# Out:
#                                                    name product_summary  \
# 0                                                  None            None
# 1                                                  None            None
# 2                                                  None            None
# 3                                                  None            None
# 4                                                  None            None
# ...                                                 ...             ...
# 2125                                               None            None
# 2126  Moxking Wired Durable Metal Earphones Earbuds ...            None
# 2127                                               None            None
# 2128                                               None            None
# 2129                                               None            None
#
#      product_tech_spec                                  product_addl_info  \
# 0                 None                                               None
# 1                 None                                               None
# 2                 None                                               None
# 3                 None                                               None
# 4                 None                                               None
# ...                ...                                                ...
# 2125              None                                               None
# 2126              None  [{'info': 'Product Dimensions', 'value': '5.91...
# 2127              None                                               None
# 2128              None                                               None
# 2129              None                                               None
#
#        seller                                        seller_link freq_bought  \
# 0        None                                               None        None
# 1        None                                               None        None
# 2        None                                               None        None
# 3        None                                               None        None
# 4        None                                               None        None
# ...       ...                                                ...         ...
# 2125     None                                               None        None
# 2126  Joysico  https://www.amazon.com/gp/help/seller/at-a-gla...        None
# 2127     None                                               None        None
# 2128     None                                               None        None
# 2129     None                                               None        None
#
#      freq_bought_link                                link_to_all_reviews
# 0                None                                               None
# 1                None                                               None
# 2                None                                               None
# 3                None                                               None
# 4                None                                               None
# ...               ...                                                ...
# 2125             None                                               None
# 2126             None  /Moxking-Earphones-Microphone-Isolating-Headph...
# 2127             None                                               None
# 2128             None                                               None
# 2129             None                                               None
#
# [2130 rows x 9 columns]

# %%
df_1 = df[(df["name"] == "None")]
df_1
# Out:
# Empty DataFrame
# Columns: [name, product_summary, product_tech_spec, product_addl_info, seller, seller_link, freq_bought, freq_bought_link, link_to_all_reviews]
# Index: []

# %%
df
# Out:
#                                                    name product_summary  \
# 0                                                  None            None
# 1                                                  None            None
# 2                                                  None            None
# 3                                                  None            None
# 4                                                  None            None
# ...                                                 ...             ...
# 2125                                               None            None
# 2126  Moxking Wired Durable Metal Earphones Earbuds ...            None
# 2127                                               None            None
# 2128                                               None            None
# 2129                                               None            None
#
#      product_tech_spec                                  product_addl_info  \
# 0                 None                                               None
# 1                 None                                               None
# 2                 None                                               None
# 3                 None                                               None
# 4                 None                                               None
# ...                ...                                                ...
# 2125              None                                               None
# 2126              None  [{'info': 'Product Dimensions', 'value': '5.91...
# 2127              None                                               None
# 2128              None                                               None
# 2129              None                                               None
#
#        seller                                        seller_link freq_bought  \
# 0        None                                               None        None
# 1        None                                               None        None
# 2        None                                               None        None
# 3        None                                               None        None
# 4        None                                               None        None
# ...       ...                                                ...         ...
# 2125     None                                               None        None
# 2126  Joysico  https://www.amazon.com/gp/help/seller/at-a-gla...        None
# 2127     None                                               None        None
# 2128     None                                               None        None
# 2129     None                                               None        None
#
#      freq_bought_link                                link_to_all_reviews
# 0                None                                               None
# 1                None                                               None
# 2                None                                               None
# 3                None                                               None
# 4                None                                               None
# ...               ...                                                ...
# 2125             None                                               None
# 2126             None  /Moxking-Earphones-Microphone-Isolating-Headph...
# 2127             None                                               None
# 2128             None                                               None
# 2129             None                                               None
#
# [2130 rows x 9 columns]

# %%
df = df.dropna(subset=['name'])

# %%
#df = df.reset_index()
#df

# %%
df
# Out:
#                                                    name product_summary  \
# 5     Fone De Ouvido Intra Auricular Com Microfone J...            None
# 7     Sony WH-CH510 Wireless Bluetooth Headphones wi...            None
# 18    Bose QuietComfort 35 II Wireless Bluetooth Hea...            None
# 19    Marshall Major III Bluetooth Wireless On-Ear H...            None
# 23    AfterShokz OpenMove Wireless Bone Conduction O...            None
# ...                                                 ...             ...
# 2105  Bluetooth Headphones, OneOdio A11 Wireless Ove...            None
# 2111  HUAWEI AM115 3.5mm 3PACK Handsfree Earphones P...            None
# 2123                               JVC HA-KD 5 V Violet            None
# 2124  Urbanista San Francisco ErgonoMic Earphones wi...            None
# 2126  Moxking Wired Durable Metal Earphones Earbuds ...            None
#
#      product_tech_spec                                  product_addl_info  \
# 5                 None  [{'info': 'Product Dimensions', 'value': '6.69...
# 7                 None  [{'info': 'Product Dimensions', 'value': '2.76...
# 18                None  [{'info': 'Product Dimensions', 'value': '3.2 ...
# 19                None  [{'info': 'Product Dimensions', 'value': '6.3 ...
# 23                None  [{'info': 'Product Dimensions', 'value': '4.76...
# ...                ...                                                ...
# 2105              None  [{'info': 'Product Dimensions', 'value': '7.87...
# 2111              None  [{'info': 'Product Dimensions', 'value': '2.28...
# 2123              None  [{'info': 'Item Weight', 'value': '4.3 ounces'...
# 2124              None  [{'info': 'Product Dimensions', 'value': '1.96...
# 2126              None  [{'info': 'Product Dimensions', 'value': '5.91...
#
#               seller                                        seller_link  \
# 5       Sith Company  https://www.amazon.com/gp/help/seller/at-a-gla...
# 7               None                                               None
# 18              None                                               None
# 19    Z's Essentials  https://www.amazon.com/gp/help/seller/at-a-gla...
# 23              None                                               None
# ...              ...                                                ...
# 2105          DIRONE  https://www.amazon.com/gp/help/seller/at-a-gla...
# 2111            None                                               None
# 2123            None                                               None
# 2124            None                                               None
# 2126         Joysico  https://www.amazon.com/gp/help/seller/at-a-gla...
#
#      freq_bought freq_bought_link  \
# 5           None             None
# 7           None             None
# 18          None             None
# 19          None             None
# 23          None             None
# ...          ...              ...
# 2105        None             None
# 2111        None             None
# 2123        None             None
# 2124        None             None
# 2126        None             None
#
#                                     link_to_all_reviews
# 5                                                  None
# 7     /Sony-Bluetooth-Headphones-Hands-Free-Assistan...
# 18    /Bose-QuietComfort-Wireless-Headphones-Cancell...
# 19    /Marshall-Major-Bluetooth-Wireless-Headphone/p...
# 23    /AfterShokz-OpenMove-Conduction-Bluetooth-Head...
# ...                                                 ...
# 2105  /Bluetooth-Headphones-Microphone-Compatible-Co...
# 2111  /HUAWEI-AM115-3-5mm-Handsfree-Earphones/produc...
# 2123                                               None
# 2124  /Urbanista-Francisco-ErgonoMic-Earphones-Remot...
# 2126  /Moxking-Earphones-Microphone-Isolating-Headph...
#
# [456 rows x 9 columns]

# %%
#df["price"]= pd.to_numeric(df["price"])

# %%
df.to_csv('Headphones_product.csv')

# %%
df.to_excel('Headphones_product.xlsx')

# %%
df.to_json('Headphones_product.jsonl')
