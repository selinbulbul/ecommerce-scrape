# %%
import pandas as pd

# %%
df = pd.read_json("search_output.jsonl")

# %% [markdown]
# # PRICE

# %%
df.head()
# Out:
#                                                title  \
# 0  J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1  Logitech K835 Wired Mechanical TKL aluminum ke...
# 2  PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3  Microsoft Wired Keyboard 600 - German - black ...
# 4  Logitech K280e Pro Wired Business Keyboard for...
#
#                                                  url              rating  \
# 0  https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 out of 5 stars
# 1  https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 out of 5 stars
# 2  https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 out of 5 stars
# 3  https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 out of 5 stars
# 4  https://www.amazon.com/-/en/Logitech-Business-...  4.5 out of 5 stars
#
#   review_count   price
# 0          462  €37.99
# 1          861  €57.99
# 2            3  €22.99
# 3        1,631   €8.99
# 4        4,869  €23.79

# %%
df = df.dropna()
df.head()
# Out:
#                                                title  \
# 0  J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1  Logitech K835 Wired Mechanical TKL aluminum ke...
# 2  PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3  Microsoft Wired Keyboard 600 - German - black ...
# 4  Logitech K280e Pro Wired Business Keyboard for...
#
#                                                  url              rating  \
# 0  https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 out of 5 stars
# 1  https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 out of 5 stars
# 2  https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 out of 5 stars
# 3  https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 out of 5 stars
# 4  https://www.amazon.com/-/en/Logitech-Business-...  4.5 out of 5 stars
#
#   review_count   price
# 0          462  €37.99
# 1          861  €57.99
# 2            3  €22.99
# 3        1,631   €8.99
# 4        4,869  €23.79

# %%
df["price"] = df["price"].replace({'\€':''}, regex = True)
df.head(20)
# Out:
#                                                 title  \
# 0   J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1   Logitech K835 Wired Mechanical TKL aluminum ke...
# 2   PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3   Microsoft Wired Keyboard 600 - German - black ...
# 4   Logitech K280e Pro Wired Business Keyboard for...
# 6   Logitech K835 Wired Mechanical TKL aluminum ke...
# 7   CHERRY KC 6000 Slim USB QWERTZ German Black - ...
# 8   Logitech MX Keys Wireless Keyboard, Bluetooth ...
# 9   EZONTEQ Ergonomic Gaming Keyboard RGB LED Ligh...
# 10  Rii RK907 Keyboard USB, Wired Keyboard PC, Bus...
# 11  Mechanical Gaming Keyboard with 20 RGB Modes L...
# 12  WisFox Keyboard Mouse Set Wireless 2.4 GHz Ful...
# 13  WisFox Wireless Keyboard Mouse 2.4GHz Ultra Th...
# 14  Seenda Wireless Keyboard Illuminated with Whit...
# 15  Sharkoon Gaming Keyboard (German keyboard layout)
# 16   Rii Mini Wireless Keyboard with Touchpad (I8+X8)
# 17     CHERRY TAS STREAM KEYBOARD Black German Layout
# 18  Energy Sistem Gaming Keyboard ESG K2 Ghosthunt...
# 19  Corsair K55 Gaming Keyboard [English Layout no...
# 20  Logitech K400 Plus Touch Wireless Keyboard Bla...
#
#                                                   url              rating  \
# 0   https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 out of 5 stars
# 1   https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 out of 5 stars
# 2   https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 out of 5 stars
# 3   https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 out of 5 stars
# 4   https://www.amazon.com/-/en/Logitech-Business-...  4.5 out of 5 stars
# 6   https://www.amazon.com/-/en/Logitech-Wired-Mec...  4.6 out of 5 stars
# 7   https://www.amazon.com/-/en/CHERRY-6000-QWERTZ...  4.5 out of 5 stars
# 8   https://www.amazon.com/-/en/Logitech-Wireless-...  4.8 out of 5 stars
# 9   https://www.amazon.com/-/en/Ergonomic-Keyboard...  4.5 out of 5 stars
# 10  https://www.amazon.com/-/en/Keyboard-Business-...  4.0 out of 5 stars
# 11  https://www.amazon.com/-/en/Mechanical-Keyboar...  4.3 out of 5 stars
# 12  https://www.amazon.com/-/en/gp/slredirect/pica...  4.5 out of 5 stars
# 13  https://www.amazon.com/-/en/gp/slredirect/pica...  4.4 out of 5 stars
# 14  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 out of 5 stars
# 15  https://www.amazon.com/-/en/Sharkoon-Gaming-Ke...  4.5 out of 5 stars
# 16  https://www.amazon.com/-/en/Rii-Mini-Wireless-...  4.3 out of 5 stars
# 17  https://www.amazon.com/-/en/CHERRY-STREAM-KEYB...  4.4 out of 5 stars
# 18  https://www.amazon.com/-/en/Gaming-Keyboard-ES...  3.8 out of 5 stars
# 19  https://www.amazon.com/-/en/Corsair-Gaming-Key...  4.5 out of 5 stars
# 20  https://www.amazon.com/-/en/Logitech-Wireless-...  4.5 out of 5 stars
#
#    review_count   price
# 0           462   37.99
# 1           861   57.99
# 2             3   22.99
# 3         1,631    8.99
# 4         4,869   23.79
# 6           861   57.99
# 7           924   31.99
# 8         4,336   79.95
# 9           715   32.99
# 10          802   11.89
# 11           78   35.15
# 12            7   20.39
# 13          722   20.39
# 14            1   35.99
# 15       10,089   29.87
# 16        2,153   12.74
# 17          555   20.99
# 18           44   19.90
# 19          454  119.00
# 20        6,153   30.99

# %%
df["price"] = df["price"].replace({',':'.'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1   Logitech K835 Wired Mechanical TKL aluminum ke...
# 2   PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3   Microsoft Wired Keyboard 600 - German - black ...
# 4   Logitech K280e Pro Wired Business Keyboard for...
# 6   Logitech K835 Wired Mechanical TKL aluminum ke...
# 7   CHERRY KC 6000 Slim USB QWERTZ German Black - ...
# 8   Logitech MX Keys Wireless Keyboard, Bluetooth ...
# 9   EZONTEQ Ergonomic Gaming Keyboard RGB LED Ligh...
# 10  Rii RK907 Keyboard USB, Wired Keyboard PC, Bus...
# 11  Mechanical Gaming Keyboard with 20 RGB Modes L...
# 12  WisFox Keyboard Mouse Set Wireless 2.4 GHz Ful...
# 13  WisFox Wireless Keyboard Mouse 2.4GHz Ultra Th...
# 14  Seenda Wireless Keyboard Illuminated with Whit...
# 15  Sharkoon Gaming Keyboard (German keyboard layout)
#
#                                                   url              rating  \
# 0   https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 out of 5 stars
# 1   https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 out of 5 stars
# 2   https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 out of 5 stars
# 3   https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 out of 5 stars
# 4   https://www.amazon.com/-/en/Logitech-Business-...  4.5 out of 5 stars
# 6   https://www.amazon.com/-/en/Logitech-Wired-Mec...  4.6 out of 5 stars
# 7   https://www.amazon.com/-/en/CHERRY-6000-QWERTZ...  4.5 out of 5 stars
# 8   https://www.amazon.com/-/en/Logitech-Wireless-...  4.8 out of 5 stars
# 9   https://www.amazon.com/-/en/Ergonomic-Keyboard...  4.5 out of 5 stars
# 10  https://www.amazon.com/-/en/Keyboard-Business-...  4.0 out of 5 stars
# 11  https://www.amazon.com/-/en/Mechanical-Keyboar...  4.3 out of 5 stars
# 12  https://www.amazon.com/-/en/gp/slredirect/pica...  4.5 out of 5 stars
# 13  https://www.amazon.com/-/en/gp/slredirect/pica...  4.4 out of 5 stars
# 14  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 out of 5 stars
# 15  https://www.amazon.com/-/en/Sharkoon-Gaming-Ke...  4.5 out of 5 stars
#
#    review_count  price
# 0           462  37.99
# 1           861  57.99
# 2             3  22.99
# 3         1,631   8.99
# 4         4,869  23.79
# 6           861  57.99
# 7           924  31.99
# 8         4,336  79.95
# 9           715  32.99
# 10          802  11.89
# 11           78  35.15
# 12            7  20.39
# 13          722  20.39
# 14            1  35.99
# 15       10,089  29.87

# %%
df["rating"] = df["rating"].replace({'von 5 Sternen':'/ 5'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1   Logitech K835 Wired Mechanical TKL aluminum ke...
# 2   PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3   Microsoft Wired Keyboard 600 - German - black ...
# 4   Logitech K280e Pro Wired Business Keyboard for...
# 6   Logitech K835 Wired Mechanical TKL aluminum ke...
# 7   CHERRY KC 6000 Slim USB QWERTZ German Black - ...
# 8   Logitech MX Keys Wireless Keyboard, Bluetooth ...
# 9   EZONTEQ Ergonomic Gaming Keyboard RGB LED Ligh...
# 10  Rii RK907 Keyboard USB, Wired Keyboard PC, Bus...
# 11  Mechanical Gaming Keyboard with 20 RGB Modes L...
# 12  WisFox Keyboard Mouse Set Wireless 2.4 GHz Ful...
# 13  WisFox Wireless Keyboard Mouse 2.4GHz Ultra Th...
# 14  Seenda Wireless Keyboard Illuminated with Whit...
# 15  Sharkoon Gaming Keyboard (German keyboard layout)
#
#                                                   url              rating  \
# 0   https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 out of 5 stars
# 1   https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 out of 5 stars
# 2   https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 out of 5 stars
# 3   https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 out of 5 stars
# 4   https://www.amazon.com/-/en/Logitech-Business-...  4.5 out of 5 stars
# 6   https://www.amazon.com/-/en/Logitech-Wired-Mec...  4.6 out of 5 stars
# 7   https://www.amazon.com/-/en/CHERRY-6000-QWERTZ...  4.5 out of 5 stars
# 8   https://www.amazon.com/-/en/Logitech-Wireless-...  4.8 out of 5 stars
# 9   https://www.amazon.com/-/en/Ergonomic-Keyboard...  4.5 out of 5 stars
# 10  https://www.amazon.com/-/en/Keyboard-Business-...  4.0 out of 5 stars
# 11  https://www.amazon.com/-/en/Mechanical-Keyboar...  4.3 out of 5 stars
# 12  https://www.amazon.com/-/en/gp/slredirect/pica...  4.5 out of 5 stars
# 13  https://www.amazon.com/-/en/gp/slredirect/pica...  4.4 out of 5 stars
# 14  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 out of 5 stars
# 15  https://www.amazon.com/-/en/Sharkoon-Gaming-Ke...  4.5 out of 5 stars
#
#    review_count  price
# 0           462  37.99
# 1           861  57.99
# 2             3  22.99
# 3         1,631   8.99
# 4         4,869  23.79
# 6           861  57.99
# 7           924  31.99
# 8         4,336  79.95
# 9           715  32.99
# 10          802  11.89
# 11           78  35.15
# 12            7  20.39
# 13          722  20.39
# 14            1  35.99
# 15       10,089  29.87

# %%
df["rating"] = df["rating"].replace({'out of 5 stars':'/ 5'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1   Logitech K835 Wired Mechanical TKL aluminum ke...
# 2   PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3   Microsoft Wired Keyboard 600 - German - black ...
# 4   Logitech K280e Pro Wired Business Keyboard for...
# 6   Logitech K835 Wired Mechanical TKL aluminum ke...
# 7   CHERRY KC 6000 Slim USB QWERTZ German Black - ...
# 8   Logitech MX Keys Wireless Keyboard, Bluetooth ...
# 9   EZONTEQ Ergonomic Gaming Keyboard RGB LED Ligh...
# 10  Rii RK907 Keyboard USB, Wired Keyboard PC, Bus...
# 11  Mechanical Gaming Keyboard with 20 RGB Modes L...
# 12  WisFox Keyboard Mouse Set Wireless 2.4 GHz Ful...
# 13  WisFox Wireless Keyboard Mouse 2.4GHz Ultra Th...
# 14  Seenda Wireless Keyboard Illuminated with Whit...
# 15  Sharkoon Gaming Keyboard (German keyboard layout)
#
#                                                   url   rating review_count  \
# 0   https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5          462
# 1   https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5          861
# 2   https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5            3
# 3   https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 / 5        1,631
# 4   https://www.amazon.com/-/en/Logitech-Business-...  4.5 / 5        4,869
# 6   https://www.amazon.com/-/en/Logitech-Wired-Mec...  4.6 / 5          861
# 7   https://www.amazon.com/-/en/CHERRY-6000-QWERTZ...  4.5 / 5          924
# 8   https://www.amazon.com/-/en/Logitech-Wireless-...  4.8 / 5        4,336
# 9   https://www.amazon.com/-/en/Ergonomic-Keyboard...  4.5 / 5          715
# 10  https://www.amazon.com/-/en/Keyboard-Business-...  4.0 / 5          802
# 11  https://www.amazon.com/-/en/Mechanical-Keyboar...  4.3 / 5           78
# 12  https://www.amazon.com/-/en/gp/slredirect/pica...  4.5 / 5            7
# 13  https://www.amazon.com/-/en/gp/slredirect/pica...  4.4 / 5          722
# 14  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5            1
# 15  https://www.amazon.com/-/en/Sharkoon-Gaming-Ke...  4.5 / 5       10,089
#
#     price
# 0   37.99
# 1   57.99
# 2   22.99
# 3    8.99
# 4   23.79
# 6   57.99
# 7   31.99
# 8   79.95
# 9   32.99
# 10  11.89
# 11  35.15
# 12  20.39
# 13  20.39
# 14  35.99
# 15  29.87

# %%
df["rating"] = df["rating"].replace({',':'.'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1   Logitech K835 Wired Mechanical TKL aluminum ke...
# 2   PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3   Microsoft Wired Keyboard 600 - German - black ...
# 4   Logitech K280e Pro Wired Business Keyboard for...
# 6   Logitech K835 Wired Mechanical TKL aluminum ke...
# 7   CHERRY KC 6000 Slim USB QWERTZ German Black - ...
# 8   Logitech MX Keys Wireless Keyboard, Bluetooth ...
# 9   EZONTEQ Ergonomic Gaming Keyboard RGB LED Ligh...
# 10  Rii RK907 Keyboard USB, Wired Keyboard PC, Bus...
# 11  Mechanical Gaming Keyboard with 20 RGB Modes L...
# 12  WisFox Keyboard Mouse Set Wireless 2.4 GHz Ful...
# 13  WisFox Wireless Keyboard Mouse 2.4GHz Ultra Th...
# 14  Seenda Wireless Keyboard Illuminated with Whit...
# 15  Sharkoon Gaming Keyboard (German keyboard layout)
#
#                                                   url   rating review_count  \
# 0   https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5          462
# 1   https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5          861
# 2   https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5            3
# 3   https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 / 5        1,631
# 4   https://www.amazon.com/-/en/Logitech-Business-...  4.5 / 5        4,869
# 6   https://www.amazon.com/-/en/Logitech-Wired-Mec...  4.6 / 5          861
# 7   https://www.amazon.com/-/en/CHERRY-6000-QWERTZ...  4.5 / 5          924
# 8   https://www.amazon.com/-/en/Logitech-Wireless-...  4.8 / 5        4,336
# 9   https://www.amazon.com/-/en/Ergonomic-Keyboard...  4.5 / 5          715
# 10  https://www.amazon.com/-/en/Keyboard-Business-...  4.0 / 5          802
# 11  https://www.amazon.com/-/en/Mechanical-Keyboar...  4.3 / 5           78
# 12  https://www.amazon.com/-/en/gp/slredirect/pica...  4.5 / 5            7
# 13  https://www.amazon.com/-/en/gp/slredirect/pica...  4.4 / 5          722
# 14  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5            1
# 15  https://www.amazon.com/-/en/Sharkoon-Gaming-Ke...  4.5 / 5       10,089
#
#     price
# 0   37.99
# 1   57.99
# 2   22.99
# 3    8.99
# 4   23.79
# 6   57.99
# 7   31.99
# 8   79.95
# 9   32.99
# 10  11.89
# 11  35.15
# 12  20.39
# 13  20.39
# 14  35.99
# 15  29.87

# %%
### additional split function  df.price[0].split('$')[1] , df.rating[0].split(' ')[0] , https://pandas.pydata.org/docs/reference/api/pandas.Series.str.split.html

# %%
df_rc = df["review_count"].apply(lambda x: x.replace(',','.') )
display (df_rc)
df_rc_2 = pd.DataFrame(df_rc)
# Out:
# 0         462
# 1         861
# 2           3
# 3       1.631
# 4       4.869
#         ...
# 1612      181
# 1613      612
# 1614        1
# 1615        7
# 1616       14
# Name: review_count, Length: 1500, dtype: object

# %%
df_rc_2
# Out:
#      review_count
# 0             462
# 1             861
# 2               3
# 3           1.631
# 4           4.869
# ...           ...
# 1612          181
# 1613          612
# 1614            1
# 1615            7
# 1616           14
#
# [1500 rows x 1 columns]

# %%
df = df.drop(columns= "review_count")

# %%
df
# Out:
#                                                   title  \
# 0     J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1     Logitech K835 Wired Mechanical TKL aluminum ke...
# 2     PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3     Microsoft Wired Keyboard 600 - German - black ...
# 4     Logitech K280e Pro Wired Business Keyboard for...
# ...                                                 ...
# 1612  ENHANCE Galaxy Gaming Keyboard Wrist Rest Pad ...
# 1613  MoKo Universal Foldable Keyboard, Ultra Thin P...
# 1614  Fintie Keyboard Case for Lenovo Tab P11 11 Inc...
# 1615  WisFox Keyboard Mouse Set Wireless 2.4 GHz Ful...
# 1616  HUAWEI Display 23.8 inches, 60 cm (23.8 inches...
#
#                                                     url   rating   price
# 0     https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5   37.99
# 1     https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   57.99
# 2     https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   22.99
# 3     https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 / 5    8.99
# 4     https://www.amazon.com/-/en/Logitech-Business-...  4.5 / 5   23.79
# ...                                                 ...      ...     ...
# 1612  https://www.amazon.com/-/en/Keyboard-Keyboards...  4.5 / 5   24.99
# 1613  https://www.amazon.com/-/en/Universal-Recharge...  4.4 / 5   23.97
# 1614  https://www.amazon.com/-/en/Keyboard-Protectiv...  4.0 / 5   44.99
# 1615  https://www.amazon.com/-/en/gp/slredirect/pica...  4.5 / 5   20.39
# 1616  https://www.amazon.com/-/en/gp/slredirect/pica...  4.7 / 5  129.00
#
# [1500 rows x 4 columns]

# %%
f_column = df_rc_2 ["review_count"]
df = pd.concat([df,f_column], axis = 1)
df
# Out:
#                                                   title  \
# 0     J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1     Logitech K835 Wired Mechanical TKL aluminum ke...
# 2     PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3     Microsoft Wired Keyboard 600 - German - black ...
# 4     Logitech K280e Pro Wired Business Keyboard for...
# ...                                                 ...
# 1612  ENHANCE Galaxy Gaming Keyboard Wrist Rest Pad ...
# 1613  MoKo Universal Foldable Keyboard, Ultra Thin P...
# 1614  Fintie Keyboard Case for Lenovo Tab P11 11 Inc...
# 1615  WisFox Keyboard Mouse Set Wireless 2.4 GHz Ful...
# 1616  HUAWEI Display 23.8 inches, 60 cm (23.8 inches...
#
#                                                     url   rating   price  \
# 0     https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5   37.99
# 1     https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   57.99
# 2     https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   22.99
# 3     https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 / 5    8.99
# 4     https://www.amazon.com/-/en/Logitech-Business-...  4.5 / 5   23.79
# ...                                                 ...      ...     ...
# 1612  https://www.amazon.com/-/en/Keyboard-Keyboards...  4.5 / 5   24.99
# 1613  https://www.amazon.com/-/en/Universal-Recharge...  4.4 / 5   23.97
# 1614  https://www.amazon.com/-/en/Keyboard-Protectiv...  4.0 / 5   44.99
# 1615  https://www.amazon.com/-/en/gp/slredirect/pica...  4.5 / 5   20.39
# 1616  https://www.amazon.com/-/en/gp/slredirect/pica...  4.7 / 5  129.00
#
#      review_count
# 0             462
# 1             861
# 2               3
# 3           1.631
# 4           4.869
# ...           ...
# 1612          181
# 1613          612
# 1614            1
# 1615            7
# 1616           14
#
# [1500 rows x 5 columns]

# %%
df = df.rename(columns = {"price":"price €"})
df
# Out:
#                                                   title  \
# 0     J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1     Logitech K835 Wired Mechanical TKL aluminum ke...
# 2     PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3     Microsoft Wired Keyboard 600 - German - black ...
# 4     Logitech K280e Pro Wired Business Keyboard for...
# ...                                                 ...
# 1612  ENHANCE Galaxy Gaming Keyboard Wrist Rest Pad ...
# 1613  MoKo Universal Foldable Keyboard, Ultra Thin P...
# 1614  Fintie Keyboard Case for Lenovo Tab P11 11 Inc...
# 1615  WisFox Keyboard Mouse Set Wireless 2.4 GHz Ful...
# 1616  HUAWEI Display 23.8 inches, 60 cm (23.8 inches...
#
#                                                     url   rating price €  \
# 0     https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5   37.99
# 1     https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   57.99
# 2     https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   22.99
# 3     https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 / 5    8.99
# 4     https://www.amazon.com/-/en/Logitech-Business-...  4.5 / 5   23.79
# ...                                                 ...      ...     ...
# 1612  https://www.amazon.com/-/en/Keyboard-Keyboards...  4.5 / 5   24.99
# 1613  https://www.amazon.com/-/en/Universal-Recharge...  4.4 / 5   23.97
# 1614  https://www.amazon.com/-/en/Keyboard-Protectiv...  4.0 / 5   44.99
# 1615  https://www.amazon.com/-/en/gp/slredirect/pica...  4.5 / 5   20.39
# 1616  https://www.amazon.com/-/en/gp/slredirect/pica...  4.7 / 5  129.00
#
#      review_count
# 0             462
# 1             861
# 2               3
# 3           1.631
# 4           4.869
# ...           ...
# 1612          181
# 1613          612
# 1614            1
# 1615            7
# 1616           14
#
# [1500 rows x 5 columns]

# %%
df = df.rename(columns = {"title":"product title"})
df
# Out:
#                                           product title  \
# 0     J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1     Logitech K835 Wired Mechanical TKL aluminum ke...
# 2     PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3     Microsoft Wired Keyboard 600 - German - black ...
# 4     Logitech K280e Pro Wired Business Keyboard for...
# ...                                                 ...
# 1612  ENHANCE Galaxy Gaming Keyboard Wrist Rest Pad ...
# 1613  MoKo Universal Foldable Keyboard, Ultra Thin P...
# 1614  Fintie Keyboard Case for Lenovo Tab P11 11 Inc...
# 1615  WisFox Keyboard Mouse Set Wireless 2.4 GHz Ful...
# 1616  HUAWEI Display 23.8 inches, 60 cm (23.8 inches...
#
#                                                     url   rating price €  \
# 0     https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5   37.99
# 1     https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   57.99
# 2     https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   22.99
# 3     https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 / 5    8.99
# 4     https://www.amazon.com/-/en/Logitech-Business-...  4.5 / 5   23.79
# ...                                                 ...      ...     ...
# 1612  https://www.amazon.com/-/en/Keyboard-Keyboards...  4.5 / 5   24.99
# 1613  https://www.amazon.com/-/en/Universal-Recharge...  4.4 / 5   23.97
# 1614  https://www.amazon.com/-/en/Keyboard-Protectiv...  4.0 / 5   44.99
# 1615  https://www.amazon.com/-/en/gp/slredirect/pica...  4.5 / 5   20.39
# 1616  https://www.amazon.com/-/en/gp/slredirect/pica...  4.7 / 5  129.00
#
#      review_count
# 0             462
# 1             861
# 2               3
# 3           1.631
# 4           4.869
# ...           ...
# 1612          181
# 1613          612
# 1614            1
# 1615            7
# 1616           14
#
# [1500 rows x 5 columns]

# %%
df.loc[:, 'product'] = 'Keyboard'

df.head(15)
# Out:
#                                         product title  \
# 0   J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1   Logitech K835 Wired Mechanical TKL aluminum ke...
# 2   PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3   Microsoft Wired Keyboard 600 - German - black ...
# 4   Logitech K280e Pro Wired Business Keyboard for...
# 6   Logitech K835 Wired Mechanical TKL aluminum ke...
# 7   CHERRY KC 6000 Slim USB QWERTZ German Black - ...
# 8   Logitech MX Keys Wireless Keyboard, Bluetooth ...
# 9   EZONTEQ Ergonomic Gaming Keyboard RGB LED Ligh...
# 10  Rii RK907 Keyboard USB, Wired Keyboard PC, Bus...
# 11  Mechanical Gaming Keyboard with 20 RGB Modes L...
# 12  WisFox Keyboard Mouse Set Wireless 2.4 GHz Ful...
# 13  WisFox Wireless Keyboard Mouse 2.4GHz Ultra Th...
# 14  Seenda Wireless Keyboard Illuminated with Whit...
# 15  Sharkoon Gaming Keyboard (German keyboard layout)
#
#                                                   url   rating price €  \
# 0   https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5   37.99
# 1   https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   57.99
# 2   https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   22.99
# 3   https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 / 5    8.99
# 4   https://www.amazon.com/-/en/Logitech-Business-...  4.5 / 5   23.79
# 6   https://www.amazon.com/-/en/Logitech-Wired-Mec...  4.6 / 5   57.99
# 7   https://www.amazon.com/-/en/CHERRY-6000-QWERTZ...  4.5 / 5   31.99
# 8   https://www.amazon.com/-/en/Logitech-Wireless-...  4.8 / 5   79.95
# 9   https://www.amazon.com/-/en/Ergonomic-Keyboard...  4.5 / 5   32.99
# 10  https://www.amazon.com/-/en/Keyboard-Business-...  4.0 / 5   11.89
# 11  https://www.amazon.com/-/en/Mechanical-Keyboar...  4.3 / 5   35.15
# 12  https://www.amazon.com/-/en/gp/slredirect/pica...  4.5 / 5   20.39
# 13  https://www.amazon.com/-/en/gp/slredirect/pica...  4.4 / 5   20.39
# 14  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5   35.99
# 15  https://www.amazon.com/-/en/Sharkoon-Gaming-Ke...  4.5 / 5   29.87
#
#    review_count   product
# 0           462  Keyboard
# 1           861  Keyboard
# 2             3  Keyboard
# 3         1.631  Keyboard
# 4         4.869  Keyboard
# 6           861  Keyboard
# 7           924  Keyboard
# 8         4.336  Keyboard
# 9           715  Keyboard
# 10          802  Keyboard
# 11           78  Keyboard
# 12            7  Keyboard
# 13          722  Keyboard
# 14            1  Keyboard
# 15       10.089  Keyboard

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1500 entries, 0 to 1616
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product title  1500 non-null   object
#  1   url            1500 non-null   object
#  2   rating         1500 non-null   object
#  3   price €        1500 non-null   object
#  4   review_count   1500 non-null   object
#  5   product        1500 non-null   object
# dtypes: object(6)
# memory usage: 82.0+ KB

# %%
#df["price"]= pd.to_numeric(df["price"])

# %%
df.to_csv('Keyboard_sample_cleaned.csv')

# %%
df.to_excel('Keyboard_sample_cleaned.xlsx')

# %%
df
# Out:
#                                           product title  \
# 0     J JOYACCESS Wireless Keyboard with Mouse, Keyb...
# 1     Logitech K835 Wired Mechanical TKL aluminum ke...
# 2     PONVIT Keyboard Mouse Set Wireless 2.4G Wirele...
# 3     Microsoft Wired Keyboard 600 - German - black ...
# 4     Logitech K280e Pro Wired Business Keyboard for...
# ...                                                 ...
# 1612  ENHANCE Galaxy Gaming Keyboard Wrist Rest Pad ...
# 1613  MoKo Universal Foldable Keyboard, Ultra Thin P...
# 1614  Fintie Keyboard Case for Lenovo Tab P11 11 Inc...
# 1615  WisFox Keyboard Mouse Set Wireless 2.4 GHz Ful...
# 1616  HUAWEI Display 23.8 inches, 60 cm (23.8 inches...
#
#                                                     url   rating price €  \
# 0     https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5   37.99
# 1     https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   57.99
# 2     https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5   22.99
# 3     https://www.amazon.com/-/en/Microsoft-Wired-Ke...  4.6 / 5    8.99
# 4     https://www.amazon.com/-/en/Logitech-Business-...  4.5 / 5   23.79
# ...                                                 ...      ...     ...
# 1612  https://www.amazon.com/-/en/Keyboard-Keyboards...  4.5 / 5   24.99
# 1613  https://www.amazon.com/-/en/Universal-Recharge...  4.4 / 5   23.97
# 1614  https://www.amazon.com/-/en/Keyboard-Protectiv...  4.0 / 5   44.99
# 1615  https://www.amazon.com/-/en/gp/slredirect/pica...  4.5 / 5   20.39
# 1616  https://www.amazon.com/-/en/gp/slredirect/pica...  4.7 / 5  129.00
#
#      review_count   product
# 0             462  Keyboard
# 1             861  Keyboard
# 2               3  Keyboard
# 3           1.631  Keyboard
# 4           4.869  Keyboard
# ...           ...       ...
# 1612          181  Keyboard
# 1613          612  Keyboard
# 1614            1  Keyboard
# 1615            7  Keyboard
# 1616           14  Keyboard
#
# [1500 rows x 6 columns]
