# %%
import pandas as pd

# %%
df = pd.read_json("product_output.jsonl")

# %%
df
# Out:
#                                                    name product_summary  \
# 0                                                  None            None
# 1                                                  None            None
# 2                                                  None            None
# 3     Microsoft Keyboard 600 Black, German layout, A...            None
# 4                                                  None            None
# ...                                                 ...             ...
# 1612                                               None            None
# 1613  MoKo Wireless Bluetooth Keyboard, Ultra-Thin F...            None
# 1614                                               None            None
# 1615                                               None            None
# 1616                                               None            None
#
#                                       product_tech_spec  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 1612                                               None
# 1613  [{'info': 'Brand', 'value': '‎MoKo'}, {'info':...
# 1614                                               None
# 1615                                               None
# 1616                                               None
#
#                                       product_addl_info seller seller_link  \
# 0                                                  None   None        None
# 1                                                  None   None        None
# 2                                                  None   None        None
# 3     [{'info': 'Product Dimensions', 'value': '18.7...   None        None
# 4                                                  None   None        None
# ...                                                 ...    ...         ...
# 1612                                               None   None        None
# 1613  [{'info': 'Customer Reviews', 'value': '/*
# * F...   None        None
# 1614                                               None   None        None
# 1615                                               None   None        None
# 1616                                               None   None        None
#
#       freq_bought  freq_bought_link  \
# 0             NaN               NaN
# 1             NaN               NaN
# 2             NaN               NaN
# 3             NaN               NaN
# 4             NaN               NaN
# ...           ...               ...
# 1612          NaN               NaN
# 1613          NaN               NaN
# 1614          NaN               NaN
# 1615          NaN               NaN
# 1616          NaN               NaN
#
#                                     link_to_all_reviews
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3     /Microsoft-Keyboard-German-layout-ANB-00008/pr...
# 4                                                  None
# ...                                                 ...
# 1612                                               None
# 1613  /MoKo-Ultra-Thin-Rechargeable-Compatible-Smart...
# 1614                                               None
# 1615                                               None
# 1616                                               None
#
# [1617 rows x 9 columns]

# %%
df_1 = df[(df["name"] == "None")]
df_1
# Out:
# Empty DataFrame
# Columns: [name, product_summary, product_tech_spec, product_addl_info, seller, seller_link, freq_bought, freq_bought_link, link_to_all_reviews]
# Index: []

# %%
df
# Out:
#                                                    name product_summary  \
# 0                                                  None            None
# 1                                                  None            None
# 2                                                  None            None
# 3                                                  None            None
# 4                                                  None            None
# ...                                                 ...             ...
# 2125                                               None            None
# 2126  Moxking Wired Durable Metal Earphones Earbuds ...            None
# 2127                                               None            None
# 2128                                               None            None
# 2129                                               None            None
#
#      product_tech_spec                                  product_addl_info  \
# 0                 None                                               None
# 1                 None                                               None
# 2                 None                                               None
# 3                 None                                               None
# 4                 None                                               None
# ...                ...                                                ...
# 2125              None                                               None
# 2126              None  [{'info': 'Product Dimensions', 'value': '5.91...
# 2127              None                                               None
# 2128              None                                               None
# 2129              None                                               None
#
#        seller                                        seller_link freq_bought  \
# 0        None                                               None        None
# 1        None                                               None        None
# 2        None                                               None        None
# 3        None                                               None        None
# 4        None                                               None        None
# ...       ...                                                ...         ...
# 2125     None                                               None        None
# 2126  Joysico  https://www.amazon.com/gp/help/seller/at-a-gla...        None
# 2127     None                                               None        None
# 2128     None                                               None        None
# 2129     None                                               None        None
#
#      freq_bought_link                                link_to_all_reviews
# 0                None                                               None
# 1                None                                               None
# 2                None                                               None
# 3                None                                               None
# 4                None                                               None
# ...               ...                                                ...
# 2125             None                                               None
# 2126             None  /Moxking-Earphones-Microphone-Isolating-Headph...
# 2127             None                                               None
# 2128             None                                               None
# 2129             None                                               None
#
# [2130 rows x 9 columns]

# %%
df = df.dropna(subset=['name'])

# %%
#df = df.reset_index()
#df

# %%
df
# Out:
#                                                    name product_summary  \
# 3     Microsoft Keyboard 600 Black, German layout, A...            None
# 5            Logitech K120 Keyboard, German, 920-002489            None
# 15    Sharkoon Skiller SGK4 Gaming Keyboard RGB, N-K...            None
# 17                    Cherry Keyboard STREAM [DE] black            None
# 20                Logitech "K400 Plus Keyboard, German"            None
# ...                                                 ...             ...
# 1601   Dell Business Multimedia Keyboard - KB522, Black            None
# 1605  GK61 Mechanical Gaming Keyboard - 61 Keys Mult...            None
# 1606                     V7 USB/PS2 Wired Keyboard - ES            None
# 1611  Drop Planck Mechanical Keyboard Kit V6 — DIY C...            None
# 1613  MoKo Wireless Bluetooth Keyboard, Ultra-Thin F...            None
#
#                                       product_tech_spec  \
# 3                                                  None
# 5                                                  None
# 15                                                 None
# 17                                                 None
# 20                                                 None
# ...                                                 ...
# 1601  [{'info': 'Brand', 'value': '‎Dell'}, {'info':...
# 1605                                               None
# 1606                                               None
# 1611                                               None
# 1613  [{'info': 'Brand', 'value': '‎MoKo'}, {'info':...
#
#                                       product_addl_info  \
# 3     [{'info': 'Product Dimensions', 'value': '18.7...
# 5     [{'info': 'Product Dimensions', 'value': '17.3...
# 15    [{'info': 'Product Dimensions', 'value': '18.5...
# 17    [{'info': 'Product Dimensions', 'value': '18.2...
# 20    [{'info': 'Product Dimensions', 'value': '13.7...
# ...                                                 ...
# 1601  [{'info': 'Customer Reviews', 'value': '/*
# * F...
# 1605                                               None
# 1606                                               None
# 1611                                               None
# 1613  [{'info': 'Customer Reviews', 'value': '/*
# * F...
#
#                      seller  \
# 3                      None
# 5                      None
# 15                     None
# 17                     None
# 20      ZAR Systems Germany
# ...                     ...
# 1601                   None
# 1605    HK Gaming Keyboards
# 1606  Triplenet Pricing INC
# 1611                   None
# 1613                   None
#
#                                             seller_link  freq_bought  \
# 3                                                  None          NaN
# 5                                                  None          NaN
# 15                                                 None          NaN
# 17                                                 None          NaN
# 20    https://www.amazon.com/gp/help/seller/at-a-gla...          NaN
# ...                                                 ...          ...
# 1601                                               None          NaN
# 1605  https://www.amazon.com/gp/help/seller/at-a-gla...          NaN
# 1606  https://www.amazon.com/gp/help/seller/at-a-gla...          NaN
# 1611                                               None          NaN
# 1613                                               None          NaN
#
#       freq_bought_link                                link_to_all_reviews
# 3                  NaN  /Microsoft-Keyboard-German-layout-ANB-00008/pr...
# 5                  NaN  /Logitech-K120-Keyboard-German-920-002489/prod...
# 15                 NaN                                               None
# 17                 NaN                                               None
# 20                 NaN                                               None
# ...                ...                                                ...
# 1601               NaN  /Dell-Business-Multimedia-Keyboard-KB522/produ...
# 1605               NaN  /GK61-Mechanical-Gaming-Keyboard-Programmable/...
# 1606               NaN                                               None
# 1611               NaN  /Drop-Planck-Mechanical-Keyboard-Kit/product-r...
# 1613               NaN  /MoKo-Ultra-Thin-Rechargeable-Compatible-Smart...
#
# [288 rows x 9 columns]

# %%
#df["price"]= pd.to_numeric(df["price"])

# %%
df.to_csv('Keyboards_product.csv')

# %%
df.to_excel('Keyboards_product.xlsx')

# %%
df.to_json('Keyboards_product.jsonl')
