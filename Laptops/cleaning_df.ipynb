# %%
import pandas as pd

# %%
df = pd.read_json("search_output.jsonl")

# %% [markdown]
# # PRICE

# %%
df.head()
# Out:
#                                                title  \
# 0  Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1  BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2  HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3  Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 4  OMEN 15-en0375ng (15,6 Zoll / FHD IPS 144Hz) G...
#
#                                                  url             rating  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4,2 von 5 Sternen
# 1  https://www.amazon.com/gp/slredirect/picassoRe...  3,8 von 5 Sternen
# 2  https://www.amazon.com/gp/slredirect/picassoRe...  4,7 von 5 Sternen
# 3  https://www.amazon.com/Acer-Chromebook-Convert...  4,7 von 5 Sternen
# 4  https://www.amazon.com/15-en0375ng-Gaming-GeFo...  4,3 von 5 Sternen
#
#   review_count     price
# 0          216  379,00 €
# 1          687  459,00 €
# 2          496  699,90 €
# 3           32  415,95 €
# 4           62      None

# %%
df = df.dropna()
df.head()
# Out:
#                                                title  \
# 0  Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1  BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2  HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3  Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 5  Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
#
#                                                  url             rating  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4,2 von 5 Sternen
# 1  https://www.amazon.com/gp/slredirect/picassoRe...  3,8 von 5 Sternen
# 2  https://www.amazon.com/gp/slredirect/picassoRe...  4,7 von 5 Sternen
# 3  https://www.amazon.com/Acer-Chromebook-Convert...  4,7 von 5 Sternen
# 5  https://www.amazon.com/Acer-Chromebook-CB314-1...  4,4 von 5 Sternen
#
#   review_count     price
# 0          216  379,00 €
# 1          687  459,00 €
# 2          496  699,90 €
# 3           32  415,95 €
# 5        1.702  249,99 €

# %%
df["price"] = df["price"].replace({'\€':''}, regex = True)
df.head(20)
# Out:
#                                                 title  \
# 0   Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1   BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2   HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3   Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 5   Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
# 6   HUAWEI MateBook D 15 Zoll Laptop, FullView 108...
# 7   DELL Latitude E5470 Business Notebook, Intel i...
# 8   ASUS Intel Quad SSD (17,3 Zoll HD++) Notebook ...
# 9   Lenovo (15,6 Zoll) HD+ Notebook (Intel N4020 2...
# 10  Lenovo IdeaPad 5 Laptop 35,6 cm (14 Zoll, 1920...
# 11  Acer Aspire 3 (A315-23-R706) Laptop 15.6 Zoll ...
# 12  LincPlus P1 Laptop Full HD 13,3 Zoll Ultrabook...
# 13  LincPlus P3 Laptop Full HD 14 Zoll Ultrabook, ...
# 14  Dell Inspiron 14 5405, 14.0 Zoll FHD, AMD Ryze...
# 15  Jumper Laptop 13.3 Zoll FHD Notebook (4GB DDR3...
# 16  ASUS Notebook (15,6 Zoll Full HD matt 144Hz) A...
# 17  Laptop CHUWI HeroBook Pro,14.1 Full HD (1920X ...
# 20  Amazon Basics – Stadtrucksack aus Leinen, für ...
# 21  Laptop 10.1 Zoll Notebook , Windows 10 Quad Co...
# 22  15,6-Zoll-Laptop (Intel Celeron 64-Bit, 6 GB D...
#
#                                                   url             rating  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4,2 von 5 Sternen
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  3,8 von 5 Sternen
# 2   https://www.amazon.com/gp/slredirect/picassoRe...  4,7 von 5 Sternen
# 3   https://www.amazon.com/Acer-Chromebook-Convert...  4,7 von 5 Sternen
# 5   https://www.amazon.com/Acer-Chromebook-CB314-1...  4,4 von 5 Sternen
# 6   https://www.amazon.com/HUAWEI-Ultrabook-QWERTZ...  4,7 von 5 Sternen
# 7   https://www.amazon.com/Latitude-Prozessor-Arbe...  4,5 von 5 Sternen
# 8   https://www.amazon.com/ASUS-Notebook-Pentium%C...  4,3 von 5 Sternen
# 9   https://www.amazon.com/Lenovo-Notebook-Bluetoo...  4,3 von 5 Sternen
# 10  https://www.amazon.com/Lenovo-1920x1080-WideVi...  4,6 von 5 Sternen
# 11  https://www.amazon.com/Acer-A315-23-R706-Full-...  3,8 von 5 Sternen
# 12  https://www.amazon.com/LincPlus-Deutsches-Tast...  4,1 von 5 Sternen
# 13  https://www.amazon.com/LincPlus-Ultrabook-aufr...  3,8 von 5 Sternen
# 14  https://www.amazon.com/Dell-Inspiron-RyzenTM-4...  4,0 von 5 Sternen
# 15  https://www.amazon.com/Jumper-Quad-core-Graphi...  4,1 von 5 Sternen
# 16  https://www.amazon.com/Notebook-OctaCore-NVIDI...  4,4 von 5 Sternen
# 17  https://www.amazon.com/CHUWI-HeroBook-Ultraboo...  4,0 von 5 Sternen
# 20  https://www.amazon.com/AmazonBasics-Stadtrucks...  4,6 von 5 Sternen
# 21  https://www.amazon.com/gp/slredirect/picassoRe...  4,5 von 5 Sternen
# 22  https://www.amazon.com/gp/slredirect/picassoRe...  3,0 von 5 Sternen
#
#    review_count      price
# 0           216    379,00
# 1           687    459,00
# 2           496    699,90
# 3            32    415,95
# 5         1.702    249,99
# 6           496    499,00
# 7           114    745,00
# 8         1.564    444,00
# 9         3.412    399,00
# 10          300    699,00
# 11            8    590,61
# 12        1.079    279,00
# 13           68    269,00
# 14           14    599,00
# 15          183    279,99
# 16          717  1.149,00
# 17        2.264    349,00
# 20           48     18,27
# 21           11    219,99
# 22           17    288,99

# %%
df["price"] = df["price"].replace({',':'.'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1   BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2   HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3   Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 5   Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
# 6   HUAWEI MateBook D 15 Zoll Laptop, FullView 108...
# 7   DELL Latitude E5470 Business Notebook, Intel i...
# 8   ASUS Intel Quad SSD (17,3 Zoll HD++) Notebook ...
# 9   Lenovo (15,6 Zoll) HD+ Notebook (Intel N4020 2...
# 10  Lenovo IdeaPad 5 Laptop 35,6 cm (14 Zoll, 1920...
# 11  Acer Aspire 3 (A315-23-R706) Laptop 15.6 Zoll ...
# 12  LincPlus P1 Laptop Full HD 13,3 Zoll Ultrabook...
# 13  LincPlus P3 Laptop Full HD 14 Zoll Ultrabook, ...
# 14  Dell Inspiron 14 5405, 14.0 Zoll FHD, AMD Ryze...
# 15  Jumper Laptop 13.3 Zoll FHD Notebook (4GB DDR3...
#
#                                                   url             rating  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4,2 von 5 Sternen
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  3,8 von 5 Sternen
# 2   https://www.amazon.com/gp/slredirect/picassoRe...  4,7 von 5 Sternen
# 3   https://www.amazon.com/Acer-Chromebook-Convert...  4,7 von 5 Sternen
# 5   https://www.amazon.com/Acer-Chromebook-CB314-1...  4,4 von 5 Sternen
# 6   https://www.amazon.com/HUAWEI-Ultrabook-QWERTZ...  4,7 von 5 Sternen
# 7   https://www.amazon.com/Latitude-Prozessor-Arbe...  4,5 von 5 Sternen
# 8   https://www.amazon.com/ASUS-Notebook-Pentium%C...  4,3 von 5 Sternen
# 9   https://www.amazon.com/Lenovo-Notebook-Bluetoo...  4,3 von 5 Sternen
# 10  https://www.amazon.com/Lenovo-1920x1080-WideVi...  4,6 von 5 Sternen
# 11  https://www.amazon.com/Acer-A315-23-R706-Full-...  3,8 von 5 Sternen
# 12  https://www.amazon.com/LincPlus-Deutsches-Tast...  4,1 von 5 Sternen
# 13  https://www.amazon.com/LincPlus-Ultrabook-aufr...  3,8 von 5 Sternen
# 14  https://www.amazon.com/Dell-Inspiron-RyzenTM-4...  4,0 von 5 Sternen
# 15  https://www.amazon.com/Jumper-Quad-core-Graphi...  4,1 von 5 Sternen
#
#    review_count    price
# 0           216  379.00
# 1           687  459.00
# 2           496  699.90
# 3            32  415.95
# 5         1.702  249.99
# 6           496  499.00
# 7           114  745.00
# 8         1.564  444.00
# 9         3.412  399.00
# 10          300  699.00
# 11            8  590.61
# 12        1.079  279.00
# 13           68  269.00
# 14           14  599.00
# 15          183  279.99

# %%
df["rating"] = df["rating"].replace({'von 5 Sternen':'/ 5'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1   BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2   HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3   Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 5   Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
# 6   HUAWEI MateBook D 15 Zoll Laptop, FullView 108...
# 7   DELL Latitude E5470 Business Notebook, Intel i...
# 8   ASUS Intel Quad SSD (17,3 Zoll HD++) Notebook ...
# 9   Lenovo (15,6 Zoll) HD+ Notebook (Intel N4020 2...
# 10  Lenovo IdeaPad 5 Laptop 35,6 cm (14 Zoll, 1920...
# 11  Acer Aspire 3 (A315-23-R706) Laptop 15.6 Zoll ...
# 12  LincPlus P1 Laptop Full HD 13,3 Zoll Ultrabook...
# 13  LincPlus P3 Laptop Full HD 14 Zoll Ultrabook, ...
# 14  Dell Inspiron 14 5405, 14.0 Zoll FHD, AMD Ryze...
# 15  Jumper Laptop 13.3 Zoll FHD Notebook (4GB DDR3...
#
#                                                   url   rating review_count  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4,2 / 5          216
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  3,8 / 5          687
# 2   https://www.amazon.com/gp/slredirect/picassoRe...  4,7 / 5          496
# 3   https://www.amazon.com/Acer-Chromebook-Convert...  4,7 / 5           32
# 5   https://www.amazon.com/Acer-Chromebook-CB314-1...  4,4 / 5        1.702
# 6   https://www.amazon.com/HUAWEI-Ultrabook-QWERTZ...  4,7 / 5          496
# 7   https://www.amazon.com/Latitude-Prozessor-Arbe...  4,5 / 5          114
# 8   https://www.amazon.com/ASUS-Notebook-Pentium%C...  4,3 / 5        1.564
# 9   https://www.amazon.com/Lenovo-Notebook-Bluetoo...  4,3 / 5        3.412
# 10  https://www.amazon.com/Lenovo-1920x1080-WideVi...  4,6 / 5          300
# 11  https://www.amazon.com/Acer-A315-23-R706-Full-...  3,8 / 5            8
# 12  https://www.amazon.com/LincPlus-Deutsches-Tast...  4,1 / 5        1.079
# 13  https://www.amazon.com/LincPlus-Ultrabook-aufr...  3,8 / 5           68
# 14  https://www.amazon.com/Dell-Inspiron-RyzenTM-4...  4,0 / 5           14
# 15  https://www.amazon.com/Jumper-Quad-core-Graphi...  4,1 / 5          183
#
#       price
# 0   379.00
# 1   459.00
# 2   699.90
# 3   415.95
# 5   249.99
# 6   499.00
# 7   745.00
# 8   444.00
# 9   399.00
# 10  699.00
# 11  590.61
# 12  279.00
# 13  269.00
# 14  599.00
# 15  279.99

# %%
df["rating"] = df["rating"].replace({'out of 5 stars':'/ 5'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1   BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2   HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3   Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 5   Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
# 6   HUAWEI MateBook D 15 Zoll Laptop, FullView 108...
# 7   DELL Latitude E5470 Business Notebook, Intel i...
# 8   ASUS Intel Quad SSD (17,3 Zoll HD++) Notebook ...
# 9   Lenovo (15,6 Zoll) HD+ Notebook (Intel N4020 2...
# 10  Lenovo IdeaPad 5 Laptop 35,6 cm (14 Zoll, 1920...
# 11  Acer Aspire 3 (A315-23-R706) Laptop 15.6 Zoll ...
# 12  LincPlus P1 Laptop Full HD 13,3 Zoll Ultrabook...
# 13  LincPlus P3 Laptop Full HD 14 Zoll Ultrabook, ...
# 14  Dell Inspiron 14 5405, 14.0 Zoll FHD, AMD Ryze...
# 15  Jumper Laptop 13.3 Zoll FHD Notebook (4GB DDR3...
#
#                                                   url   rating review_count  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4,2 / 5          216
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  3,8 / 5          687
# 2   https://www.amazon.com/gp/slredirect/picassoRe...  4,7 / 5          496
# 3   https://www.amazon.com/Acer-Chromebook-Convert...  4,7 / 5           32
# 5   https://www.amazon.com/Acer-Chromebook-CB314-1...  4,4 / 5        1.702
# 6   https://www.amazon.com/HUAWEI-Ultrabook-QWERTZ...  4,7 / 5          496
# 7   https://www.amazon.com/Latitude-Prozessor-Arbe...  4,5 / 5          114
# 8   https://www.amazon.com/ASUS-Notebook-Pentium%C...  4,3 / 5        1.564
# 9   https://www.amazon.com/Lenovo-Notebook-Bluetoo...  4,3 / 5        3.412
# 10  https://www.amazon.com/Lenovo-1920x1080-WideVi...  4,6 / 5          300
# 11  https://www.amazon.com/Acer-A315-23-R706-Full-...  3,8 / 5            8
# 12  https://www.amazon.com/LincPlus-Deutsches-Tast...  4,1 / 5        1.079
# 13  https://www.amazon.com/LincPlus-Ultrabook-aufr...  3,8 / 5           68
# 14  https://www.amazon.com/Dell-Inspiron-RyzenTM-4...  4,0 / 5           14
# 15  https://www.amazon.com/Jumper-Quad-core-Graphi...  4,1 / 5          183
#
#       price
# 0   379.00
# 1   459.00
# 2   699.90
# 3   415.95
# 5   249.99
# 6   499.00
# 7   745.00
# 8   444.00
# 9   399.00
# 10  699.00
# 11  590.61
# 12  279.00
# 13  269.00
# 14  599.00
# 15  279.99

# %%
df["rating"] = df["rating"].replace({',':'.'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1   BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2   HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3   Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 5   Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
# 6   HUAWEI MateBook D 15 Zoll Laptop, FullView 108...
# 7   DELL Latitude E5470 Business Notebook, Intel i...
# 8   ASUS Intel Quad SSD (17,3 Zoll HD++) Notebook ...
# 9   Lenovo (15,6 Zoll) HD+ Notebook (Intel N4020 2...
# 10  Lenovo IdeaPad 5 Laptop 35,6 cm (14 Zoll, 1920...
# 11  Acer Aspire 3 (A315-23-R706) Laptop 15.6 Zoll ...
# 12  LincPlus P1 Laptop Full HD 13,3 Zoll Ultrabook...
# 13  LincPlus P3 Laptop Full HD 14 Zoll Ultrabook, ...
# 14  Dell Inspiron 14 5405, 14.0 Zoll FHD, AMD Ryze...
# 15  Jumper Laptop 13.3 Zoll FHD Notebook (4GB DDR3...
#
#                                                   url   rating review_count  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5          216
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  3.8 / 5          687
# 2   https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5          496
# 3   https://www.amazon.com/Acer-Chromebook-Convert...  4.7 / 5           32
# 5   https://www.amazon.com/Acer-Chromebook-CB314-1...  4.4 / 5        1.702
# 6   https://www.amazon.com/HUAWEI-Ultrabook-QWERTZ...  4.7 / 5          496
# 7   https://www.amazon.com/Latitude-Prozessor-Arbe...  4.5 / 5          114
# 8   https://www.amazon.com/ASUS-Notebook-Pentium%C...  4.3 / 5        1.564
# 9   https://www.amazon.com/Lenovo-Notebook-Bluetoo...  4.3 / 5        3.412
# 10  https://www.amazon.com/Lenovo-1920x1080-WideVi...  4.6 / 5          300
# 11  https://www.amazon.com/Acer-A315-23-R706-Full-...  3.8 / 5            8
# 12  https://www.amazon.com/LincPlus-Deutsches-Tast...  4.1 / 5        1.079
# 13  https://www.amazon.com/LincPlus-Ultrabook-aufr...  3.8 / 5           68
# 14  https://www.amazon.com/Dell-Inspiron-RyzenTM-4...  4.0 / 5           14
# 15  https://www.amazon.com/Jumper-Quad-core-Graphi...  4.1 / 5          183
#
#       price
# 0   379.00
# 1   459.00
# 2   699.90
# 3   415.95
# 5   249.99
# 6   499.00
# 7   745.00
# 8   444.00
# 9   399.00
# 10  699.00
# 11  590.61
# 12  279.00
# 13  269.00
# 14  599.00
# 15  279.99

# %%
### additional split function  df.price[0].split('$')[1] , df.rating[0].split(' ')[0] , https://pandas.pydata.org/docs/reference/api/pandas.Series.str.split.html

# %%
df_rc = df["review_count"].apply(lambda x: x.replace(',','.') )
display (df_rc)
df_rc_2 = pd.DataFrame(df_rc)
# Out:
# 0         216
# 1         687
# 2         496
# 3          32
# 5       1.702
#         ...
# 2206       21
# 2207        3
# 2208      920
# 2209       32
# 2210    5.889
# Name: review_count, Length: 1471, dtype: object

# %%
df_rc_2
# Out:
#      review_count
# 0             216
# 1             687
# 2             496
# 3              32
# 5           1.702
# ...           ...
# 2206           21
# 2207            3
# 2208          920
# 2209           32
# 2210        5.889
#
# [1471 rows x 1 columns]

# %%
df = df.drop(columns= "review_count")

# %%
df
# Out:
#                                                   title  \
# 0     Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1     BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2     HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3     Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 5     Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
# ...                                                 ...
# 2206  Laptop Stand, Laptop Stand, Notebook Stand, Mu...
# 2207  Laptop Stand, Height-Adjustable Notebook Stand...
# 2208  Voova 17 17.3 Inch Laptop Bag Laptop Sleeve No...
# 2209  Misott Vertical Laptop Stand, Space-Saving Com...
# 2210                               Phone charging cable
#
#                                                     url   rating    price
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5  379.00
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  3.8 / 5  459.00
# 2     https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  699.90
# 3     https://www.amazon.com/Acer-Chromebook-Convert...  4.7 / 5  415.95
# 5     https://www.amazon.com/Acer-Chromebook-CB314-1...  4.4 / 5  249.99
# ...                                                 ...      ...      ...
# 2206  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5    16.99
# 2207  https://www.amazon.com/-/en/gp/slredirect/pica...  4.0 / 5    25.99
# 2208  https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5    19.54
# 2209  https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5    16.98
# 2210  https://www.amazon.com/-/en/gp/slredirect/pica...  4.4 / 5     8.99
#
# [1471 rows x 4 columns]

# %%
f_column = df_rc_2 ["review_count"]
df = pd.concat([df,f_column], axis = 1)
df
# Out:
#                                                   title  \
# 0     Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1     BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2     HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3     Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 5     Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
# ...                                                 ...
# 2206  Laptop Stand, Laptop Stand, Notebook Stand, Mu...
# 2207  Laptop Stand, Height-Adjustable Notebook Stand...
# 2208  Voova 17 17.3 Inch Laptop Bag Laptop Sleeve No...
# 2209  Misott Vertical Laptop Stand, Space-Saving Com...
# 2210                               Phone charging cable
#
#                                                     url   rating    price  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5  379.00
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  3.8 / 5  459.00
# 2     https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  699.90
# 3     https://www.amazon.com/Acer-Chromebook-Convert...  4.7 / 5  415.95
# 5     https://www.amazon.com/Acer-Chromebook-CB314-1...  4.4 / 5  249.99
# ...                                                 ...      ...      ...
# 2206  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5    16.99
# 2207  https://www.amazon.com/-/en/gp/slredirect/pica...  4.0 / 5    25.99
# 2208  https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5    19.54
# 2209  https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5    16.98
# 2210  https://www.amazon.com/-/en/gp/slredirect/pica...  4.4 / 5     8.99
#
#      review_count
# 0             216
# 1             687
# 2             496
# 3              32
# 5           1.702
# ...           ...
# 2206           21
# 2207            3
# 2208          920
# 2209           32
# 2210        5.889
#
# [1471 rows x 5 columns]

# %%
df = df.rename(columns = {"price":"price €"})
df
# Out:
#                                                   title  \
# 0     Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1     BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2     HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3     Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 5     Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
# ...                                                 ...
# 2206  Laptop Stand, Laptop Stand, Notebook Stand, Mu...
# 2207  Laptop Stand, Height-Adjustable Notebook Stand...
# 2208  Voova 17 17.3 Inch Laptop Bag Laptop Sleeve No...
# 2209  Misott Vertical Laptop Stand, Space-Saving Com...
# 2210                               Phone charging cable
#
#                                                     url   rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5  379.00
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  3.8 / 5  459.00
# 2     https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  699.90
# 3     https://www.amazon.com/Acer-Chromebook-Convert...  4.7 / 5  415.95
# 5     https://www.amazon.com/Acer-Chromebook-CB314-1...  4.4 / 5  249.99
# ...                                                 ...      ...      ...
# 2206  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5    16.99
# 2207  https://www.amazon.com/-/en/gp/slredirect/pica...  4.0 / 5    25.99
# 2208  https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5    19.54
# 2209  https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5    16.98
# 2210  https://www.amazon.com/-/en/gp/slredirect/pica...  4.4 / 5     8.99
#
#      review_count
# 0             216
# 1             687
# 2             496
# 3              32
# 5           1.702
# ...           ...
# 2206           21
# 2207            3
# 2208          920
# 2209           32
# 2210        5.889
#
# [1471 rows x 5 columns]

# %%
df = df.rename(columns = {"title":"product title"})
df
# Out:
#                                           product title  \
# 0     Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1     BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2     HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3     Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 5     Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
# ...                                                 ...
# 2206  Laptop Stand, Laptop Stand, Notebook Stand, Mu...
# 2207  Laptop Stand, Height-Adjustable Notebook Stand...
# 2208  Voova 17 17.3 Inch Laptop Bag Laptop Sleeve No...
# 2209  Misott Vertical Laptop Stand, Space-Saving Com...
# 2210                               Phone charging cable
#
#                                                     url   rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5  379.00
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  3.8 / 5  459.00
# 2     https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  699.90
# 3     https://www.amazon.com/Acer-Chromebook-Convert...  4.7 / 5  415.95
# 5     https://www.amazon.com/Acer-Chromebook-CB314-1...  4.4 / 5  249.99
# ...                                                 ...      ...      ...
# 2206  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5    16.99
# 2207  https://www.amazon.com/-/en/gp/slredirect/pica...  4.0 / 5    25.99
# 2208  https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5    19.54
# 2209  https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5    16.98
# 2210  https://www.amazon.com/-/en/gp/slredirect/pica...  4.4 / 5     8.99
#
#      review_count
# 0             216
# 1             687
# 2             496
# 3              32
# 5           1.702
# ...           ...
# 2206           21
# 2207            3
# 2208          920
# 2209           32
# 2210        5.889
#
# [1471 rows x 5 columns]

# %%
df.loc[:, 'product'] = 'Laptops'

df.head(15)
# Out:
#                                         product title  \
# 0   Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1   BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2   HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3   Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 5   Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
# 6   HUAWEI MateBook D 15 Zoll Laptop, FullView 108...
# 7   DELL Latitude E5470 Business Notebook, Intel i...
# 8   ASUS Intel Quad SSD (17,3 Zoll HD++) Notebook ...
# 9   Lenovo (15,6 Zoll) HD+ Notebook (Intel N4020 2...
# 10  Lenovo IdeaPad 5 Laptop 35,6 cm (14 Zoll, 1920...
# 11  Acer Aspire 3 (A315-23-R706) Laptop 15.6 Zoll ...
# 12  LincPlus P1 Laptop Full HD 13,3 Zoll Ultrabook...
# 13  LincPlus P3 Laptop Full HD 14 Zoll Ultrabook, ...
# 14  Dell Inspiron 14 5405, 14.0 Zoll FHD, AMD Ryze...
# 15  Jumper Laptop 13.3 Zoll FHD Notebook (4GB DDR3...
#
#                                                   url   rating  price €  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5  379.00
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  3.8 / 5  459.00
# 2   https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  699.90
# 3   https://www.amazon.com/Acer-Chromebook-Convert...  4.7 / 5  415.95
# 5   https://www.amazon.com/Acer-Chromebook-CB314-1...  4.4 / 5  249.99
# 6   https://www.amazon.com/HUAWEI-Ultrabook-QWERTZ...  4.7 / 5  499.00
# 7   https://www.amazon.com/Latitude-Prozessor-Arbe...  4.5 / 5  745.00
# 8   https://www.amazon.com/ASUS-Notebook-Pentium%C...  4.3 / 5  444.00
# 9   https://www.amazon.com/Lenovo-Notebook-Bluetoo...  4.3 / 5  399.00
# 10  https://www.amazon.com/Lenovo-1920x1080-WideVi...  4.6 / 5  699.00
# 11  https://www.amazon.com/Acer-A315-23-R706-Full-...  3.8 / 5  590.61
# 12  https://www.amazon.com/LincPlus-Deutsches-Tast...  4.1 / 5  279.00
# 13  https://www.amazon.com/LincPlus-Ultrabook-aufr...  3.8 / 5  269.00
# 14  https://www.amazon.com/Dell-Inspiron-RyzenTM-4...  4.0 / 5  599.00
# 15  https://www.amazon.com/Jumper-Quad-core-Graphi...  4.1 / 5  279.99
#
#    review_count  product
# 0           216  Laptops
# 1           687  Laptops
# 2           496  Laptops
# 3            32  Laptops
# 5         1.702  Laptops
# 6           496  Laptops
# 7           114  Laptops
# 8         1.564  Laptops
# 9         3.412  Laptops
# 10          300  Laptops
# 11            8  Laptops
# 12        1.079  Laptops
# 13           68  Laptops
# 14           14  Laptops
# 15          183  Laptops

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1500 entries, 0 to 1616
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product title  1500 non-null   object
#  1   url            1500 non-null   object
#  2   rating         1500 non-null   object
#  3   price €        1500 non-null   object
#  4   review_count   1500 non-null   object
#  5   product        1500 non-null   object
# dtypes: object(6)
# memory usage: 82.0+ KB

# %%
#df["price"]= pd.to_numeric(df["price"])

# %%
df.to_csv('Laptops_sample_cleaned.csv')

# %%
df.to_excel('Laptops_sample_cleaned.xlsx')

# %%
df
# Out:
#                                           product title  \
# 0     Lenovo ThinkPad T440 Business Notebook, Intel ...
# 1     BMAX Y13 2 in 1 Laptop, 13.3 Zoll FHD Converti...
# 2     HUAWEI MateBook D 14 Zoll Laptop, FullView 108...
# 3     Acer Chromebook Convertible 13 Zoll (CP513-1H)...
# 5     Acer Chromebook 14 Zoll (CB314-1H-C7PS) (Chrom...
# ...                                                 ...
# 2206  Laptop Stand, Laptop Stand, Notebook Stand, Mu...
# 2207  Laptop Stand, Height-Adjustable Notebook Stand...
# 2208  Voova 17 17.3 Inch Laptop Bag Laptop Sleeve No...
# 2209  Misott Vertical Laptop Stand, Space-Saving Com...
# 2210                               Phone charging cable
#
#                                                     url   rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5  379.00
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  3.8 / 5  459.00
# 2     https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  699.90
# 3     https://www.amazon.com/Acer-Chromebook-Convert...  4.7 / 5  415.95
# 5     https://www.amazon.com/Acer-Chromebook-CB314-1...  4.4 / 5  249.99
# ...                                                 ...      ...      ...
# 2206  https://www.amazon.com/-/en/gp/slredirect/pica...  5.0 / 5    16.99
# 2207  https://www.amazon.com/-/en/gp/slredirect/pica...  4.0 / 5    25.99
# 2208  https://www.amazon.com/-/en/gp/slredirect/pica...  4.6 / 5    19.54
# 2209  https://www.amazon.com/-/en/gp/slredirect/pica...  4.2 / 5    16.98
# 2210  https://www.amazon.com/-/en/gp/slredirect/pica...  4.4 / 5     8.99
#
#      review_count  product
# 0             216  Laptops
# 1             687  Laptops
# 2             496  Laptops
# 3              32  Laptops
# 5           1.702  Laptops
# ...           ...      ...
# 2206           21  Laptops
# 2207            3  Laptops
# 2208          920  Laptops
# 2209           32  Laptops
# 2210        5.889  Laptops
#
# [1471 rows x 6 columns]
