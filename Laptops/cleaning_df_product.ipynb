# %%
import pandas as pd

# %%
df = pd.read_json("product_output.jsonl")

# %%
df
# Out:
#       name product_summary product_tech_spec product_addl_info seller  \
# 0     None            None              None              None   None
# 1     None            None              None              None   None
# 2     None            None              None              None   None
# 3     None            None              None              None   None
# 4     None            None              None              None   None
# ...    ...             ...               ...               ...    ...
# 2206  None            None              None              None   None
# 2207  None            None              None              None   None
# 2208  None            None              None              None   None
# 2209  None            None              None              None   None
# 2210  None            None              None              None   None
#
#      seller_link  freq_bought  freq_bought_link link_to_all_reviews
# 0           None          NaN               NaN                None
# 1           None          NaN               NaN                None
# 2           None          NaN               NaN                None
# 3           None          NaN               NaN                None
# 4           None          NaN               NaN                None
# ...          ...          ...               ...                 ...
# 2206        None          NaN               NaN                None
# 2207        None          NaN               NaN                None
# 2208        None          NaN               NaN                None
# 2209        None          NaN               NaN                None
# 2210        None          NaN               NaN                None
#
# [2211 rows x 9 columns]

# %%
df_1 = df[(df["name"] == "None")]
df_1
# Out:
# Empty DataFrame
# Columns: [name, product_summary, product_tech_spec, product_addl_info, seller, seller_link, freq_bought, freq_bought_link, link_to_all_reviews]
# Index: []

# %%
df
# Out:
#                                                    name product_summary  \
# 0                                                  None            None
# 1                                                  None            None
# 2                                                  None            None
# 3                                                  None            None
# 4                                                  None            None
# ...                                                 ...             ...
# 2125                                               None            None
# 2126  Moxking Wired Durable Metal Earphones Earbuds ...            None
# 2127                                               None            None
# 2128                                               None            None
# 2129                                               None            None
#
#      product_tech_spec                                  product_addl_info  \
# 0                 None                                               None
# 1                 None                                               None
# 2                 None                                               None
# 3                 None                                               None
# 4                 None                                               None
# ...                ...                                                ...
# 2125              None                                               None
# 2126              None  [{'info': 'Product Dimensions', 'value': '5.91...
# 2127              None                                               None
# 2128              None                                               None
# 2129              None                                               None
#
#        seller                                        seller_link freq_bought  \
# 0        None                                               None        None
# 1        None                                               None        None
# 2        None                                               None        None
# 3        None                                               None        None
# 4        None                                               None        None
# ...       ...                                                ...         ...
# 2125     None                                               None        None
# 2126  Joysico  https://www.amazon.com/gp/help/seller/at-a-gla...        None
# 2127     None                                               None        None
# 2128     None                                               None        None
# 2129     None                                               None        None
#
#      freq_bought_link                                link_to_all_reviews
# 0                None                                               None
# 1                None                                               None
# 2                None                                               None
# 3                None                                               None
# 4                None                                               None
# ...               ...                                                ...
# 2125             None                                               None
# 2126             None  /Moxking-Earphones-Microphone-Isolating-Headph...
# 2127             None                                               None
# 2128             None                                               None
# 2129             None                                               None
#
# [2130 rows x 9 columns]

# %%
df = df.dropna(subset=['name'])

# %%
#df = df.reset_index()
#df

# %%
df
# Out:
#                                                    name  \
# 20    Amazon Basics Urban Backpack for Laptops up to...
# 32    Laptop PC 11.6 Inch TECLAST F5 360° Convertibl...
# 39    Hseok 15.6-Inch Laptop Case Sleeve, Environmen...
# 42    Amazon Basics 13.3" Professional Laptop Case S...
# 51    Bewahly Vertical Laptop Stand[Adjustable Size]...
# ...                                                 ...
# 2183  Green Cell Extended Series MU06 Battery for HP...
# 2193  Alfheim Laptop Backpack for Men Women Fits 14 ...
# 2195  [5-Yrs Free Data Recovery] Gigastone 128GB 2-P...
# 2202  Logitech Slim Combo for iPad 5./6. Generation ...
# 2205  MiiKARE Aluminium Laptop Ständer, höhenverstel...
#
#                                         product_summary  \
# 20    [{'info': 'Brand', 'value': '‎Amazon Basics'},...
# 32    [{'info': 'Item model number', 'value': '‎F5'}...
# 39    [{'info': 'Brand', 'value': '‎Hseok'}, {'info'...
# 42    [{'info': 'Brand', 'value': '‎Amazon Basics'},...
# 51                                                 None
# ...                                                 ...
# 2183                                               None
# 2193                                               None
# 2195                                               None
# 2202                                               None
# 2205                                               None
#
#                                       product_tech_spec  \
# 20    [{'info': 'Standing screen display size', 'val...
# 32    [{'info': 'Standing screen display size', 'val...
# 39    [{'info': 'Standing screen display size', 'val...
# 42    [{'info': 'Standing screen display size', 'val...
# 51                                                 None
# ...                                                 ...
# 2183                                               None
# 2193  [{'info': 'Brand Name', 'value': '‎Alfheim'}, ...
# 2195                                               None
# 2202                                               None
# 2205                                               None
#
#                                       product_addl_info              seller  \
# 20    [{'info': 'Customer Reviews', 'value': '/*
# * F...                None
# 32    [{'info': 'ASIN', 'value': 'B089KJPHVN'}, {'in...                None
# 39    [{'info': 'Customer Reviews', 'value': '/*
# * F...               Hseok
# 42    [{'info': 'Customer Reviews', 'value': '/*
# * F...                None
# 51    [{'info': 'Product Dimensions', 'value': '5.91...          Bewahly US
# ...                                                 ...                 ...
# 2183  [{'info': 'Product Dimensions', 'value': '8.07...                None
# 2193  [{'info': 'ASIN', 'value': 'B07Y69HY35'}, {'in...                None
# 2195  [{'info': 'Package Dimensions', 'value': '5.51...  Gigastone  America
# 2202  [{'info': 'Product Dimensions', 'value': '9.69...                None
# 2205  [{'info': 'Package Dimensions', 'value': '11.2...                None
#
#                                             seller_link  freq_bought  \
# 20                                                 None          NaN
# 32                                                 None          NaN
# 39    https://www.amazon.com/gp/help/seller/at-a-gla...          NaN
# 42                                                 None          NaN
# 51    https://www.amazon.com/gp/help/seller/at-a-gla...          NaN
# ...                                                 ...          ...
# 2183                                               None          NaN
# 2193                                               None          NaN
# 2195  https://www.amazon.com/gp/help/seller/at-a-gla...          NaN
# 2202                                               None          NaN
# 2205                                               None          NaN
#
#       freq_bought_link                                link_to_all_reviews
# 20                 NaN  /AmazonBasics-Urban-Backpack-Laptops-15-Inches...
# 32                 NaN                                               None
# 39                 NaN  /Hseok-15-6-Inch-Environmental-Friendly-Spill-...
# 42                 NaN  /AmazonBasics-Professional-Laptop-Sleeve-Retra...
# 51                 NaN  /Bewahly-Vertical-Adjustable-Aluminum-Suitable...
# ...                ...                                                ...
# 2183               NaN                                               None
# 2193               NaN                                               None
# 2195               NaN  /Gigastone-2-Pack-Recording-Nintendo-Compatibl...
# 2202               NaN                                               None
# 2205               NaN                                               None
#
# [207 rows x 9 columns]

# %%
#df["price"]= pd.to_numeric(df["price"])

# %%
df.to_csv('Laptops_product.csv')

# %%
df.to_excel('Laptops_product.xlsx')

# %%
df.to_json('Laptops_product.jsonl')
