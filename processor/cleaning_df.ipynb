# %%
import pandas as pd

# %%
df = pd.read_json("search_output.jsonl")

# %% [markdown]
# # PRICE

# %%
df.head()
# Out:
#                                                title  \
# 0  MINIS FORUM Mini PC, Intel Celeron Processor J...
# 1  Tablet 10 Zoll,Blackview Tab10 Android 11 Octa...
# 2  AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 3                         AMD Ryzen 5 1600 Prozessor
# 4  INTEL BXTS15A Thermal Solution TS15A for Intel...
#
#                                                  url             rating  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4,3 von 5 Sternen
# 1  https://www.amazon.com/gp/slredirect/picassoRe...               None
# 2  https://www.amazon.com/AMD-Ryzen-3700X-Prozess...  4,8 von 5 Sternen
# 3  https://www.amazon.com/AMD-Ryzen-5-1600-Prozes...  4,7 von 5 Sternen
# 4  https://www.amazon.com/BXTS15A-Solution-Intel-...  4,4 von 5 Sternen
#
#   review_count     price
# 0          106  249,99 €
# 1         None  219,99 €
# 2       20.484  262,70 €
# 3       10.236      None
# 4           13   28,91 €

# %%
df = df.dropna()
df.head()
# Out:
#                                                title  \
# 0  MINIS FORUM Mini PC, Intel Celeron Processor J...
# 2  AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 4  INTEL BXTS15A Thermal Solution TS15A for Intel...
# 5  AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 6  Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
#
#                                                  url             rating  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4,3 von 5 Sternen
# 2  https://www.amazon.com/AMD-Ryzen-3700X-Prozess...  4,8 von 5 Sternen
# 4  https://www.amazon.com/BXTS15A-Solution-Intel-...  4,4 von 5 Sternen
# 5  https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...  4,8 von 5 Sternen
# 6  https://www.amazon.com/gp/slredirect/picassoRe...  4,1 von 5 Sternen
#
#   review_count     price
# 0          106  249,99 €
# 2       20.484  262,70 €
# 4           13   28,91 €
# 5       33.386  209,99 €
# 6          205  320,99 €

# %%
df["price"] = df["price"].replace({'\€':''}, regex = True)
df
# Out:
#                                                   title  \
# 0     MINIS FORUM Mini PC, Intel Celeron Processor J...
# 2     AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 4     INTEL BXTS15A Thermal Solution TS15A for Intel...
# 5     AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 6     Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
# ...                                                 ...
# 2088  MoneyQiu HY-700 (50 g) > 3.14 W/m.K, CPU Therm...
# 2090                             MSI Gaming Motherboard
# 2091  ACEPC Mini PC, Intel Celeron J3455, AK1 4GB RA...
# 2092  Intel Nuc Mini Complete PC, Intel i5-10210U Qu...
# 2093  Intel Nuc Mini Complete PC, Intel Quad Core 4 ...
#
#                                                     url              rating  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...   4,3 von 5 Sternen
# 2     https://www.amazon.com/AMD-Ryzen-3700X-Prozess...   4,8 von 5 Sternen
# 4     https://www.amazon.com/BXTS15A-Solution-Intel-...   4,4 von 5 Sternen
# 5     https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...   4,8 von 5 Sternen
# 6     https://www.amazon.com/gp/slredirect/picassoRe...   4,1 von 5 Sternen
# ...                                                 ...                 ...
# 2088  https://www.amazon.com/-/en/MoneyQiu-HY-700-Th...  4.5 out of 5 stars
# 2090  https://www.amazon.com/-/en/7C37-001R-MSI-Gami...  4.6 out of 5 stars
# 2091  https://www.amazon.com/-/en/Celeron-Windows-Bl...  3.8 out of 5 stars
# 2092  https://www.amazon.com/-/en/Complete-i5-10210U...  4.0 out of 5 stars
# 2093  https://www.amazon.com/-/en/Complete-2-30GHz-G...  4.7 out of 5 stars
#
#      review_count    price
# 0             106  249,99
# 2          20.484  262,70
# 4              13   28,91
# 5          33.386  209,99
# 6             205  320,99
# ...           ...      ...
# 2088          424    16.99
# 2090        2,467   174.90
# 2091          175   159.90
# 2092            2   429.99
# 2093           48   469.00
#
# [1569 rows x 5 columns]

# %%
df["price"] = df["price"].replace({',':'.'}, regex = True)
df
# Out:
#                                                   title  \
# 0     MINIS FORUM Mini PC, Intel Celeron Processor J...
# 2     AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 4     INTEL BXTS15A Thermal Solution TS15A for Intel...
# 5     AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 6     Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
# ...                                                 ...
# 2088  MoneyQiu HY-700 (50 g) > 3.14 W/m.K, CPU Therm...
# 2090                             MSI Gaming Motherboard
# 2091  ACEPC Mini PC, Intel Celeron J3455, AK1 4GB RA...
# 2092  Intel Nuc Mini Complete PC, Intel i5-10210U Qu...
# 2093  Intel Nuc Mini Complete PC, Intel Quad Core 4 ...
#
#                                                     url              rating  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...   4,3 von 5 Sternen
# 2     https://www.amazon.com/AMD-Ryzen-3700X-Prozess...   4,8 von 5 Sternen
# 4     https://www.amazon.com/BXTS15A-Solution-Intel-...   4,4 von 5 Sternen
# 5     https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...   4,8 von 5 Sternen
# 6     https://www.amazon.com/gp/slredirect/picassoRe...   4,1 von 5 Sternen
# ...                                                 ...                 ...
# 2088  https://www.amazon.com/-/en/MoneyQiu-HY-700-Th...  4.5 out of 5 stars
# 2090  https://www.amazon.com/-/en/7C37-001R-MSI-Gami...  4.6 out of 5 stars
# 2091  https://www.amazon.com/-/en/Celeron-Windows-Bl...  3.8 out of 5 stars
# 2092  https://www.amazon.com/-/en/Complete-i5-10210U...  4.0 out of 5 stars
# 2093  https://www.amazon.com/-/en/Complete-2-30GHz-G...  4.7 out of 5 stars
#
#      review_count    price
# 0             106  249.99
# 2          20.484  262.70
# 4              13   28.91
# 5          33.386  209.99
# 6             205  320.99
# ...           ...      ...
# 2088          424    16.99
# 2090        2,467   174.90
# 2091          175   159.90
# 2092            2   429.99
# 2093           48   469.00
#
# [1569 rows x 5 columns]

# %%
df["rating"] = df["rating"].replace({'von 5 Sternen':'/ 5'}, regex = True)
df
# Out:
#                                                   title  \
# 0     MINIS FORUM Mini PC, Intel Celeron Processor J...
# 2     AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 4     INTEL BXTS15A Thermal Solution TS15A for Intel...
# 5     AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 6     Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
# ...                                                 ...
# 2088  MoneyQiu HY-700 (50 g) > 3.14 W/m.K, CPU Therm...
# 2090                             MSI Gaming Motherboard
# 2091  ACEPC Mini PC, Intel Celeron J3455, AK1 4GB RA...
# 2092  Intel Nuc Mini Complete PC, Intel i5-10210U Qu...
# 2093  Intel Nuc Mini Complete PC, Intel Quad Core 4 ...
#
#                                                     url              rating  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...             4,3 / 5
# 2     https://www.amazon.com/AMD-Ryzen-3700X-Prozess...             4,8 / 5
# 4     https://www.amazon.com/BXTS15A-Solution-Intel-...             4,4 / 5
# 5     https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...             4,8 / 5
# 6     https://www.amazon.com/gp/slredirect/picassoRe...             4,1 / 5
# ...                                                 ...                 ...
# 2088  https://www.amazon.com/-/en/MoneyQiu-HY-700-Th...  4.5 out of 5 stars
# 2090  https://www.amazon.com/-/en/7C37-001R-MSI-Gami...  4.6 out of 5 stars
# 2091  https://www.amazon.com/-/en/Celeron-Windows-Bl...  3.8 out of 5 stars
# 2092  https://www.amazon.com/-/en/Complete-i5-10210U...  4.0 out of 5 stars
# 2093  https://www.amazon.com/-/en/Complete-2-30GHz-G...  4.7 out of 5 stars
#
#      review_count    price
# 0             106  249.99
# 2          20.484  262.70
# 4              13   28.91
# 5          33.386  209.99
# 6             205  320.99
# ...           ...      ...
# 2088          424    16.99
# 2090        2,467   174.90
# 2091          175   159.90
# 2092            2   429.99
# 2093           48   469.00
#
# [1569 rows x 5 columns]

# %%
df["rating"] = df["rating"].replace({'out of 5 stars':'/ 5'}, regex = True)
df
# Out:
#                                                   title  \
# 0     MINIS FORUM Mini PC, Intel Celeron Processor J...
# 2     AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 4     INTEL BXTS15A Thermal Solution TS15A for Intel...
# 5     AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 6     Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
# ...                                                 ...
# 2088  MoneyQiu HY-700 (50 g) > 3.14 W/m.K, CPU Therm...
# 2090                             MSI Gaming Motherboard
# 2091  ACEPC Mini PC, Intel Celeron J3455, AK1 4GB RA...
# 2092  Intel Nuc Mini Complete PC, Intel i5-10210U Qu...
# 2093  Intel Nuc Mini Complete PC, Intel Quad Core 4 ...
#
#                                                     url   rating review_count  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4,3 / 5          106
# 2     https://www.amazon.com/AMD-Ryzen-3700X-Prozess...  4,8 / 5       20.484
# 4     https://www.amazon.com/BXTS15A-Solution-Intel-...  4,4 / 5           13
# 5     https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...  4,8 / 5       33.386
# 6     https://www.amazon.com/gp/slredirect/picassoRe...  4,1 / 5          205
# ...                                                 ...      ...          ...
# 2088  https://www.amazon.com/-/en/MoneyQiu-HY-700-Th...  4.5 / 5          424
# 2090  https://www.amazon.com/-/en/7C37-001R-MSI-Gami...  4.6 / 5        2,467
# 2091  https://www.amazon.com/-/en/Celeron-Windows-Bl...  3.8 / 5          175
# 2092  https://www.amazon.com/-/en/Complete-i5-10210U...  4.0 / 5            2
# 2093  https://www.amazon.com/-/en/Complete-2-30GHz-G...  4.7 / 5           48
#
#         price
# 0     249.99
# 2     262.70
# 4      28.91
# 5     209.99
# 6     320.99
# ...       ...
# 2088    16.99
# 2090   174.90
# 2091   159.90
# 2092   429.99
# 2093   469.00
#
# [1569 rows x 5 columns]

# %%
df["rating"] = df["rating"].replace({',':'.'}, regex = True)
df
# Out:
#                                                   title  \
# 0     MINIS FORUM Mini PC, Intel Celeron Processor J...
# 2     AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 4     INTEL BXTS15A Thermal Solution TS15A for Intel...
# 5     AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 6     Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
# ...                                                 ...
# 2088  MoneyQiu HY-700 (50 g) > 3.14 W/m.K, CPU Therm...
# 2090                             MSI Gaming Motherboard
# 2091  ACEPC Mini PC, Intel Celeron J3455, AK1 4GB RA...
# 2092  Intel Nuc Mini Complete PC, Intel i5-10210U Qu...
# 2093  Intel Nuc Mini Complete PC, Intel Quad Core 4 ...
#
#                                                     url   rating review_count  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5          106
# 2     https://www.amazon.com/AMD-Ryzen-3700X-Prozess...  4.8 / 5       20.484
# 4     https://www.amazon.com/BXTS15A-Solution-Intel-...  4.4 / 5           13
# 5     https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...  4.8 / 5       33.386
# 6     https://www.amazon.com/gp/slredirect/picassoRe...  4.1 / 5          205
# ...                                                 ...      ...          ...
# 2088  https://www.amazon.com/-/en/MoneyQiu-HY-700-Th...  4.5 / 5          424
# 2090  https://www.amazon.com/-/en/7C37-001R-MSI-Gami...  4.6 / 5        2,467
# 2091  https://www.amazon.com/-/en/Celeron-Windows-Bl...  3.8 / 5          175
# 2092  https://www.amazon.com/-/en/Complete-i5-10210U...  4.0 / 5            2
# 2093  https://www.amazon.com/-/en/Complete-2-30GHz-G...  4.7 / 5           48
#
#         price
# 0     249.99
# 2     262.70
# 4      28.91
# 5     209.99
# 6     320.99
# ...       ...
# 2088    16.99
# 2090   174.90
# 2091   159.90
# 2092   429.99
# 2093   469.00
#
# [1569 rows x 5 columns]

# %%
### additional split function  df.price[0].split('$')[1] , df.rating[0].split(' ')[0] , https://pandas.pydata.org/docs/reference/api/pandas.Series.str.split.html

# %%
df_rc = df["review_count"].apply(lambda x: x.replace(',','.') )
display (df_rc)
df_rc_2 = pd.DataFrame(df_rc)
# Out:
# 0          106
# 2       20.484
# 4           13
# 5       33.386
# 6          205
#          ...
# 2088       424
# 2090     2.467
# 2091       175
# 2092         2
# 2093        48
# Name: review_count, Length: 1569, dtype: object

# %%
df_rc_2
# Out:
#      review_count
# 0             106
# 2          20.484
# 4              13
# 5          33.386
# 6             205
# ...           ...
# 2088          424
# 2090        2.467
# 2091          175
# 2092            2
# 2093           48
#
# [1569 rows x 1 columns]

# %%
df = df.drop(columns= "review_count")

# %%
df
# Out:
#                                                   title  \
# 0     MINIS FORUM Mini PC, Intel Celeron Processor J...
# 2     AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 4     INTEL BXTS15A Thermal Solution TS15A for Intel...
# 5     AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 6     Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
# ...                                                 ...
# 2088  MoneyQiu HY-700 (50 g) > 3.14 W/m.K, CPU Therm...
# 2090                             MSI Gaming Motherboard
# 2091  ACEPC Mini PC, Intel Celeron J3455, AK1 4GB RA...
# 2092  Intel Nuc Mini Complete PC, Intel i5-10210U Qu...
# 2093  Intel Nuc Mini Complete PC, Intel Quad Core 4 ...
#
#                                                     url   rating    price
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  249.99
# 2     https://www.amazon.com/AMD-Ryzen-3700X-Prozess...  4.8 / 5  262.70
# 4     https://www.amazon.com/BXTS15A-Solution-Intel-...  4.4 / 5   28.91
# 5     https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...  4.8 / 5  209.99
# 6     https://www.amazon.com/gp/slredirect/picassoRe...  4.1 / 5  320.99
# ...                                                 ...      ...      ...
# 2088  https://www.amazon.com/-/en/MoneyQiu-HY-700-Th...  4.5 / 5    16.99
# 2090  https://www.amazon.com/-/en/7C37-001R-MSI-Gami...  4.6 / 5   174.90
# 2091  https://www.amazon.com/-/en/Celeron-Windows-Bl...  3.8 / 5   159.90
# 2092  https://www.amazon.com/-/en/Complete-i5-10210U...  4.0 / 5   429.99
# 2093  https://www.amazon.com/-/en/Complete-2-30GHz-G...  4.7 / 5   469.00
#
# [1569 rows x 4 columns]

# %%
f_column = df_rc_2 ["review_count"]
df = pd.concat([df,f_column], axis = 1)
df
# Out:
#                                                   title  \
# 0     MINIS FORUM Mini PC, Intel Celeron Processor J...
# 2     AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 4     INTEL BXTS15A Thermal Solution TS15A for Intel...
# 5     AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 6     Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
# ...                                                 ...
# 2088  MoneyQiu HY-700 (50 g) > 3.14 W/m.K, CPU Therm...
# 2090                             MSI Gaming Motherboard
# 2091  ACEPC Mini PC, Intel Celeron J3455, AK1 4GB RA...
# 2092  Intel Nuc Mini Complete PC, Intel i5-10210U Qu...
# 2093  Intel Nuc Mini Complete PC, Intel Quad Core 4 ...
#
#                                                     url   rating    price  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  249.99
# 2     https://www.amazon.com/AMD-Ryzen-3700X-Prozess...  4.8 / 5  262.70
# 4     https://www.amazon.com/BXTS15A-Solution-Intel-...  4.4 / 5   28.91
# 5     https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...  4.8 / 5  209.99
# 6     https://www.amazon.com/gp/slredirect/picassoRe...  4.1 / 5  320.99
# ...                                                 ...      ...      ...
# 2088  https://www.amazon.com/-/en/MoneyQiu-HY-700-Th...  4.5 / 5    16.99
# 2090  https://www.amazon.com/-/en/7C37-001R-MSI-Gami...  4.6 / 5   174.90
# 2091  https://www.amazon.com/-/en/Celeron-Windows-Bl...  3.8 / 5   159.90
# 2092  https://www.amazon.com/-/en/Complete-i5-10210U...  4.0 / 5   429.99
# 2093  https://www.amazon.com/-/en/Complete-2-30GHz-G...  4.7 / 5   469.00
#
#      review_count
# 0             106
# 2          20.484
# 4              13
# 5          33.386
# 6             205
# ...           ...
# 2088          424
# 2090        2.467
# 2091          175
# 2092            2
# 2093           48
#
# [1569 rows x 5 columns]

# %%
df = df.rename(columns = {"price":"price €"})
df
# Out:
#                                                   title  \
# 0     MINIS FORUM Mini PC, Intel Celeron Processor J...
# 2     AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 4     INTEL BXTS15A Thermal Solution TS15A for Intel...
# 5     AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 6     Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
# ...                                                 ...
# 2088  MoneyQiu HY-700 (50 g) > 3.14 W/m.K, CPU Therm...
# 2090                             MSI Gaming Motherboard
# 2091  ACEPC Mini PC, Intel Celeron J3455, AK1 4GB RA...
# 2092  Intel Nuc Mini Complete PC, Intel i5-10210U Qu...
# 2093  Intel Nuc Mini Complete PC, Intel Quad Core 4 ...
#
#                                                     url   rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  249.99
# 2     https://www.amazon.com/AMD-Ryzen-3700X-Prozess...  4.8 / 5  262.70
# 4     https://www.amazon.com/BXTS15A-Solution-Intel-...  4.4 / 5   28.91
# 5     https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...  4.8 / 5  209.99
# 6     https://www.amazon.com/gp/slredirect/picassoRe...  4.1 / 5  320.99
# ...                                                 ...      ...      ...
# 2088  https://www.amazon.com/-/en/MoneyQiu-HY-700-Th...  4.5 / 5    16.99
# 2090  https://www.amazon.com/-/en/7C37-001R-MSI-Gami...  4.6 / 5   174.90
# 2091  https://www.amazon.com/-/en/Celeron-Windows-Bl...  3.8 / 5   159.90
# 2092  https://www.amazon.com/-/en/Complete-i5-10210U...  4.0 / 5   429.99
# 2093  https://www.amazon.com/-/en/Complete-2-30GHz-G...  4.7 / 5   469.00
#
#      review_count
# 0             106
# 2          20.484
# 4              13
# 5          33.386
# 6             205
# ...           ...
# 2088          424
# 2090        2.467
# 2091          175
# 2092            2
# 2093           48
#
# [1569 rows x 5 columns]

# %%
df = df.rename(columns = {"title":"product title"})
df
# Out:
#                                           product title  \
# 0     MINIS FORUM Mini PC, Intel Celeron Processor J...
# 2     AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 4     INTEL BXTS15A Thermal Solution TS15A for Intel...
# 5     AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 6     Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
# ...                                                 ...
# 2088  MoneyQiu HY-700 (50 g) > 3.14 W/m.K, CPU Therm...
# 2090                             MSI Gaming Motherboard
# 2091  ACEPC Mini PC, Intel Celeron J3455, AK1 4GB RA...
# 2092  Intel Nuc Mini Complete PC, Intel i5-10210U Qu...
# 2093  Intel Nuc Mini Complete PC, Intel Quad Core 4 ...
#
#                                                     url   rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  249.99
# 2     https://www.amazon.com/AMD-Ryzen-3700X-Prozess...  4.8 / 5  262.70
# 4     https://www.amazon.com/BXTS15A-Solution-Intel-...  4.4 / 5   28.91
# 5     https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...  4.8 / 5  209.99
# 6     https://www.amazon.com/gp/slredirect/picassoRe...  4.1 / 5  320.99
# ...                                                 ...      ...      ...
# 2088  https://www.amazon.com/-/en/MoneyQiu-HY-700-Th...  4.5 / 5    16.99
# 2090  https://www.amazon.com/-/en/7C37-001R-MSI-Gami...  4.6 / 5   174.90
# 2091  https://www.amazon.com/-/en/Celeron-Windows-Bl...  3.8 / 5   159.90
# 2092  https://www.amazon.com/-/en/Complete-i5-10210U...  4.0 / 5   429.99
# 2093  https://www.amazon.com/-/en/Complete-2-30GHz-G...  4.7 / 5   469.00
#
#      review_count
# 0             106
# 2          20.484
# 4              13
# 5          33.386
# 6             205
# ...           ...
# 2088          424
# 2090        2.467
# 2091          175
# 2092            2
# 2093           48
#
# [1569 rows x 5 columns]

# %%
df.loc[:, 'product'] = 'Processor'

df.head()
# Out:
#                                        product title  \
# 0  MINIS FORUM Mini PC, Intel Celeron Processor J...
# 2  AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 4  INTEL BXTS15A Thermal Solution TS15A for Intel...
# 5  AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 6  Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
#
#                                                  url   rating  price €  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  249.99
# 2  https://www.amazon.com/AMD-Ryzen-3700X-Prozess...  4.8 / 5  262.70
# 4  https://www.amazon.com/BXTS15A-Solution-Intel-...  4.4 / 5   28.91
# 5  https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...  4.8 / 5  209.99
# 6  https://www.amazon.com/gp/slredirect/picassoRe...  4.1 / 5  320.99
#
#   review_count    product
# 0          106  Processor
# 2       20.484  Processor
# 4           13  Processor
# 5       33.386  Processor
# 6          205  Processor

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1890 entries, 0 to 2129
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product title  1890 non-null   object
#  1   url            1890 non-null   object
#  2   rating         1890 non-null   object
#  3   price €        1890 non-null   object
#  4   review_count   1890 non-null   object
#  5   product        1890 non-null   object
# dtypes: object(6)
# memory usage: 103.4+ KB

# %%
#df["price"]= pd.to_numeric(df["price"])

# %%
df.to_csv('Processors_sample_cleaned.csv')

# %%
df.to_excel('Processors_sample_cleaned.xlsx')

# %%
df
# Out:
#                                           product title  \
# 0     MINIS FORUM Mini PC, Intel Celeron Processor J...
# 2     AMD Ryzen 7 3700X Prozessor, 4GHz AM4 36MB Cac...
# 4     INTEL BXTS15A Thermal Solution TS15A for Intel...
# 5     AMD Ryzen 5 3600 4, 2GHz AM4 35MB Cache Wraith...
# 6     Jumper 14 Zoll Laptop 8GB DDR4 256GB SSD, Inte...
# ...                                                 ...
# 2088  MoneyQiu HY-700 (50 g) > 3.14 W/m.K, CPU Therm...
# 2090                             MSI Gaming Motherboard
# 2091  ACEPC Mini PC, Intel Celeron J3455, AK1 4GB RA...
# 2092  Intel Nuc Mini Complete PC, Intel i5-10210U Qu...
# 2093  Intel Nuc Mini Complete PC, Intel Quad Core 4 ...
#
#                                                     url   rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  249.99
# 2     https://www.amazon.com/AMD-Ryzen-3700X-Prozess...  4.8 / 5  262.70
# 4     https://www.amazon.com/BXTS15A-Solution-Intel-...  4.4 / 5   28.91
# 5     https://www.amazon.com/AMD-Ryzen-3600-Wraith-S...  4.8 / 5  209.99
# 6     https://www.amazon.com/gp/slredirect/picassoRe...  4.1 / 5  320.99
# ...                                                 ...      ...      ...
# 2088  https://www.amazon.com/-/en/MoneyQiu-HY-700-Th...  4.5 / 5    16.99
# 2090  https://www.amazon.com/-/en/7C37-001R-MSI-Gami...  4.6 / 5   174.90
# 2091  https://www.amazon.com/-/en/Celeron-Windows-Bl...  3.8 / 5   159.90
# 2092  https://www.amazon.com/-/en/Complete-i5-10210U...  4.0 / 5   429.99
# 2093  https://www.amazon.com/-/en/Complete-2-30GHz-G...  4.7 / 5   469.00
#
#      review_count    product
# 0             106  Processor
# 2          20.484  Processor
# 4              13  Processor
# 5          33.386  Processor
# 6             205  Processor
# ...           ...        ...
# 2088          424  Processor
# 2090        2.467  Processor
# 2091          175  Processor
# 2092            2  Processor
# 2093           48  Processor
#
# [1569 rows x 6 columns]
