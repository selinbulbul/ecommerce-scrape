# %%
import numpy as np 
import pandas as pd 
import json
import pymysql

# %%
s = pd.read_csv('Combined.csv')

s
# Out:
#        Unnamed: 0                                      product title  \
# 0               0  Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1               1  Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2               2  Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3               3  Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4               4  Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# ...           ...                                                ...
# 14434       14434  Xiaomi Redmi 9 smartphone + headphones (16.59 ...
# 14435       14435  Samsung Galaxy S20 FE, Android SIM Free Smartp...
# 14436       14436  Outdoor Mobile Phone, IIIF150 B2021 Outdoor Sm...
# 14437       14437               SPC 2350116N Apolo Senior 5 16GB 1GB
# 14438       14438  Ulefone Note 9P Smartphone Without Contract, A...
#
#                                                      url   rating  price €  \
# 0      https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  284.00
# 1      https://www.amazon.com/gp/slredirect/picassoRe...  4.5 / 5  194.00
# 2      https://www.amazon.com/Canon-4000D-Camera-18-5...  4.7 / 5  438.00
# 3      https://www.amazon.com/Canon-Camera-2000D-18-5...  4.7 / 5  417.60
# 4      https://www.amazon.com/Canon-850D-DSLR-Digital...  4.7 / 5  849.00
# ...                                                  ...      ...      ...
# 14434  https://www.amazon.com/-/en/smartphone-headpho...  4.7 / 5   178.67
# 14435  https://www.amazon.com/-/en/Samsung-Android-Sm...  4.6 / 5   625.00
# 14436  https://www.amazon.com/-/en/gp/slredirect/pica...  4.4 / 5   179.99
# 14437  https://www.amazon.com/-/en/gp/slredirect/pica...  2.9 / 5    89.90
# 14438  https://www.amazon.com/-/en/gp/slredirect/pica...  4.3 / 5   154.99
#
#        review_count      product
# 0            23.000  DSLR_Camera
# 1           211.000  DSLR_Camera
# 2             1.637  DSLR_Camera
# 3             1.284  DSLR_Camera
# 4            28.000  DSLR_Camera
# ...             ...          ...
# 14434       288.000   Smartphone
# 14435         1.601   Smartphone
# 14436        64.000   Smartphone
# 14437       124.000   Smartphone
# 14438         2.383   Smartphone
#
# [14439 rows x 7 columns]

# %%
sqlEngine = create_engine('mysql+pymysql://root:Selin_1987@127.0.0.1/amazon', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

# This is for creating data base
sqlEngine.execute("CREATE DATABASE IF NOT EXISTS AMAZON") #create db
sqlEngine.execute("USE AMAZON") # select new db

tableName   = "search_summary"


try:
    frame = s.to_sql(tableName, dbConnection, if_exists='replace',index = False)

except ValueError as vx:
    print(vx)

except Exception as ex:   
    print(ex)

else:
    print("Table %s created successfully."%tableName);   

finally:
    dbConnection.close()
# Out:
# Table search_summary created successfully.
