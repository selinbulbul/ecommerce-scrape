# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## DSLR_Cameras

# %%
df= pd.read_csv("Sales_summary_final.csv")
# Out:
# C:\Users\Selin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#                                                     title InvoiceNo StockCode  \
# 0       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1       Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2       Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3               Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
# ...                                                   ...       ...       ...
# 554412  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78579472     71050
# 554413  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78577315     71050
# 554414  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78575941     71050
# 554415  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78573149     71050
# 554416  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78545182     71050
#
#         Quantity       InvoiceDate  CustomerID Country  \
# 0              4  09-12-2019 12:50     12680.0  France
# 1              6  09-12-2019 12:50     12680.0  France
# 2              8  09-12-2019 12:49     13113.0      DE
# 3             24  09-12-2019 12:49     13113.0      DE
# 4              8  09-12-2019 12:31     15804.0      DE
# ...          ...               ...         ...     ...
# 554412         4  29-11-2019 15:09     13521.0      DE
# 554413        11  18-11-2019 13:25     17811.0      DE
# 554414         3  13-11-2019 11:39     16438.0      DE
# 554415         3  27-10-2019 19:56     16438.0      DE
# 554416         6  28-02-2019 14:48     14046.0      DE
#
#                                                       url  rating  \
# 0       https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6
# 1       https://www.amazon.com/Lowepro-Photo-Hatchback...     4.5
# 2       https://www.amazon.com/Neewer-Display-Speedlit...     4.2
# 3       https://www.amazon.com/Lowepro-Fastpack-DSLR-C...     4.4
# 4       https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6
# ...                                                   ...     ...
# 554412  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554413  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554414  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554415  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554416  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
#
#         review_count   price product_type  total_sale        ASIN  \
# 0              15513   52.95  dslr camera      211.80  B00U2UZ40Y
# 1               1473   87.49  dslr camera      524.94  B008O8EGOQ
# 2                611   69.99  dslr camera      559.92  B00VE5HQ4I
# 3               1608  469.99  dslr camera    11279.76  B000YIWR8G
# 4              15513   52.95  dslr camera      423.60  B00U2UZ40Y
# ...              ...     ...          ...         ...         ...
# 554412           101   69.00   smartphone      276.00  B07R2J372X
# 554413           101   69.00   smartphone      759.00  B07R2J372X
# 554414           101   69.00   smartphone      207.00  B07R2J372X
# 554415           101   69.00   smartphone      207.00  B07R2J372X
# 554416           101   69.00   smartphone      414.00  B07R2J372X
#
#        invoice_date invoice_time
# 0        2019-12-09     12:50:00
# 1        2019-12-09     12:50:00
# 2        2019-12-09     12:49:00
# 3        2019-12-09     12:49:00
# 4        2019-12-09     12:31:00
# ...             ...          ...
# 554412   2019-11-29     15:09:00
# 554413   2019-11-18     13:25:00
# 554414   2019-11-13     11:39:00
# 554415   2019-10-27     19:56:00
# 554416   2019-02-28     14:48:00
#
# [554417 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554417 entries, 0 to 554416
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   title         554417 non-null  object
#  1   InvoiceNo     554417 non-null  object
#  2   StockCode     554417 non-null  object
#  3   Quantity      554417 non-null  int64
#  4   InvoiceDate   554417 non-null  object
#  5   CustomerID    415102 non-null  float64
#  6   Country       554417 non-null  object
#  7   url           554417 non-null  object
#  8   rating        554417 non-null  float64
#  9   review_count  554417 non-null  int64
#  10  price         554417 non-null  float64
#  11  product_type  554417 non-null  object
#  12  total_sale    554417 non-null  float64
#  13  ASIN          546019 non-null  object
#  14  invoice_date  554417 non-null  object
#  15  invoice_time  554417 non-null  object
# dtypes: float64(4), int64(2), object(10)
# memory usage: 67.7+ MB

# %%
df["invoice_date"]= pd.to_datetime(df["invoice_date"])

# %%
df['invoice_month'] = pd.to_datetime(df['invoice_date'], format='%Y-%m-%d').dt.strftime('%Y-%m')

# %%
df['month'] = pd.to_datetime(df['invoice_date'], format='%Y-%m-%d').dt.strftime('%m')

# %%
df['year'] = pd.to_datetime(df['invoice_date'], format='%Y-%m-%d').dt.strftime('%Y')

# %%
df['day_of_week'] = df['invoice_date'].dt.dayofweek

# %%
df
# Out:
#                                                     title InvoiceNo StockCode  \
# 0       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1       Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2       Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3               Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
# ...                                                   ...       ...       ...
# 554412  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78579472     71050
# 554413  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78577315     71050
# 554414  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78575941     71050
# 554415  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78573149     71050
# 554416  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78545182     71050
#
#         Quantity       InvoiceDate  CustomerID Country  \
# 0              4  09-12-2019 12:50     12680.0  France
# 1              6  09-12-2019 12:50     12680.0  France
# 2              8  09-12-2019 12:49     13113.0      DE
# 3             24  09-12-2019 12:49     13113.0      DE
# 4              8  09-12-2019 12:31     15804.0      DE
# ...          ...               ...         ...     ...
# 554412         4  29-11-2019 15:09     13521.0      DE
# 554413        11  18-11-2019 13:25     17811.0      DE
# 554414         3  13-11-2019 11:39     16438.0      DE
# 554415         3  27-10-2019 19:56     16438.0      DE
# 554416         6  28-02-2019 14:48     14046.0      DE
#
#                                                       url  rating  \
# 0       https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6
# 1       https://www.amazon.com/Lowepro-Photo-Hatchback...     4.5
# 2       https://www.amazon.com/Neewer-Display-Speedlit...     4.2
# 3       https://www.amazon.com/Lowepro-Fastpack-DSLR-C...     4.4
# 4       https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6
# ...                                                   ...     ...
# 554412  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554413  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554414  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554415  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554416  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
#
#         review_count   price product_type  total_sale        ASIN  \
# 0              15513   52.95  dslr camera      211.80  B00U2UZ40Y
# 1               1473   87.49  dslr camera      524.94  B008O8EGOQ
# 2                611   69.99  dslr camera      559.92  B00VE5HQ4I
# 3               1608  469.99  dslr camera    11279.76  B000YIWR8G
# 4              15513   52.95  dslr camera      423.60  B00U2UZ40Y
# ...              ...     ...          ...         ...         ...
# 554412           101   69.00   smartphone      276.00  B07R2J372X
# 554413           101   69.00   smartphone      759.00  B07R2J372X
# 554414           101   69.00   smartphone      207.00  B07R2J372X
# 554415           101   69.00   smartphone      207.00  B07R2J372X
# 554416           101   69.00   smartphone      414.00  B07R2J372X
#
#        invoice_date invoice_time invoice_month  day_of_week
# 0        2019-12-09     12:50:00       2019-12            0
# 1        2019-12-09     12:50:00       2019-12            0
# 2        2019-12-09     12:49:00       2019-12            0
# 3        2019-12-09     12:49:00       2019-12            0
# 4        2019-12-09     12:31:00       2019-12            0
# ...             ...          ...           ...          ...
# 554412   2019-11-29     15:09:00       2019-11            4
# 554413   2019-11-18     13:25:00       2019-11            0
# 554414   2019-11-13     11:39:00       2019-11            2
# 554415   2019-10-27     19:56:00       2019-10            6
# 554416   2019-02-28     14:48:00       2019-02            3
#
# [554417 rows x 18 columns]

# %%
df ["weekdays"] = df ['day_of_week'].apply(lambda x : "Monday" if x==0 else "Tuesday" if x == 1 else "Wednesday" if x == 2 else "Thursday" if x == 3 else "Friday" if x == 4 else "Saturday" if x == 5 else "Sunday") 
df
# Out:
#                                                     title InvoiceNo StockCode  \
# 0       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1       Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2       Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3               Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
# ...                                                   ...       ...       ...
# 554412  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78579472     71050
# 554413  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78577315     71050
# 554414  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78575941     71050
# 554415  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78573149     71050
# 554416  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78545182     71050
#
#         Quantity       InvoiceDate  CustomerID Country  \
# 0              4  09-12-2019 12:50     12680.0  France
# 1              6  09-12-2019 12:50     12680.0  France
# 2              8  09-12-2019 12:49     13113.0      DE
# 3             24  09-12-2019 12:49     13113.0      DE
# 4              8  09-12-2019 12:31     15804.0      DE
# ...          ...               ...         ...     ...
# 554412         4  29-11-2019 15:09     13521.0      DE
# 554413        11  18-11-2019 13:25     17811.0      DE
# 554414         3  13-11-2019 11:39     16438.0      DE
# 554415         3  27-10-2019 19:56     16438.0      DE
# 554416         6  28-02-2019 14:48     14046.0      DE
#
#                                                       url  rating  \
# 0       https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6
# 1       https://www.amazon.com/Lowepro-Photo-Hatchback...     4.5
# 2       https://www.amazon.com/Neewer-Display-Speedlit...     4.2
# 3       https://www.amazon.com/Lowepro-Fastpack-DSLR-C...     4.4
# 4       https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6
# ...                                                   ...     ...
# 554412  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554413  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554414  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554415  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554416  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
#
#         review_count   price product_type  total_sale        ASIN  \
# 0              15513   52.95  dslr camera      211.80  B00U2UZ40Y
# 1               1473   87.49  dslr camera      524.94  B008O8EGOQ
# 2                611   69.99  dslr camera      559.92  B00VE5HQ4I
# 3               1608  469.99  dslr camera    11279.76  B000YIWR8G
# 4              15513   52.95  dslr camera      423.60  B00U2UZ40Y
# ...              ...     ...          ...         ...         ...
# 554412           101   69.00   smartphone      276.00  B07R2J372X
# 554413           101   69.00   smartphone      759.00  B07R2J372X
# 554414           101   69.00   smartphone      207.00  B07R2J372X
# 554415           101   69.00   smartphone      207.00  B07R2J372X
# 554416           101   69.00   smartphone      414.00  B07R2J372X
#
#        invoice_date invoice_time invoice_month month  day_of_week   weekdays
# 0        2019-12-09     12:50:00       2019-12    12            0     Monday
# 1        2019-12-09     12:50:00       2019-12    12            0     Monday
# 2        2019-12-09     12:49:00       2019-12    12            0     Monday
# 3        2019-12-09     12:49:00       2019-12    12            0     Monday
# 4        2019-12-09     12:31:00       2019-12    12            0     Monday
# ...             ...          ...           ...   ...          ...        ...
# 554412   2019-11-29     15:09:00       2019-11    11            4     Friday
# 554413   2019-11-18     13:25:00       2019-11    11            0     Monday
# 554414   2019-11-13     11:39:00       2019-11    11            2  Wednesday
# 554415   2019-10-27     19:56:00       2019-10    10            6     Sunday
# 554416   2019-02-28     14:48:00       2019-02    02            3   Thursday
#
# [554417 rows x 20 columns]

# %% [markdown]
# ## 1s Task- What are the top 5 items generating the maximum revenue.

# %%
df_1= df.groupby(by ='title')['total_sale'].sum().reset_index()

# %%
df_1.sort_values(by = "total_sale", ascending=False)
# Out:
#                                                   title   total_sale
# 3275  Samsung Galaxy S9 G960U 64GB Unlocked 4G LTE P...  27327048.60
# 437   Apple iPhone X, 256GB, Silver - Fully Unlocked...  19288555.00
# 3268  Samsung Galaxy S10+ Plus 128GB+8GB RAM SM-G975...   9271575.00
# 1560  Intel Core i7-8700K Desktop Processor 6 Cores ...   9217596.44
# 704   Canon EF 17-40mm f/4L USM Ultra Wide Angle Zoo...   9009418.00
# ...                                                 ...          ...
# 359   Alto Notebook Stand with Wireless Keyboard. Ho...   -441689.12
# 13    (Renewed) Latest Microsoft Surface Pro 4 (2736...   -672610.16
# 2913  Power Bank 20000mAh Portable Charger Battery P...   -847457.42
# 3254  Samsung Electronics EV-NX500ZBMIUS NX500 28 MP...  -1491840.00
# 990   Dell Inspiron 11 3195, 2 in 1, 7th Gen AMD A9-...  -1825848.00
#
# [4188 rows x 2 columns]

# %% [markdown]
# ## 2nd Task- Daily customer buying pattern, looking complicated

# %%
plt.figure(figsize=(14, 10))
sb.lineplot(x = "invoice_date", y = 'Quantity', data = df, hue = 'product_type')
plt.ylim(ymax = 110, ymin = 0);

# %%
#customer buying pattern 1)type of products 2) quantity of purchase --> daily,weekly,monthly
df2_month = df.groupby(['product_type', 'invoice_month'])['Quantity'].sum().reset_index()
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-41c0cad8af23> in <module>
#       1 #customer buying pattern 1)type of products 2) quantity of purchase --> daily,weekly,monthly
#       2 df2_month = df.groupby(['product_type', 'invoice_month'])['Quantity'].sum().reset_index()
# ----> 3 df2
#
# NameError: name 'df2' is not defined

# %%
#monthly
fig_dims = (15, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sb.lineplot(x = 'invoice_month', y = 'Quantity', data = df2_month, hue = 'product_type', ax=ax )
# Out:
# <AxesSubplot:xlabel='invoice_month', ylabel='Quantity'>

# %%
#weekly
df2_week= df.groupby(['product_type', 'weekdays'])['Quantity'].sum().reset_index()
df2_week
# Out:
#    product_type   weekdays  Quantity
# 0   dslr camera     Friday    176287
# 1   dslr camera     Monday    138031
# 2   dslr camera   Saturday    171638
# 3   dslr camera     Sunday    212885
# 4   dslr camera   Thursday    152910
# 5   dslr camera  Wednesday     86226
# 6      keyboard     Friday    229297
# 7      keyboard     Monday    190081
# 8      keyboard   Saturday    234558
# 9      keyboard     Sunday    278335
# 10     keyboard   Thursday    204300
# 11     keyboard  Wednesday    113156
# 12      monitor     Friday     43935
# 13      monitor     Monday     35629
# 14      monitor   Saturday     42506
# 15      monitor     Sunday     44480
# 16      monitor   Thursday     30071
# 17      monitor  Wednesday     20568
# 18        mouse     Friday    185295
# 19        mouse     Monday    158973
# 20        mouse   Saturday    176568
# 21        mouse     Sunday    216080
# 22        mouse   Thursday    158157
# 23        mouse  Wednesday     85738
# 24    processor     Friday    227623
# 25    processor     Monday    112857
# 26    processor   Saturday    147002
# 27    processor     Sunday    183098
# 28    processor   Thursday    121214
# 29    processor  Wednesday     67629
# 30   smartphone     Friday    243688
# 31   smartphone     Monday    287904
# 32   smartphone   Saturday    268903
# 33   smartphone     Sunday    315461
# 34   smartphone   Thursday    212706
# 35   smartphone  Wednesday    118141

# %%
df2_week_2= df2_week.sort_values(by= "Quantity", ascending = False)
df2_week_2
# Out:
#    product_type   weekdays  Quantity
# 33   smartphone     Sunday    315461
# 31   smartphone     Monday    287904
# 9      keyboard     Sunday    278335
# 32   smartphone   Saturday    268903
# 30   smartphone     Friday    243688
# 8      keyboard   Saturday    234558
# 6      keyboard     Friday    229297
# 24    processor     Friday    227623
# 21        mouse     Sunday    216080
# 3   dslr camera     Sunday    212885
# 34   smartphone   Thursday    212706
# 10     keyboard   Thursday    204300
# 7      keyboard     Monday    190081
# 18        mouse     Friday    185295
# 27    processor     Sunday    183098
# 20        mouse   Saturday    176568
# 0   dslr camera     Friday    176287
# 2   dslr camera   Saturday    171638
# 19        mouse     Monday    158973
# 22        mouse   Thursday    158157
# 4   dslr camera   Thursday    152910
# 26    processor   Saturday    147002
# 1   dslr camera     Monday    138031
# 28    processor   Thursday    121214
# 35   smartphone  Wednesday    118141
# 11     keyboard  Wednesday    113156
# 25    processor     Monday    112857
# 5   dslr camera  Wednesday     86226
# 23        mouse  Wednesday     85738
# 29    processor  Wednesday     67629
# 15      monitor     Sunday     44480
# 12      monitor     Friday     43935
# 14      monitor   Saturday     42506
# 13      monitor     Monday     35629
# 16      monitor   Thursday     30071
# 17      monitor  Wednesday     20568

# %%
df2_week.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_type  36 non-null     object
#  1   weekdays      36 non-null     object
#  2   Quantity      36 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 992.0+ bytes

# %%
df2_week["weekdays"].value_counts()
# Out:
# Thursday     6
# Monday       6
# Friday       6
# Sunday       6
# Wednesday    6
# Saturday     6
# Name: weekdays, dtype: int64

# %%
order = ["Monday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

# %%
p = sb.catplot(x = 'weekdays', y = 'Quantity', kind="bar", data = df2_week_2, ax=ax, col= "product_type", col_wrap=3, palette="OrRd_r", order = order)
_, xlabels = plt.xticks()
p.set_xticklabels(xlabels, size=10)
# Out:
# C:\Users\Selin\anaconda3\lib\site-packages\seaborn\categorical.py:3772: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try barplot
#   warnings.warn(msg, UserWarning)

# %%
fig_dims = (15, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sb.lineplot(x = 'weekdays', y = 'Quantity', data = df2_week_2,palette="OrRd_r", hue= "product_type", ax= ax, marker='o');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-93a30887df7c> in <module>
#       1 fig_dims = (15, 10)
#       2 fig, ax = plt.subplots(figsize=fig_dims)
# ----> 3 sb.lineplot(x = 'weekdays', y = 'Quantity', data = df2_week_2,palette="OrRd_r", hue= "product_type", ax= ax, marker='o');
#
# NameError: name 'df2_week_2' is not defined

# %% [markdown]
# ## 3rd Task- There might be various factors that might play a role. In my last assignment, I used to observe people place a lot of orders in the lunch time. So, this kind of information would add values to our analysis.

# %%
#df["invoice_"]= pd.to_datetime(df["invoice_date"])

# %%
df
# Out:
#                                                     title InvoiceNo StockCode  \
# 0       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1       Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2       Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3               Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
# ...                                                   ...       ...       ...
# 554412  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78579472     71050
# 554413  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78577315     71050
# 554414  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78575941     71050
# 554415  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78573149     71050
# 554416  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78545182     71050
#
#         Quantity       InvoiceDate  CustomerID Country  \
# 0              4  09-12-2019 12:50     12680.0  France
# 1              6  09-12-2019 12:50     12680.0  France
# 2              8  09-12-2019 12:49     13113.0      DE
# 3             24  09-12-2019 12:49     13113.0      DE
# 4              8  09-12-2019 12:31     15804.0      DE
# ...          ...               ...         ...     ...
# 554412         4  29-11-2019 15:09     13521.0      DE
# 554413        11  18-11-2019 13:25     17811.0      DE
# 554414         3  13-11-2019 11:39     16438.0      DE
# 554415         3  27-10-2019 19:56     16438.0      DE
# 554416         6  28-02-2019 14:48     14046.0      DE
#
#                                                       url  rating  \
# 0       https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6
# 1       https://www.amazon.com/Lowepro-Photo-Hatchback...     4.5
# 2       https://www.amazon.com/Neewer-Display-Speedlit...     4.2
# 3       https://www.amazon.com/Lowepro-Fastpack-DSLR-C...     4.4
# 4       https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6
# ...                                                   ...     ...
# 554412  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554413  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554414  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554415  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554416  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
#
#         review_count   price product_type  total_sale        ASIN  \
# 0              15513   52.95  dslr camera      211.80  B00U2UZ40Y
# 1               1473   87.49  dslr camera      524.94  B008O8EGOQ
# 2                611   69.99  dslr camera      559.92  B00VE5HQ4I
# 3               1608  469.99  dslr camera    11279.76  B000YIWR8G
# 4              15513   52.95  dslr camera      423.60  B00U2UZ40Y
# ...              ...     ...          ...         ...         ...
# 554412           101   69.00   smartphone      276.00  B07R2J372X
# 554413           101   69.00   smartphone      759.00  B07R2J372X
# 554414           101   69.00   smartphone      207.00  B07R2J372X
# 554415           101   69.00   smartphone      207.00  B07R2J372X
# 554416           101   69.00   smartphone      414.00  B07R2J372X
#
#        invoice_date invoice_time
# 0        2019-12-09     12:50:00
# 1        2019-12-09     12:50:00
# 2        2019-12-09     12:49:00
# 3        2019-12-09     12:49:00
# 4        2019-12-09     12:31:00
# ...             ...          ...
# 554412   2019-11-29     15:09:00
# 554413   2019-11-18     13:25:00
# 554414   2019-11-13     11:39:00
# 554415   2019-10-27     19:56:00
# 554416   2019-02-28     14:48:00
#
# [554417 rows x 16 columns]

# %%
df['invoice_hour'] = pd.to_datetime(df['invoice_time'], format='%H:%M:%S').dt.strftime('%H')

# %%
df.head()
# Out:
#                                                title InvoiceNo StockCode  \
# 0  Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1  Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2  Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3          Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4  Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
#
#    Quantity       InvoiceDate  CustomerID Country  \
# 0         4  09-12-2019 12:50     12680.0  France
# 1         6  09-12-2019 12:50     12680.0  France
# 2         8  09-12-2019 12:49     13113.0      DE
# 3        24  09-12-2019 12:49     13113.0      DE
# 4         8  09-12-2019 12:31     15804.0      DE
#
#                                                  url  rating  review_count  \
# 0  https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6         15513
# 1  https://www.amazon.com/Lowepro-Photo-Hatchback...     4.5          1473
# 2  https://www.amazon.com/Neewer-Display-Speedlit...     4.2           611
# 3  https://www.amazon.com/Lowepro-Fastpack-DSLR-C...     4.4          1608
# 4  https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6         15513
#
#     price product_type  total_sale        ASIN invoice_date invoice_time  \
# 0   52.95  dslr camera      211.80  B00U2UZ40Y   2019-12-09     12:50:00
# 1   87.49  dslr camera      524.94  B008O8EGOQ   2019-12-09     12:50:00
# 2   69.99  dslr camera      559.92  B00VE5HQ4I   2019-12-09     12:49:00
# 3  469.99  dslr camera    11279.76  B000YIWR8G   2019-12-09     12:49:00
# 4   52.95  dslr camera      423.60  B00U2UZ40Y   2019-12-09     12:31:00
#
#   invoice_hour
# 0           12
# 1           12
# 2           12
# 3           12
# 4           12

# %%
df3= df.groupby(['product_type', 'invoice_hour'])['Quantity'].sum().reset_index()
df3
# Out:
#    product_type invoice_hour  Quantity
# 0   dslr camera           07      2646
# 1   dslr camera           08     29123
# 2   dslr camera           09     75239
# 3   dslr camera           10    122484
# 4   dslr camera           11    122822
# ..          ...          ...       ...
# 80   smartphone           16     78073
# 81   smartphone           17     46950
# 82   smartphone           18     16433
# 83   smartphone           19      6635
# 84   smartphone           20      2398
#
# [85 rows x 3 columns]

# %%
#style
sb.set(rc={'figure.figsize':(15,8)})
sb.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
sb.set(style="ticks", context="talk")
plt.style.use("dark_background")
sb.set_style("dark")
#from matplotlib.ticker import PercentFormatter
#import matplotlib.ticker as mtick
#clrs = ['#83bffb','#fdfdb1', '#fcac59', 'orange']  palette= clrs,
fig, ax = plt.subplots()
ax = sb.pointplot(data = df3, x = 'invoice_hour', y = 'Quantity', hue = 'product_type')

plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title

ax.set(title = 'Product hourly distribution',ylabel= 'mean(Quantity)');

# %%
#style
sb.set(rc={'figure.figsize':(15,8)})
sb.set_context("paper", font_scale=1, rc={"lines.linewidth": 2.5})
sb.set(style="ticks", context="talk")
plt.style.use("dark_background")
sb.set_style("dark")

fig, ax = plt.subplots()
#ax.yaxis.set_major_formatter(mtick.PercentFormatter(1000.0)) 
ax = sb.pointplot(data = df3, x = 'invoice_hour', y = 'Quantity', color = "Blue");

   
#plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
#plt.setp(ax.get_legend().get_title(), fontsize='16') # for legend title;
ax.set(title = 'Hourly customer behaviour',ylabel= 'mean(Quantity)')

# label points on the plot
# Out:
# [Text(0.5, 1.0, 'Hourly customer behaviour'), Text(0, 0.5, 'mean(Quantity)')]

# %% [markdown]
# ## 4th Task- Is there any specific days when the sales have been unusually high / low and what could be the possible reasons? (This is a very generic question and most of the time you have to make an educated guess with a supporting data###)

# %%
df.head()
# Out:
#                                                title InvoiceNo StockCode  \
# 0  Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1  Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2  Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3          Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4  Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
#
#    Quantity       InvoiceDate  CustomerID Country  \
# 0         4  09-12-2019 12:50     12680.0  France
# 1         6  09-12-2019 12:50     12680.0  France
# 2         8  09-12-2019 12:49     13113.0      DE
# 3        24  09-12-2019 12:49     13113.0      DE
# 4         8  09-12-2019 12:31     15804.0      DE
#
#                                                  url  rating  review_count  \
# 0  https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6         15513
# 1  https://www.amazon.com/Lowepro-Photo-Hatchback...     4.5          1473
# 2  https://www.amazon.com/Neewer-Display-Speedlit...     4.2           611
# 3  https://www.amazon.com/Lowepro-Fastpack-DSLR-C...     4.4          1608
# 4  https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6         15513
#
#     price product_type  total_sale        ASIN invoice_date invoice_time  \
# 0   52.95  dslr camera      211.80  B00U2UZ40Y   2019-12-09     12:50:00
# 1   87.49  dslr camera      524.94  B008O8EGOQ   2019-12-09     12:50:00
# 2   69.99  dslr camera      559.92  B00VE5HQ4I   2019-12-09     12:49:00
# 3  469.99  dslr camera    11279.76  B000YIWR8G   2019-12-09     12:49:00
# 4   52.95  dslr camera      423.60  B00U2UZ40Y   2019-12-09     12:31:00
#
#   invoice_hour
# 0           12
# 1           12
# 2           12
# 3           12
# 4           12

# %%
pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.1.0-py2.py3-none-any.whl (20.6 MB)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six in c:\users\selin\anaconda3\lib\site-packages (from plotly) (1.15.0)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.1.0 tenacity-8.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
df4 = df.groupby("invoice_date")['Quantity'].sum().reset_index()
df4
# Out:
#     invoice_date  Quantity
# 0     2018-12-01     28360
# 1     2018-12-02     32749
# 2     2018-12-03     16885
# 3     2018-12-05     16886
# 4     2018-12-06     22504
# ..           ...       ...
# 300   2019-12-05     45650
# 301   2019-12-06     31158
# 302   2019-12-07     40097
# 303   2019-12-08     36367
# 304   2019-12-09     94293
#
# [305 rows x 2 columns]

# %%
import plotly.express as px

#df = px.data.stocks()
fig = px.line(df4, x='invoice_date', y="Quantity")
fig.show()

# %%
df4.sort_values (by = "Quantity", ascending = "False" )
# Out:
#     invoice_date  Quantity
# 152   2019-06-14    -12710
# 48    2019-02-06      2110
# 78    2019-03-13      2850
# 54    2019-02-13      2854
# 18    2018-12-22      3273
# ..           ...       ...
# 300   2019-12-05     45650
# 248   2019-10-05     48052
# 282   2019-11-14     48737
# 32    2019-01-18     83561
# 304   2019-12-09     94293
#
# [305 rows x 2 columns]

# %%
df4.sort_values ("Quantity", ascending= False )
# Out:
#     invoice_date  Quantity
# 304   2019-12-09     94293
# 32    2019-01-18     83561
# 282   2019-11-14     48737
# 248   2019-10-05     48052
# 300   2019-12-05     45650
# ..           ...       ...
# 18    2018-12-22      3273
# 54    2019-02-13      2854
# 78    2019-03-13      2850
# 48    2019-02-06      2110
# 152   2019-06-14    -12710
#
# [305 rows x 2 columns]

# %% [markdown]
# ## 5th Task- What do you think about the customers? Are they individuals or wholesalers?

# %%
df.head()
# Out:
#                                                title InvoiceNo StockCode  \
# 0  Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1  Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2  Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3          Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4  Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
#
#    Quantity       InvoiceDate  CustomerID Country  \
# 0         4  09-12-2019 12:50     12680.0  France
# 1         6  09-12-2019 12:50     12680.0  France
# 2         8  09-12-2019 12:49     13113.0      DE
# 3        24  09-12-2019 12:49     13113.0      DE
# 4         8  09-12-2019 12:31     15804.0      DE
#
#                                                  url  rating  review_count  \
# 0  https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6         15513
# 1  https://www.amazon.com/Lowepro-Photo-Hatchback...     4.5          1473
# 2  https://www.amazon.com/Neewer-Display-Speedlit...     4.2           611
# 3  https://www.amazon.com/Lowepro-Fastpack-DSLR-C...     4.4          1608
# 4  https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6         15513
#
#     price product_type  total_sale        ASIN invoice_date invoice_time  \
# 0   52.95  dslr camera      211.80  B00U2UZ40Y   2019-12-09     12:50:00
# 1   87.49  dslr camera      524.94  B008O8EGOQ   2019-12-09     12:50:00
# 2   69.99  dslr camera      559.92  B00VE5HQ4I   2019-12-09     12:49:00
# 3  469.99  dslr camera    11279.76  B000YIWR8G   2019-12-09     12:49:00
# 4   52.95  dslr camera      423.60  B00U2UZ40Y   2019-12-09     12:31:00
#
#   invoice_hour
# 0           12
# 1           12
# 2           12
# 3           12
# 4           12

# %%
df5 = df.groupby(["InvoiceNo", "invoice_date"])["Quantity"].sum().reset_index()
df5
# Out:
#        InvoiceNo invoice_date  Quantity
# 0       78536365   2018-12-01        52
# 1       78536366   2018-12-01        12
# 2       78536367   2018-12-01        77
# 3       78536368   2018-12-01        12
# 4       78536369   2018-12-01         3
# ...          ...          ...       ...
# 28181   78581586   2019-12-09        10
# 28182   78581587   2019-12-09        44
# 28183  78A563185   2019-08-12         1
# 28184  78A563186   2019-08-12         1
# 28185  78A563187   2019-08-12         1
#
# [28186 rows x 3 columns]

# %% [markdown]
# ## 6th Task- Highest number of orders and highest money spent: Can you explore a bit on this.. like which countries / customers.

# %%
df.head()
# Out:
#                                                title InvoiceNo StockCode  \
# 0  Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1  Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2  Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3          Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4  Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
#
#    Quantity       InvoiceDate  CustomerID Country  \
# 0         4  09-12-2019 12:50     12680.0  France
# 1         6  09-12-2019 12:50     12680.0  France
# 2         8  09-12-2019 12:49     13113.0      DE
# 3        24  09-12-2019 12:49     13113.0      DE
# 4         8  09-12-2019 12:31     15804.0      DE
#
#                                                  url  rating  review_count  \
# 0  https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6         15513
# 1  https://www.amazon.com/Lowepro-Photo-Hatchback...     4.5          1473
# 2  https://www.amazon.com/Neewer-Display-Speedlit...     4.2           611
# 3  https://www.amazon.com/Lowepro-Fastpack-DSLR-C...     4.4          1608
# 4  https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6         15513
#
#     price product_type  total_sale        ASIN invoice_date invoice_time  \
# 0   52.95  dslr camera      211.80  B00U2UZ40Y   2019-12-09     12:50:00
# 1   87.49  dslr camera      524.94  B008O8EGOQ   2019-12-09     12:50:00
# 2   69.99  dslr camera      559.92  B00VE5HQ4I   2019-12-09     12:49:00
# 3  469.99  dslr camera    11279.76  B000YIWR8G   2019-12-09     12:49:00
# 4   52.95  dslr camera      423.60  B00U2UZ40Y   2019-12-09     12:31:00
#
#   invoice_month  day_of_week weekdays
# 0       2019 12            0   Monday
# 1       2019 12            0   Monday
# 2       2019 12            0   Monday
# 3       2019 12            0   Monday
# 4       2019 12            0   Monday

# %%
df6 = df.groupby(["CustomerID", "Country"])["Quantity"].sum().reset_index()
# Out:
#       CustomerID      Country  Quantity
# 1698     14646.0  Netherlands    205535
# 1888     14911.0      Ireland     83711
# 3017     16446.0           DE     80997
# 57       12415.0    Australia     80119
# 0        12346.0           DE     74215
# ...          ...          ...       ...
# 4107     17956.0           DE         1
# 3228     16742.0           DE         1
# 2549     15802.0           DE         1
# 4022     17846.0           DE         1
# 2567     15823.0           DE         1
#
# [4347 rows x 3 columns]

# %% [markdown]
# ##### highest number of orders

# %%
#Customerwise most of the orders are coming from : 
df6.sort_values("Quantity", ascending = False)
# Out:
#       CustomerID      Country  Quantity
# 1698     14646.0  Netherlands    205535
# 1888     14911.0      Ireland     83711
# 3017     16446.0           DE     80997
# 57       12415.0    Australia     80119
# 0        12346.0           DE     74215
# ...          ...          ...       ...
# 4107     17956.0           DE         1
# 3228     16742.0           DE         1
# 2549     15802.0           DE         1
# 4022     17846.0           DE         1
# 2567     15823.0           DE         1
#
# [4347 rows x 3 columns]

# %%
#Countrywise most of the order quantity coming from: 
df6_country= df6.groupby(["Country"])["Quantity"].sum().reset_index()
df6_country.sort_values("Quantity", ascending= False)
# Out:
#                  Country  Quantity
# 9                     DE   4444231
# 23           Netherlands    209202
# 16               Ireland    146474
# 33                    UK    123792
# 13                France    115695
# 0              Australia     87033
# 31                Sweden     36760
# 32           Switzerland     31308
# 30                 Spain     30061
# 19                 Japan     26828
# 3                Belgium     23672
# 24                Norway     19855
# 26              Portugal     17114
# 12               Finland     11691
# 6        Channel Islands      9728
# 10               Denmark      8709
# 18                 Italy      8325
# 7                 Cyprus      6816
# 29             Singapore      5629
# 1                Austria      5075
# 17                Israel      4211
# 25                Poland      3963
# 5                 Canada      2839
# 34                   USA      2607
# 15               Iceland      2542
# 36               Unknown      1878
# 14                Greece      1651
# 22                 Malta      1036
# 35  United Arab Emirates      1035
# 8         Czech Republic       682
# 21             Lithuania       676
# 11    European Community       520
# 20               Lebanon       402
# 27                   RSA       362
# 4                 Brazil       356
# 2                Bahrain       268
# 28          Saudi Arabia        80

# %%
# Which country orders more 
df6.value_counts("Country")
# Out:
# Country
# DE                      3921
# UK                        94
# France                    87
# Spain                     30
# Belgium                   25
# Switzerland               21
# Portugal                  19
# Italy                     14
# Finland                   12
# Austria                   11
# Norway                    10
# Netherlands                9
# Australia                  9
# Denmark                    9
# Channel Islands            9
# Cyprus                     8
# Sweden                     8
# Japan                      8
# Poland                     6
# USA                        4
# Canada                     4
# Greece                     4
# Unknown                    4
# Israel                     3
# Ireland                    3
# Malta                      2
# Bahrain                    2
# United Arab Emirates       2
# Czech Republic             1
# Lithuania                  1
# Lebanon                    1
# RSA                        1
# Saudi Arabia               1
# Singapore                  1
# Brazil                     1
# Iceland                    1
# European Community         1
# dtype: int64

# %% [markdown]
# ##### highest number of sales

# %%
df.head(1)
# Out:
#                                                title InvoiceNo StockCode  \
# 0  Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
#
#    Quantity       InvoiceDate  CustomerID Country  \
# 0         4  09-12-2019 12:50     12680.0  France
#
#                                                  url  rating  review_count  \
# 0  https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6         15513
#
#    price product_type  total_sale        ASIN invoice_date invoice_time  \
# 0  52.95  dslr camera       211.8  B00U2UZ40Y   2019-12-09     12:50:00
#
#   invoice_month  day_of_week weekdays
# 0       2019 12            0   Monday

# %%
df6_sales = df.groupby(["CustomerID", "Country"])["total_sale"].sum().reset_index()
df6_sales.sort_values("total_sale", ascending= False)
# Out:
#       CustomerID      Country   total_sale
# 1698     14646.0  Netherlands  21664738.30
# 1888     14911.0      Ireland   9340224.33
# 57       12415.0    Australia   9244349.18
# 3737     17450.0           DE   9061246.11
# 4210     18102.0           DE   8114485.22
# ...          ...          ...          ...
# 361      12789.0  Netherlands        35.97
# 2647     15940.0           DE        31.96
# 4333     18268.0           DE        23.98
# 2882     16257.0           DE        22.98
# 833      13452.0           DE        13.98
#
# [4347 rows x 3 columns]

# %%
df6_sales_CustomerID = df6_sales.groupby(["CustomerID"])["total_sale"].sum().reset_index()
df6_sales_CustomerID.sort_values("total_sale", ascending= False)
# Out:
#       CustomerID   total_sale
# 1690     14646.0  21664738.30
# 1880     14911.0   9340224.33
# 55       12415.0   9244349.18
# 3729     17450.0   9061246.11
# 4202     18102.0   8114485.22
# ...          ...          ...
# 353      12789.0        35.97
# 2639     15940.0        31.96
# 4325     18268.0        23.98
# 2874     16257.0        22.98
# 825      13452.0        13.98
#
# [4339 rows x 2 columns]

# %%
df6_sales_CustomerID["CustomerID"].value_counts()
# Out:
# 14546.0    1
# 17827.0    1
# 13482.0    1
# 14377.0    1
# 13762.0    1
#           ..
# 13130.0    1
# 16085.0    1
# 13514.0    1
# 13198.0    1
# 13297.0    1
# Name: CustomerID, Length: 4339, dtype: int64

# %%
df6_sales_country = df6_sales.groupby(["Country"])["total_sale"].sum().reset_index()
df6_sales_country.sort_values("total_sale", ascending= False)
# Out:
#                  Country    total_sale
# 9                     DE  4.567605e+08
# 23           Netherlands  2.200264e+07
# 16               Ireland  1.530354e+07
# 13                France  1.149104e+07
# 33                    UK  1.139257e+07
# 0              Australia  9.848729e+06
# 31                Sweden  4.373181e+06
# 19                 Japan  3.078620e+06
# 30                 Spain  2.754244e+06
# 32           Switzerland  2.730491e+06
# 3                Belgium  2.474314e+06
# 24                Norway  1.755610e+06
# 26              Portugal  1.707936e+06
# 12               Finland  1.108042e+06
# 6        Channel Islands  9.950680e+05
# 18                 Italy  9.713113e+05
# 7                 Cyprus  8.877748e+05
# 29             Singapore  7.530347e+05
# 10               Denmark  6.722136e+05
# 17                Israel  4.833599e+05
# 1                Austria  4.480337e+05
# 25                Poland  3.892792e+05
# 34                   USA  2.725382e+05
# 5                 Canada  2.277556e+05
# 15               Iceland  2.151716e+05
# 36               Unknown  1.936429e+05
# 14                Greece  1.381092e+05
# 22                 Malta  1.340011e+05
# 8         Czech Republic  8.854790e+04
# 35  United Arab Emirates  8.243556e+04
# 11    European Community  6.188509e+04
# 21             Lithuania  6.145114e+04
# 4                 Brazil  4.518014e+04
# 20               Lebanon  4.476415e+04
# 27                   RSA  2.722044e+04
# 2                Bahrain  1.906146e+04
# 28          Saudi Arabia  7.346600e+03

# %% [markdown]
# ## 7th Task- Top 5 countries generating the max revenue. (Can you create a map of them - this is optional and good to have)

# %%
df6_sales_country = df6_sales.groupby(["Country"])["total_sale"].sum().reset_index()
df6_sales_country.sort_values("total_sale", ascending= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3a1b61eb91b1> in <module>
# ----> 1 df6_sales_country = df6_sales.groupby(["Country"])["total_sale"].sum().reset_index()
#       2 df6_sales_country.sort_values("total_sale", ascending= False)
#
# NameError: name 'df6_sales' is not defined

# %%
conda install -c conda-forge geopandas
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
df6_sales_country.rename(columns ={"Country": "name"})

# %%
import geopandas as gpd#import locally saved file
revenue = df6_sales_country
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-50-eb4caa185725> in <module>
# ----> 1 import geopandas as gpd#import locally saved file
#       2 revenue = df6_sales_country
#       3 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
#price = df["review_count"].replace('.','DOT').replace(',','.').replace('DOT',',')
#price

# %%
df = df.drop(columns="Unnamed: 0")

# %%
df['review_count'] = df['review_count'].astype(str)
#df['review_count'] = df['review_count'].str.replace('.0', '')
#df

# %%
#df["review_count"] = df["review_count"].replace({'.':','}, regex = True)
#df

# %%
#df['review_count'] = df['review_count'].str.replace('.', ',')

# %%
#df

# %%
#df["review_count"] = df["review_count"].replace({'\xa0':''}, regex = True)
#df

# %%
#df_1= df.loc[(df.review_count.str.find('.') == 1), 'review_count']

# %%
#df_1

# %%
#df["review_count"]= pd.to_numeric(df["review_count"])

# %% [markdown]
# ## 8th Task- How about excluding the host country ('Germany in this case) to do the same analysis.

# %%
df8= df6_sales_country.sort_values("total_sale", ascending= False). reset_index()
df8 = df8.drop(columns="index")

# %%
df8.drop(0)
# Out:
#                  Country   total_sale
# 1            Netherlands  22002641.59
# 2                Ireland  15303539.90
# 3                 France  11491039.72
# 4                     UK  11392570.92
# 5              Australia   9848728.98
# 6                 Sweden   4373181.09
# 7                  Japan   3078620.22
# 8                  Spain   2754244.31
# 9            Switzerland   2730490.74
# 10               Belgium   2474313.89
# 11                Norway   1755610.04
# 12              Portugal   1707935.69
# 13               Finland   1108041.74
# 14       Channel Islands    995068.01
# 15                 Italy    971311.33
# 16                Cyprus    887774.82
# 17             Singapore    753034.67
# 18               Denmark    672213.56
# 19                Israel    483359.89
# 20               Austria    448033.73
# 21                Poland    389279.19
# 22                   USA    272538.18
# 23                Canada    227755.64
# 24               Iceland    215171.57
# 25               Unknown    193642.93
# 26                Greece    138109.24
# 27                 Malta    134001.11
# 28        Czech Republic     88547.90
# 29  United Arab Emirates     82435.56
# 30    European Community     61885.09
# 31             Lithuania     61451.14
# 32                Brazil     45180.14
# 33               Lebanon     44764.15
# 34                   RSA     27220.44
# 35               Bahrain     19061.46
# 36          Saudi Arabia      7346.60

# %% [markdown]
# ## 9th Task- Quarterly revenue ( How about creating a plotly express animation)

# %% [markdown]
# #### What is the overall sales trend?

# %%
df.columns
# Out:
# Index(['title', 'InvoiceNo', 'StockCode', 'Quantity', 'InvoiceDate',
#        'CustomerID', 'Country', 'url', 'rating', 'review_count', 'price',
#        'product_type', 'total_sale', 'ASIN', 'invoice_date', 'invoice_time',
#        'invoice_month', 'day_of_week', 'weekdays'],
#       dtype='object')

# %%
results = df.groupby("invoice_month").sum()
months = [month for month, df in df.groupby("invoice_month")]
plt.figure(figsize=(15,5))
plt.plot(months, results["total_sale"], color ="#b80045")
plt.xticks (months, rotation = "vertical", size =8)
plt.ylabel ("Sales in €")
plt.xlabel("Month")
plt.show();

# %% [markdown]
# #### What is the overall MoM, QoQ and YoY growth?

# %%
df.columns
# Out:
# Index(['title', 'InvoiceNo', 'StockCode', 'Quantity', 'InvoiceDate',
#        'CustomerID', 'Country', 'url', 'rating', 'review_count', 'price',
#        'product_type', 'total_sale', 'ASIN', 'invoice_date', 'invoice_time',
#        'invoice_month', 'day_of_week', 'weekdays'],
#       dtype='object')

# %%
df8_MoM_1= df.groupby(["invoice_month", "month"])["total_sale"].sum().reset_index()
df8_MoM_1
# Out:
#    invoice_month month    total_sale
# 0        2018-12    12  4.031045e+07
# 1        2019-01    01  3.681758e+07
# 2        2019-02    02  2.796792e+07
# 3        2019-03    03  3.907113e+07
# 4        2019-04    04  3.191926e+07
# 5        2019-05    05  3.960880e+07
# 6        2019-06    06  4.203511e+07
# 7        2019-07    07  4.532769e+07
# 8        2019-08    08  4.699824e+07
# 9        2019-09    09  6.069154e+07
# 10       2019-10    10  6.569315e+07
# 11       2019-11    11  7.970551e+07
# 12       2019-12    12  3.068230e+07

# %%
df8_MoM_1['Last_Month'] = np.roll(df8_MoM_1['total_sale'],1)

# %%
df8_MoM_1
# Out:
#    invoice_month month    total_sale    Last_Month
# 0        2018-12    12  4.031045e+07  3.068230e+07
# 1        2019-01    01  3.681758e+07  4.031045e+07
# 2        2019-02    02  2.796792e+07  3.681758e+07
# 3        2019-03    03  3.907113e+07  2.796792e+07
# 4        2019-04    04  3.191926e+07  3.907113e+07
# 5        2019-05    05  3.960880e+07  3.191926e+07
# 6        2019-06    06  4.203511e+07  3.960880e+07
# 7        2019-07    07  4.532769e+07  4.203511e+07
# 8        2019-08    08  4.699824e+07  4.532769e+07
# 9        2019-09    09  6.069154e+07  4.699824e+07
# 10       2019-10    10  6.569315e+07  6.069154e+07
# 11       2019-11    11  7.970551e+07  6.569315e+07
# 12       2019-12    12  3.068230e+07  7.970551e+07

# %%
df8_MoM_1['Growth'] = (df8_MoM_1['total_sale']/df8_MoM_1['Last_Month'])-1

# %%
p = sb.catplot(x = 'invoice_month', y = 'Growth', kind="bar", data = df8_MoM_1, ax=ax, color ="#b80045")
_, xlabels = plt.xticks()
p.set_xticklabels(xlabels, size=10, rotation = "vertical")
# Out:
# C:\Users\Selin\anaconda3\lib\site-packages\seaborn\categorical.py:3772: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try barplot
#   warnings.warn(msg, UserWarning)

# %%
results = df8_MoM_1.groupby("invoice_month").sum()
months = [month for month, df8_MoM_1 in df8_MoM_1.groupby("invoice_month")]
plt.figure(figsize=(15,5))
plt.bar(months, results["Growth"], color ="#b80045")
plt.xticks (months, rotation = "vertical", size =8)
plt.ylabel ("% Growth")
plt.xlabel("Month")
plt.show();

# %% [markdown]
# #### Quarterly Growth

# %%
df8_MoM_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   invoice_month  13 non-null     object
#  1   month          13 non-null     object
#  2   total_sale     13 non-null     float64
#  3   Last_Month     13 non-null     float64
#  4   Growth         13 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 648.0+ bytes

# %%
df8_MoM_1["month"]= pd.to_numeric(df8_MoM_1["month"])

# %%
df8_MoM1_2 = df8_MoM_1.drop(0)

# %%
df8_MoM1_2
# Out:
#    invoice_month  month    total_sale    Last_Month    Growth
# 1        2019-01      1  3.681758e+07  4.031045e+07 -0.086649
# 2        2019-02      2  2.796792e+07  3.681758e+07 -0.240365
# 3        2019-03      3  3.907113e+07  2.796792e+07  0.396998
# 4        2019-04      4  3.191926e+07  3.907113e+07 -0.183048
# 5        2019-05      5  3.960880e+07  3.191926e+07  0.240906
# 6        2019-06      6  4.203511e+07  3.960880e+07  0.061257
# 7        2019-07      7  4.532769e+07  4.203511e+07  0.078329
# 8        2019-08      8  4.699824e+07  4.532769e+07  0.036855
# 9        2019-09      9  6.069154e+07  4.699824e+07  0.291358
# 10       2019-10     10  6.569315e+07  6.069154e+07  0.082410
# 11       2019-11     11  7.970551e+07  6.569315e+07  0.213300
# 12       2019-12     12  3.068230e+07  7.970551e+07 -0.615054

# %%
df8_MoM1_2 ["Quarter"] = df8_MoM1_2 ['month'].apply(lambda x : "Q1" if x<4 else "Q2" if x < 7 else "Q3" if x < 10 else "Q4") 
df8_MoM1_2
# Out:
#    invoice_month  month    total_sale    Last_Month    Growth Quarter
# 1        2019-01      1  3.681758e+07  4.031045e+07 -0.086649      Q1
# 2        2019-02      2  2.796792e+07  3.681758e+07 -0.240365      Q1
# 3        2019-03      3  3.907113e+07  2.796792e+07  0.396998      Q1
# 4        2019-04      4  3.191926e+07  3.907113e+07 -0.183048      Q2
# 5        2019-05      5  3.960880e+07  3.191926e+07  0.240906      Q2
# 6        2019-06      6  4.203511e+07  3.960880e+07  0.061257      Q2
# 7        2019-07      7  4.532769e+07  4.203511e+07  0.078329      Q3
# 8        2019-08      8  4.699824e+07  4.532769e+07  0.036855      Q3
# 9        2019-09      9  6.069154e+07  4.699824e+07  0.291358      Q3
# 10       2019-10     10  6.569315e+07  6.069154e+07  0.082410      Q4
# 11       2019-11     11  7.970551e+07  6.569315e+07  0.213300      Q4
# 12       2019-12     12  3.068230e+07  7.970551e+07 -0.615054      Q4

# %%
# add a row here at the begining 0
df8_MoM_3= df8_MoM1_2.groupby(["Quarter"])["total_sale"].sum().reset_index()
df8_MoM_3
# Out:
#   Quarter    total_sale
# 0      Q1  1.038566e+08
# 1      Q2  1.135632e+08
# 2      Q3  1.530175e+08
# 3      Q4  1.760810e+08

# %%
#df8_MoM_3.loc[len(df.index)] = [0, 0]

# %%
df8_MoM_3['Last_Month'] = np.roll(df8_MoM_3['total_sale'],1)

# %%
#df8_MoM_3 = df8_MoM_3.drop(554417)

# %%
df8_MoM_3['Growth'] = (df8_MoM_3['total_sale']/df8_MoM_3['Last_Month'])-1

# %%
df8_MoM_3
# Out:
#   Quarter    total_sale    Last_Month    Growth
# 0      Q1  1.038566e+08  1.760810e+08 -0.410177
# 1      Q2  1.135632e+08  1.038566e+08  0.093461
# 2      Q3  1.530175e+08  1.135632e+08  0.347422
# 3      Q4  1.760810e+08  1.530175e+08  0.150725

# %%
df8_MoM_3 = df8_MoM_3.drop(0)

# %%
p = sb.catplot(x = 'Quarter', y = 'Growth', kind="bar", data = df8_MoM_3, ax=ax, color ="#b80045")
_, xlabels = plt.xticks()
p.set_xticklabels(xlabels, size=10, rotation = "vertical")
# Out:
# C:\Users\Selin\anaconda3\lib\site-packages\seaborn\categorical.py:3772: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try barplot
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 10th Task- What are the best-selling and the second best-selling products in every category? (Revenue wise).(Hint: explore SQL Window function)

# %%
df.head(3)
# Out:
#                                                title InvoiceNo StockCode  \
# 0  Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1  Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2  Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
#
#    Quantity       InvoiceDate  CustomerID Country  \
# 0         4  09-12-2019 12:50     12680.0  France
# 1         6  09-12-2019 12:50     12680.0  France
# 2         8  09-12-2019 12:49     13113.0      DE
#
#                                                  url  rating  review_count  \
# 0  https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6         15513
# 1  https://www.amazon.com/Lowepro-Photo-Hatchback...     4.5          1473
# 2  https://www.amazon.com/Neewer-Display-Speedlit...     4.2           611
#
#    price product_type  total_sale        ASIN invoice_date invoice_time  \
# 0  52.95  dslr camera      211.80  B00U2UZ40Y   2019-12-09     12:50:00
# 1  87.49  dslr camera      524.94  B008O8EGOQ   2019-12-09     12:50:00
# 2  69.99  dslr camera      559.92  B00VE5HQ4I   2019-12-09     12:49:00
#
#   invoice_month month  day_of_week weekdays
# 0       2019-12    12            0   Monday
# 1       2019-12    12            0   Monday
# 2       2019-12    12            0   Monday

# %%
df["product_type"].value_counts()
# Out:
# smartphone     134109
# keyboard       128524
# mouse          101728
# dslr camera     96531
# processor       71551
# monitor         21974
# Name: product_type, dtype: int64

# %% [markdown]
# ### DSLR Camera

# %%
df_DSLR = df[(df["product_type"] == "dslr camera")]
df_DSLR
# Out:
#                                                    title InvoiceNo StockCode  \
# 0      Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1      Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2      Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3              Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4      Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
# ...                                                  ...       ...       ...
# 96526  YONGNUO YN35mm F2 Lens 1:2 AF/MF Wide-Angle Fi...  78540288     21468
# 96527  YONGNUO YN35mm F2 Lens 1:2 AF/MF Wide-Angle Fi...  78539728     21468
# 96528  YONGNUO YN35mm F2 Lens 1:2 AF/MF Wide-Angle Fi...  78539580     21468
# 96529  YONGNUO YN35mm F2 Lens 1:2 AF/MF Wide-Angle Fi...  78537826     21468
# 96530  YONGNUO YN35mm F2 Lens 1:2 AF/MF Wide-Angle Fi...  78537133     21468
#
#        Quantity       InvoiceDate  CustomerID Country  \
# 0             4  09-12-2019 12:50     12680.0  France
# 1             6  09-12-2019 12:50     12680.0  France
# 2             8  09-12-2019 12:49     13113.0      DE
# 3            24  09-12-2019 12:49     13113.0      DE
# 4             8  09-12-2019 12:31     15804.0      DE
# ...         ...               ...         ...     ...
# 96526         1  06-01-2019 12:45     17634.0      DE
# 96527         6  21-12-2018 14:26     16270.0      DE
# 96528         6  20-12-2018 12:51     15312.0      DE
# 96529         1  08-12-2018 14:38     15581.0      DE
# 96530         1  05-12-2018 12:29     18156.0      DE
#
#                                                      url  rating  \
# 0      https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6
# 1      https://www.amazon.com/Lowepro-Photo-Hatchback...     4.5
# 2      https://www.amazon.com/Neewer-Display-Speedlit...     4.2
# 3      https://www.amazon.com/Lowepro-Fastpack-DSLR-C...     4.4
# 4      https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6
# ...                                                  ...     ...
# 96526  https://www.amazon.com/dp/B01L1JCKRY/ref=sr_1_...     4.1
# 96527  https://www.amazon.com/dp/B01L1JCKRY/ref=sr_1_...     4.1
# 96528  https://www.amazon.com/dp/B01L1JCKRY/ref=sr_1_...     4.1
# 96529  https://www.amazon.com/dp/B01L1JCKRY/ref=sr_1_...     4.1
# 96530  https://www.amazon.com/dp/B01L1JCKRY/ref=sr_1_...     4.1
#
#        review_count   price product_type  total_sale        ASIN invoice_date  \
# 0             15513   52.95  dslr camera      211.80  B00U2UZ40Y   2019-12-09
# 1              1473   87.49  dslr camera      524.94  B008O8EGOQ   2019-12-09
# 2               611   69.99  dslr camera      559.92  B00VE5HQ4I   2019-12-09
# 3              1608  469.99  dslr camera    11279.76  B000YIWR8G   2019-12-09
# 4             15513   52.95  dslr camera      423.60  B00U2UZ40Y   2019-12-09
# ...             ...     ...          ...         ...         ...          ...
# 96526           262   98.00  dslr camera       98.00  B01L1JCKRY   2019-01-06
# 96527           262   98.00  dslr camera      588.00  B01L1JCKRY   2018-12-21
# 96528           262   98.00  dslr camera      588.00  B01L1JCKRY   2018-12-20
# 96529           262   98.00  dslr camera       98.00  B01L1JCKRY   2018-12-08
# 96530           262   98.00  dslr camera       98.00  B01L1JCKRY   2018-12-05
#
#       invoice_time invoice_month month  day_of_week   weekdays
# 0         12:50:00       2019-12    12            0     Monday
# 1         12:50:00       2019-12    12            0     Monday
# 2         12:49:00       2019-12    12            0     Monday
# 3         12:49:00       2019-12    12            0     Monday
# 4         12:31:00       2019-12    12            0     Monday
# ...            ...           ...   ...          ...        ...
# 96526     12:45:00       2019-01    01            6     Sunday
# 96527     14:26:00       2018-12    12            4     Friday
# 96528     12:51:00       2018-12    12            3   Thursday
# 96529     14:38:00       2018-12    12            5   Saturday
# 96530     12:29:00       2018-12    12            2  Wednesday
#
# [96531 rows x 20 columns]

# %%
df_DSLR_2 = df_DSLR .groupby("title")["total_sale"].sum().reset_index()
df_DSLR_2.sort_values ("total_sale", ascending = False)
# Out:
#                                                  title  total_sale
# 120  Canon EF 17-40mm f/4L USM Ultra Wide Angle Zoo...  9009418.00
# 132  Canon EOS 5D Mark III 22.3 MP Full Frame CMOS ...  6296677.35
# 577  Nikon D3500 W/ AF-P DX NIKKOR 18-55mm f/3.5-5....  4666360.50
# 770  Sony 50mm f/1.8 Mid-Range Lens for Sony E Moun...  4516692.00
# 772  Sony Alpha 7 II E-mount interchangeable lens m...  3731262.00
# ..                                                 ...         ...
# 556  Nikon AF-P DX NIKKOR 18-55mm f/3.5-5.6G Lens f...  -157560.00
# 686           Professional Mini Ball Head Camera Mount  -206179.80
# 410  Moza Aircross 2 with Carrying Case, 3-Axis Han...  -235410.00
# 123  Canon EF 70-200mm f/2.8L IS III USM Lens for C...  -417368.00
# 733  Samsung Electronics EV-NX500ZBMIUS NX500 28 MP... -1491840.00
#
# [892 rows x 2 columns]

# %% [markdown]
# ### Smartphone

# %%
df_smartphone = df[(df["product_type"] == "smartphone")]
df_smartphone
# Out:
#                                                     title InvoiceNo StockCode  \
# 420308  BONAOK Wireless Bluetooth Karaoke Microphone,3...  78581492     23202
# 420309  BONAOK Wireless Bluetooth Karaoke Microphone,3...  78581439     23202
# 420310  BONAOK Wireless Bluetooth Karaoke Microphone,3...  78581421     23202
# 420311  BONAOK Wireless Bluetooth Karaoke Microphone,3...  78581413     23202
# 420312  BONAOK Wireless Bluetooth Karaoke Microphone,3...  78581412     23202
# ...                                                   ...       ...       ...
# 554412  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78579472     71050
# 554413  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78577315     71050
# 554414  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78575941     71050
# 554415  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78573149     71050
# 554416  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78545182     71050
#
#         Quantity       InvoiceDate  CustomerID Country  \
# 420308         2  09-12-2019 10:03         NaN      DE
# 420309         1  08-12-2019 16:30         NaN      DE
# 420310        19  08-12-2019 15:23     15898.0      DE
# 420311        10  08-12-2019 14:39     16833.0      DE
# 420312         5  08-12-2019 14:38     14415.0      DE
# ...          ...               ...         ...     ...
# 554412         4  29-11-2019 15:09     13521.0      DE
# 554413        11  18-11-2019 13:25     17811.0      DE
# 554414         3  13-11-2019 11:39     16438.0      DE
# 554415         3  27-10-2019 19:56     16438.0      DE
# 554416         6  28-02-2019 14:48     14046.0      DE
#
#                                                       url  rating  \
# 420308  https://www.amazon.com/gp/slredirect/picassoRe...     4.4
# 420309  https://www.amazon.com/gp/slredirect/picassoRe...     4.4
# 420310  https://www.amazon.com/gp/slredirect/picassoRe...     4.4
# 420311  https://www.amazon.com/gp/slredirect/picassoRe...     4.4
# 420312  https://www.amazon.com/gp/slredirect/picassoRe...     4.4
# ...                                                   ...     ...
# 554412  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554413  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554414  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554415  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
# 554416  https://www.amazon.com/dp/B07R2J372X/ref=sr_1_...     4.2
#
#         review_count  price product_type  total_sale        ASIN invoice_date  \
# 420308          9068  30.99   smartphone       61.98         NaN   2019-12-09
# 420309          9068  30.99   smartphone       30.99         NaN   2019-12-08
# 420310          9068  30.99   smartphone      588.81         NaN   2019-12-08
# 420311          9068  30.99   smartphone      309.90         NaN   2019-12-08
# 420312          9068  30.99   smartphone      154.95         NaN   2019-12-08
# ...              ...    ...          ...         ...         ...          ...
# 554412           101  69.00   smartphone      276.00  B07R2J372X   2019-11-29
# 554413           101  69.00   smartphone      759.00  B07R2J372X   2019-11-18
# 554414           101  69.00   smartphone      207.00  B07R2J372X   2019-11-13
# 554415           101  69.00   smartphone      207.00  B07R2J372X   2019-10-27
# 554416           101  69.00   smartphone      414.00  B07R2J372X   2019-02-28
#
#        invoice_time invoice_month month  day_of_week   weekdays
# 420308     10:03:00       2019-12    12            0     Monday
# 420309     16:30:00       2019-12    12            6     Sunday
# 420310     15:23:00       2019-12    12            6     Sunday
# 420311     14:39:00       2019-12    12            6     Sunday
# 420312     14:38:00       2019-12    12            6     Sunday
# ...             ...           ...   ...          ...        ...
# 554412     15:09:00       2019-11    11            4     Friday
# 554413     13:25:00       2019-11    11            0     Monday
# 554414     11:39:00       2019-11    11            2  Wednesday
# 554415     19:56:00       2019-10    10            6     Sunday
# 554416     14:48:00       2019-02    02            3   Thursday
#
# [134109 rows x 20 columns]

# %%
df_smartphone = df_smartphone .groupby("title")["total_sale"].sum().reset_index()
df_smartphone.sort_values ("total_sale", ascending = False)
# Out:
#                                                  title   total_sale
# 693  Samsung Galaxy S9 G960U 64GB Unlocked 4G LTE P...  27327048.60
# 103  Apple iPhone X, 256GB, Silver - Fully Unlocked...  19288555.00
# 686  Samsung Galaxy S10+ Plus 128GB+8GB RAM SM-G975...   9271575.00
# 904  Xiaomi Redmi Note 8 Pro 64GB, 6GB RAM 6.53" LT...   7802654.00
# 285  Fitbit Versa 2 Health and Fitness Smartwatch w...   7245560.05
# ..                                                 ...          ...
# 143  Blackview BV5500 pro- Rugged Cell Phone Unlock...    -94312.14
# 710  Security Camera Outdoor, Victure 1080P WiFi Ho...    -96463.92
# 589  Pixel Wireless Lavalier Microphone - Compact W...   -156767.94
# 854  VIIGER Multipurpose Canvas Belt Pouch with Bel...   -328367.56
# 615  Power Bank 20000mAh Portable Charger Battery P...   -847457.42
#
# [990 rows x 2 columns]

# %% [markdown]
# ### Keyboard

# %%
df_keyboard = df[(df["product_type"] == "keyboard")]
df_keyboard
# Out:
#                                                     title InvoiceNo StockCode  \
# 96531   NPET T20 One-Handed Gaming Keyboard, RGB Backl...  78581492    85014B
# 96532   Rii Wireless Office Keyboard and Mouse Combo R...  78581492    90003C
# 96533   Perixx Perimice-718R Wireless 2.4 GHz Ergonomi...  78581489     22182
# 96534   Perixx Perimice-718R Wireless 2.4 GHz Ergonomi...  78581443     22182
# 96535   Rechargeable Wireless Keyboard Mouse, Jelly Co...  78581439    85170D
# ...                                                   ...       ...       ...
# 225050  CORSAIR Gaming Performance FPS MOBA Keycap Kit...  78556813     23252
# 225051  CORSAIR Gaming Performance FPS MOBA Keycap Kit...  78556781     23252
# 225052  CORSAIR Gaming Performance FPS MOBA Keycap Kit...  78556778     23252
# 225053  CORSAIR Gaming Performance FPS MOBA Keycap Kit...  78556751     23252
# 225054  CORSAIR Gaming Performance FPS MOBA Keycap Kit...  78556473     23252
#
#         Quantity       InvoiceDate  CustomerID Country  \
# 96531          1  09-12-2019 10:03         NaN      DE
# 96532          1  09-12-2019 10:03         NaN      DE
# 96533         24  09-12-2019 09:46     16954.0      DE
# 96534         24  08-12-2019 16:58     13026.0      DE
# 96535          2  08-12-2019 16:30         NaN      DE
# ...          ...               ...         ...     ...
# 225050         1  14-06-2019 17:28         NaN      DE
# 225051         4  14-06-2019 12:47     13384.0      DE
# 225052         3  14-06-2019 12:41     16712.0      DE
# 225053        48  14-06-2019 12:09     15251.0      DE
# 225054         3  12-06-2019 12:00     17265.0      DE
#
#                                                       url  rating  \
# 96531   https://www.amazon.com/gp/slredirect/picassoRe...     4.3
# 96532   https://www.amazon.com/gp/slredirect/picassoRe...     4.1
# 96533   https://www.amazon.com/gp/slredirect/picassoRe...     4.0
# 96534   https://www.amazon.com/gp/slredirect/picassoRe...     4.0
# 96535   https://www.amazon.com/gp/slredirect/picassoRe...     4.5
# ...                                                   ...     ...
# 225050  https://www.amazon.com/dp/B01N0EUKT7/ref=sr_1_...     4.5
# 225051  https://www.amazon.com/dp/B01N0EUKT7/ref=sr_1_...     4.5
# 225052  https://www.amazon.com/dp/B01N0EUKT7/ref=sr_1_...     4.5
# 225053  https://www.amazon.com/dp/B01N0EUKT7/ref=sr_1_...     4.5
# 225054  https://www.amazon.com/dp/B01N0EUKT7/ref=sr_1_...     4.5
#
#         review_count  price product_type  total_sale        ASIN invoice_date  \
# 96531           1947  22.99     keyboard       22.99         NaN   2019-12-09
# 96532            155  19.99     keyboard       19.99         NaN   2019-12-09
# 96533            470  24.99     keyboard      599.76         NaN   2019-12-09
# 96534            470  24.99     keyboard      599.76         NaN   2019-12-08
# 96535            375  38.99     keyboard       77.98         NaN   2019-12-08
# ...              ...    ...          ...         ...         ...          ...
# 225050           538  16.07     keyboard       16.07  B01N0EUKT7   2019-06-14
# 225051           538  16.07     keyboard       64.28  B01N0EUKT7   2019-06-14
# 225052           538  16.07     keyboard       48.21  B01N0EUKT7   2019-06-14
# 225053           538  16.07     keyboard      771.36  B01N0EUKT7   2019-06-14
# 225054           538  16.07     keyboard       48.21  B01N0EUKT7   2019-06-12
#
#        invoice_time invoice_month month  day_of_week   weekdays
# 96531      10:03:00       2019-12    12            0     Monday
# 96532      10:03:00       2019-12    12            0     Monday
# 96533      09:46:00       2019-12    12            0     Monday
# 96534      16:58:00       2019-12    12            6     Sunday
# 96535      16:30:00       2019-12    12            6     Sunday
# ...             ...           ...   ...          ...        ...
# 225050     17:28:00       2019-06    06            4     Friday
# 225051     12:47:00       2019-06    06            4     Friday
# 225052     12:41:00       2019-06    06            4     Friday
# 225053     12:09:00       2019-06    06            4     Friday
# 225054     12:00:00       2019-06    06            2  Wednesday
#
# [128524 rows x 20 columns]

# %%
df_keyboard = df_keyboard .groupby("title")["total_sale"].sum().reset_index()
df_keyboard.sort_values ("total_sale", ascending = False)
# Out:
#                                                  title  total_sale
# 57   Acer Aspire 5 A515-55-56VK, 15.6" Full HD IPS ...  6410683.44
# 646           Microsoft Natural Ergonomic Desktop 7000  4603028.28
# 659  Microsoft Surface Pro 6 (Intel Core i5, 8GB RA...  4068854.79
# 48   ASUS Chromebook Flip C302 2-In-1 Laptop- 12.5”...  2803849.02
# 821  Razer BlackWidow Chroma V2: Esports Gaming Key...  2077288.00
# ..                                                 ...         ...
# 14   2019 14" Laptop - Intel Quad-Core Atom x5 E800...   -81646.45
# 889  Samsung Galaxy Tab A 10.1 2019 Case with Keybo...  -230227.20
# 83   AmazonBasics PC Programmable Gaming Mouse | Ad...  -251431.93
# 76   Alto Notebook Stand with Wireless Keyboard. Ho...  -441689.12
# 202  Dell Inspiron 11 3195, 2 in 1, 7th Gen AMD A9-...  -912924.00
#
# [1094 rows x 2 columns]

# %% [markdown]
# ### Mouse

# %%
df_mouse= df[(df["product_type"] == "mouse")]
df_mouse
# Out:
#                                                     title InvoiceNo StockCode  \
# 247029  Computer Wireless Mouse, WISFOX Wireless Ergon...  78581587     23255
# 247030  Rechargeable Wireless Mouse for Laptop, Cimete...  78581580     22908
# 247031  Computer Wireless Mouse, WISFOX Wireless Ergon...  78581578     23255
# 247032  Rechargeable Wireless Mouse for Laptop, Cimete...  78581578     22908
# 247033  Wireless Bluetooth Mouse,Cimetech Rechargeable...  78581538     21670
# ...                                                   ...       ...       ...
# 348752    Wow!Pad LFR48 11.5" x 12.5" Graphite Gaming Pad  78537823     35967
# 348753    Wow!Pad LFR48 11.5" x 12.5" Graphite Gaming Pad  78537434     35967
# 348754    Wow!Pad LFR48 11.5" x 12.5" Graphite Gaming Pad  78537237     35967
# 348755    Wow!Pad LFR48 11.5" x 12.5" Graphite Gaming Pad  78536975     35967
# 348756    Wow!Pad LFR48 11.5" x 12.5" Graphite Gaming Pad  78536592     35967
#
#         Quantity       InvoiceDate  CustomerID  Country  \
# 247029         4  09-12-2019 12:50     12680.0   France
# 247030         2  09-12-2019 12:20     12748.0       DE
# 247031        12  09-12-2019 12:16     12713.0       UK
# 247032        12  09-12-2019 12:16     12713.0       UK
# 247033         1  09-12-2019 11:34     14446.0       DE
# ...          ...               ...         ...      ...
# 348752         1  08-12-2018 14:25         NaN       DE
# 348753         1  06-12-2018 16:57         NaN       DE
# 348754         1  06-12-2018 09:58         NaN       DE
# 348755        24  03-12-2018 14:04     14911.0  Ireland
# 348756         3  01-12-2018 17:06         NaN       DE
#
#                                                       url  rating  \
# 247029  https://www.amazon.com/gp/slredirect/picassoRe...     4.6
# 247030  https://www.amazon.com/gp/slredirect/picassoRe...     4.3
# 247031  https://www.amazon.com/gp/slredirect/picassoRe...     4.6
# 247032  https://www.amazon.com/gp/slredirect/picassoRe...     4.3
# 247033  https://www.amazon.com/gp/slredirect/picassoRe...     4.3
# ...                                                   ...     ...
# 348752  https://www.amazon.com/dp/B000F3IS8I/ref=sr_1_...     4.3
# 348753  https://www.amazon.com/dp/B000F3IS8I/ref=sr_1_...     4.3
# 348754  https://www.amazon.com/dp/B000F3IS8I/ref=sr_1_...     4.3
# 348755  https://www.amazon.com/dp/B000F3IS8I/ref=sr_1_...     4.3
# 348756  https://www.amazon.com/dp/B000F3IS8I/ref=sr_1_...     4.3
#
#         review_count  price product_type  total_sale        ASIN invoice_date  \
# 247029           614  12.99        mouse       51.96         NaN   2019-12-09
# 247030          2034  13.99        mouse       27.98         NaN   2019-12-09
# 247031           614  12.99        mouse      155.88         NaN   2019-12-09
# 247032          2034  13.99        mouse      167.88         NaN   2019-12-09
# 247033          2034  22.99        mouse       22.99         NaN   2019-12-09
# ...              ...    ...          ...         ...         ...          ...
# 348752           262  16.99        mouse       16.99  B000F3IS8I   2018-12-08
# 348753           262  16.99        mouse       16.99  B000F3IS8I   2018-12-06
# 348754           262  16.99        mouse       16.99  B000F3IS8I   2018-12-06
# 348755           262  16.99        mouse      407.76  B000F3IS8I   2018-12-03
# 348756           262  16.99        mouse       50.97  B000F3IS8I   2018-12-01
#
#        invoice_time invoice_month month  day_of_week  weekdays
# 247029     12:50:00       2019-12    12            0    Monday
# 247030     12:20:00       2019-12    12            0    Monday
# 247031     12:16:00       2019-12    12            0    Monday
# 247032     12:16:00       2019-12    12            0    Monday
# 247033     11:34:00       2019-12    12            0    Monday
# ...             ...           ...   ...          ...       ...
# 348752     14:25:00       2018-12    12            5  Saturday
# 348753     16:57:00       2018-12    12            3  Thursday
# 348754     09:58:00       2018-12    12            3  Thursday
# 348755     14:04:00       2018-12    12            0    Monday
# 348756     17:06:00       2018-12    12            5  Saturday
#
# [101728 rows x 20 columns]

# %%
df_mouse = df_mouse .groupby("title")["total_sale"].sum().reset_index()
df_mouse.sort_values ("total_sale", ascending = False)
# Out:
#                                                  title  total_sale
# 694  VicTsing Computer Wireless Mouse, 2.4G Portabl...  3062389.12
# 362  Logitech G502 Proteus Core Tunable Gaming Mous...  2382361.74
# 382  Logitech Performance MX Wireless Mouse (DISCON...  1250409.16
# 538        ROCCAT KONE Pure Ultra Gaming Mouse - White   879723.95
# 363  Logitech G502 Proteus Spectrum RGB Tunable Gam...   793540.02
# ..                                                 ...         ...
# 649  Stranger Things Mouse Pad Customized, Premium ...   -16800.00
# 215  GORILLA STIMPACK 3XL Huge Mouse Pads Oversized...   -19595.10
# 298  Jiale 2 Pack Professional LED Optical 7200 DPI...   -23988.00
# 79   BYBART Mouse Pad, Black White Marble Stripe Mo...   -30665.13
# 72   BENGOO Gaming Mouse Wired, USB Ergonomic Compu...   -41999.28
#
# [789 rows x 2 columns]

# %% [markdown]
# ### Processor

# %%
df_processor= df[(df["product_type"] == "processor")]
df_processor
# Out:
#                                                     title InvoiceNo StockCode  \
# 348757  Innovation Cooling Graphite Thermal Pad – Alte...  78581586     21217
# 348758  Innovation Cooling Graphite Thermal Pad – Alte...  78581538     21328
# 348759  Innovation Cooling Graphite Thermal Pad – Alte...  78581498     21217
# 348760  Innovation Cooling Graphite Thermal Pad – Alte...  78581498     21328
# 348761  Innovation Cooling Graphite Thermal Pad – Alte...  78581492     21328
# ...                                                   ...       ...       ...
# 420303  Pwr Long 6Ft 2 Prong Polarized Power Cord for ...  78551291    72225C
# 420304  Pwr Long 6Ft 2 Prong Polarized Power Cord for ...  78545859    72225C
# 420305  Pwr Long 6Ft 2 Prong Polarized Power Cord for ...  78542534    72225C
# 420306  Pwr Long 6Ft 2 Prong Polarized Power Cord for ...  78539647    72225C
# 420307  Pwr Long 6Ft 2 Prong Polarized Power Cord for ...  78539437    72225C
#
#         Quantity       InvoiceDate  CustomerID Country  \
# 348757        24  09-12-2019 12:49     13113.0      DE
# 348758         1  09-12-2019 11:34     14446.0      DE
# 348759         3  09-12-2019 10:26         NaN      DE
# 348760         1  09-12-2019 10:26         NaN      DE
# 348761         2  09-12-2019 10:03         NaN      DE
# ...          ...               ...         ...     ...
# 420303        96  27-04-2019 14:26     14298.0      DE
# 420304        24  07-03-2019 14:10     15498.0      DE
# 420305        24  28-01-2019 13:27     13707.0      DE
# 420306        24  20-12-2018 16:08     15460.0      DE
# 420307        24  17-12-2018 14:54         NaN      DE
#
#                                                       url  rating  \
# 348757  https://www.amazon.com/gp/slredirect/picassoRe...     4.4
# 348758  https://www.amazon.com/gp/slredirect/picassoRe...     4.4
# 348759  https://www.amazon.com/gp/slredirect/picassoRe...     4.4
# 348760  https://www.amazon.com/gp/slredirect/picassoRe...     4.4
# 348761  https://www.amazon.com/gp/slredirect/picassoRe...     4.4
# ...                                                   ...     ...
# 420303  https://www.amazon.com/dp/B00STTPAP4/ref=sr_1_...     4.7
# 420304  https://www.amazon.com/dp/B00STTPAP4/ref=sr_1_...     4.7
# 420305  https://www.amazon.com/dp/B00STTPAP4/ref=sr_1_...     4.7
# 420306  https://www.amazon.com/dp/B00STTPAP4/ref=sr_1_...     4.7
# 420307  https://www.amazon.com/dp/B00STTPAP4/ref=sr_1_...     4.7
#
#         review_count  price product_type  total_sale        ASIN invoice_date  \
# 348757          1683  12.95    processor      310.80         NaN   2019-12-09
# 348758          1683   9.97    processor        9.97         NaN   2019-12-09
# 348759          1683  12.95    processor       38.85         NaN   2019-12-09
# 348760          1683   9.97    processor        9.97         NaN   2019-12-09
# 348761          1683   9.97    processor       19.94         NaN   2019-12-09
# ...              ...    ...          ...         ...         ...          ...
# 420303           137   7.99    processor      767.04  B00STTPAP4   2019-04-27
# 420304           137   7.99    processor      191.76  B00STTPAP4   2019-03-07
# 420305           137   7.99    processor      191.76  B00STTPAP4   2019-01-28
# 420306           137   7.99    processor      191.76  B00STTPAP4   2018-12-20
# 420307           137   7.99    processor      191.76  B00STTPAP4   2018-12-17
#
#        invoice_time invoice_month month  day_of_week  weekdays
# 348757     12:49:00       2019-12    12            0    Monday
# 348758     11:34:00       2019-12    12            0    Monday
# 348759     10:26:00       2019-12    12            0    Monday
# 348760     10:26:00       2019-12    12            0    Monday
# 348761     10:03:00       2019-12    12            0    Monday
# ...             ...           ...   ...          ...       ...
# 420303     14:26:00       2019-04    04            5  Saturday
# 420304     14:10:00       2019-03    03            3  Thursday
# 420305     13:27:00       2019-01    01            0    Monday
# 420306     16:08:00       2018-12    12            3  Thursday
# 420307     14:54:00       2018-12    12            0    Monday
#
# [71551 rows x 20 columns]

# %%
df_processor = df_processor .groupby("title")["total_sale"].sum().reset_index()
df_processor.sort_values ("total_sale", ascending = False).head(2)
# Out:
#                                                  title  total_sale
# 259  Intel Core i7-8700K Desktop Processor 6 Cores ...  9217596.44
# 40   AMD Ryzen 5 3600X 6-Core, 12-Thread Unlocked D...  5858727.34

# %% [markdown]
# ### Monitor

# %% [markdown]
# ## 11th Task- New Customer registrations per month for the year 2019.You can consider MIN("InvoiceDate") as the registration date.

# %%
df11 = df.groupby("CustomerID")
df11

# %%
df.head()
# Out:
#                                                title InvoiceNo StockCode  \
# 0  Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1  Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2  Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3          Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4  Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
#
#    Quantity       InvoiceDate  CustomerID Country  \
# 0         4  09-12-2019 12:50     12680.0  France
# 1         6  09-12-2019 12:50     12680.0  France
# 2         8  09-12-2019 12:49     13113.0      DE
# 3        24  09-12-2019 12:49     13113.0      DE
# 4         8  09-12-2019 12:31     15804.0      DE
#
#                                                  url  rating  review_count  \
# 0  https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6         15513
# 1  https://www.amazon.com/Lowepro-Photo-Hatchback...     4.5          1473
# 2  https://www.amazon.com/Neewer-Display-Speedlit...     4.2           611
# 3  https://www.amazon.com/Lowepro-Fastpack-DSLR-C...     4.4          1608
# 4  https://www.amazon.com/Fujifilm-Instax-Mini-Ra...     4.6         15513
#
#    ...  product_type total_sale        ASIN invoice_date invoice_time  \
# 0  ...   dslr camera     211.80  B00U2UZ40Y   2019-12-09     12:50:00
# 1  ...   dslr camera     524.94  B008O8EGOQ   2019-12-09     12:50:00
# 2  ...   dslr camera     559.92  B00VE5HQ4I   2019-12-09     12:49:00
# 3  ...   dslr camera   11279.76  B000YIWR8G   2019-12-09     12:49:00
# 4  ...   dslr camera     423.60  B00U2UZ40Y   2019-12-09     12:31:00
#
#   invoice_month month day_of_week  weekdays  year
# 0       2019-12    12           0    Monday  2019
# 1       2019-12    12           0    Monday  2019
# 2       2019-12    12           0    Monday  2019
# 3       2019-12    12           0    Monday  2019
# 4       2019-12    12           0    Monday  2019
#
# [5 rows x 21 columns]

# %%
df["year"]= pd.to_numeric(df["year"])

# %%
df11 = df[(df['year'] > 2018)]

# %%
df11 = df11[["invoice_date", "CustomerID","month"]]

# %%
df11.head()
# Out:
#   invoice_date  CustomerID month
# 0   2019-12-09     12680.0    12
# 1   2019-12-09     12680.0    12
# 2   2019-12-09     13113.0    12
# 3   2019-12-09     13113.0    12
# 4   2019-12-09     15804.0    12

# %%
df11 = df11.drop_duplicates('CustomerID',keep='first')

# %%
df11
# Out:
#        invoice_date  CustomerID month
# 0        2019-12-09     12680.0    12
# 2        2019-12-09     13113.0    12
# 4        2019-12-09     15804.0    12
# 7        2019-12-09     17581.0    12
# 9        2019-12-09     12748.0    12
# ...             ...         ...   ...
# 531491   2019-02-15     16073.0    02
# 533668   2019-02-04     17291.0    02
# 534571   2019-02-01     15940.0    02
# 538717   2019-01-19     14090.0    01
# 539745   2019-01-17     15316.0    01
#
# [4221 rows x 3 columns]

# %%
df11_2 = df11["invoice_date"].value_counts()

# %%
df11_2.plot()
# Out:
# <AxesSubplot:>

# %%
df11_3 = df11.groupby("month").count()
df11_3 = df11_3.reset_index()
# df11_3 ["month] lambda x : "Monday" if x==0 else "Tuesday" if x == 1 else
df11_3
# Out:
#    month  invoice_date  CustomerID
# 0     01           110         110
# 1     02           126         126
# 2     03           186         186
# 3     04           158         158
# 4     05           182         182
# 5     06           190         190
# 6     07           194         194
# 7     08           203         203
# 8     09           420         420
# 9     10           679         679
# 10    11          1222        1222
# 11    12           551         550

# %%
sb.barplot(x = "CustomerID", y="month", data = df11_3 )
# Out:
# <AxesSubplot:xlabel='CustomerID', ylabel='month'>

# %% [markdown]
# ## 12th Task-	Can you create a plot showing the growth rate of new customers for the same period (2019).

# %%
df11_3['Last_Growth'] = np.roll(df11_3['CustomerID'],1)

# %%
df11_3['C_Growth'] = (df11_3['CustomerID']/df11_3['Last_Growth'])-1

# %%
df11_3
# Out:
#    month  invoice_date  CustomerID  Customer_Growth  Last_Growth  C_Growth
# 0     01           110         110              550          550 -0.800000
# 1     02           126         126              110          110  0.145455
# 2     03           186         186              126          126  0.476190
# 3     04           158         158              186          186 -0.150538
# 4     05           182         182              158          158  0.151899
# 5     06           190         190              182          182  0.043956
# 6     07           194         194              190          190  0.021053
# 7     08           203         203              194          194  0.046392
# 8     09           420         420              203          203  1.068966
# 9     10           679         679              420          420  0.616667
# 10    11          1222        1222              679          679  0.799705
# 11    12           551         550             1222         1222 -0.549918

# %%
df11_3 = df11_3.drop(0)

# %%
plt.figure(figsize=(10,6))
p = sb.catplot(x = 'month', y = 'C_Growth', kind="bar", data = df11_3, color ="#b80045")
_, xlabels = plt.xticks()
p.set_xticklabels(xlabels, size=10)
plt.xlabel ("Months")
plt.ylabel("% Customer Growth")
plt.title("Customer Growth per Month", size=18)
# Out:
# Text(0.5, 1.0, 'Customer Growth per Month')

# %% [markdown]
# ## 13th Task- •	What are the other KPIs you can think of. (Ex- Average revenue per customer for each month in the year 2019)

# %% [markdown]
# ###  Average revenue per customer for each month in the year 2019

# %%
df13= df.groupby(["CustomerID", "month"])["total_sale"].sum().reset_index()
df13
# Out:
#        CustomerID month  total_sale
# 0         12346.0    01  4433604.10
# 1         12347.0    01    26287.86
# 2         12347.0    04    34217.06
# 3         12347.0    06    22388.94
# 4         12347.0    08    19695.78
# ...           ...   ...         ...
# 12806     18283.0    10     3013.68
# 12807     18283.0    11    35969.04
# 12808     18283.0    12    11255.21
# 12809     18287.0    05    21035.70
# 12810     18287.0    10    98874.74
#
# [12811 rows x 3 columns]

# %%
df13["month"]= pd.to_numeric(df13["month"])

# %%
df13.groupby(["month", "CustomerID"]).sum().reset_index()
# Out:
#        month  CustomerID  total_sale
# 0          1     12346.0  4433604.10
# 1          1     12347.0    26287.86
# 2          1     12348.0    79820.88
# 3          1     12356.0   160647.62
# 4          1     12359.0     9418.89
# ...      ...         ...         ...
# 12806     12     18269.0     2881.72
# 12807     12     18272.0    19916.70
# 12808     12     18273.0      299.80
# 12809     12     18282.0     1751.22
# 12810     12     18283.0    11255.21
#
# [12811 rows x 3 columns]

# %%
df13.groupby("month").mean().reset_index()
# Out:
#     month    CustomerID    total_sale
# 0       1  15134.094467  44979.817503
# 1       2  15270.518470  35535.858285
# 2       3  15236.784394  37306.433747
# 3       4  15348.468384  35749.650574
# 4       5  15279.355114  35958.751970
# 5       6  15296.750757  39559.155076
# 6       7  15258.988397  44345.794631
# 7       8  15235.082441  48507.599143
# 8       9  15219.022169  47115.304046
# 9      10  15256.041086  46980.362861
# 10     11  15304.230769  45264.157927
# 11     12  15400.326482  50186.430166

# %%
sb.barplot(x = "month", y="total_sale", data = df13 )
# Out:
# <AxesSubplot:xlabel='month', ylabel='total_sale'>
