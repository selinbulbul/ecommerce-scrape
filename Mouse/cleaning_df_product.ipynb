# %%
import pandas as pd

# %%
df = pd.read_json("product_output.jsonl")

# %%
df
# Out:
#                                                    name  \
# 0                                                  None
# 1                                                  None
# 2                      Logitech Mouse Wireless Red M185
# 3                                                  None
# 4     seenda Maus mit Kabel, PC Laptop Computer Maus...
# ...                                                 ...
# 2125                                               None
# 2126                  Microsoft Arc Touch Mouse - Black
# 2127                                               None
# 2128                                               None
# 2129                                               None
#
#                                         product_summary  \
# 0                                                  None
# 1                                                  None
# 2     [{'info': 'Brand', 'value': '‎Logitech'}, {'in...
# 3                                                  None
# ...

# %%
df = df.dropna(subset=['name'])

# %%
#df = df.reset_index()
#df

# %%
df
# Out:
#                                                    name  \
# 2                      Logitech Mouse Wireless Red M185
# 4     seenda Maus mit Kabel, PC Laptop Computer Maus...
# 10       Logitech MAIN-40191 M705 Wireless Mouse Silver
# 15    ECHTPower Rechargeable Ergonomic Mouse, 2.4G W...
# 20    Holife Gaming Mouse, [New Version] PrimAcc Com...
# ...                                                 ...
# 2090  Razer Pro Click Wireless Mouse Ergonomic CO Hu...
# 2099      LogiLink ID0096 Mouse Mat 3 x 220 x 250mm red
# 2105  Microsoft Wireless Comfort Desktop 5050 QWERTZ...
# 2124  Apple Magic Keyboard with Numeric Keypad (Wire...
# 2126                  Microsoft Arc Touch Mouse - Black
#
#                                         product_summary  \
# 2     [{'info': 'Brand', 'value': '‎Logitech'}, {'in...
# 4     [{'info': 'Brand', 'value': '‎SIMPFUN'}, {'inf...
# 10    [{'info': 'Brand', 'value': '‎Logitech'}, {'in...
# 15                                                 None
# ...

# %%
#df["price"]= pd.to_numeric(df["price"])

# %%
df.to_csv('Mouse_product.csv')

# %%
df.to_excel('Mouse_product.xlsx')

# %%
df.to_json('Mouse_product.jsonl')
