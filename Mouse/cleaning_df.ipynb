# %%
import pandas as pd

# %%
df = pd.read_json("search_output.jsonl")

# %% [markdown]
# # PRICE

# %%
df.head()
# Out:
#                                                title  \
# 0  INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1  QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2  Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3  Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4  seenda Maus mit Kabel, PC Laptop Computer Maus...
#
#                                                  url             rating  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4,3 von 5 Sternen
# 1  https://www.amazon.com/gp/slredirect/picassoRe...  4,2 von 5 Sternen
# 2  https://www.amazon.com/Logitech-M185-Maus-schn...  4,7 von 5 Sternen
# 3  https://www.amazon.com/Logitech-M185-Maus-schn...  4,7 von 5 Sternen
# 4  https://www.amazon.com/seenda-Laptop-Computer-...  4,6 von 5 Sternen
#
#   review_count    price
# 0        7.398  11,04 €
# 1          837   8,99 €
# 2       28.219   9,19 €
# 3       28.219   9,99 €
# 4          191   7,35 €

# %%
df = df.dropna()
df.head()
# Out:
#                                                title  \
# 0  INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1  QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2  Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3  Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4  seenda Maus mit Kabel, PC Laptop Computer Maus...
#
#                                                  url             rating  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4,3 von 5 Sternen
# 1  https://www.amazon.com/gp/slredirect/picassoRe...  4,2 von 5 Sternen
# 2  https://www.amazon.com/Logitech-M185-Maus-schn...  4,7 von 5 Sternen
# 3  https://www.amazon.com/Logitech-M185-Maus-schn...  4,7 von 5 Sternen
# 4  https://www.amazon.com/seenda-Laptop-Computer-...  4,6 von 5 Sternen
#
#   review_count    price
# 0        7.398  11,04 €
# 1          837   8,99 €
# 2       28.219   9,19 €
# 3       28.219   9,99 €
# 4          191   7,35 €

# %%
df["price"] = df["price"].replace({'\€':''}, regex = True)
df.head(20)
# Out:
#                                                 title  \
# 0   INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1   QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2   Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3   Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4   seenda Maus mit Kabel, PC Laptop Computer Maus...
# 5   Logitech B100 Maus mit Kabel, USB-Anschluss, 8...
# 6   Karrong Kabellos Maus Wiederaufladbar USB Funk...
# 7   Logitech M350 Pebble Kabellose Maus, Bluetooth...
# 9   TECKNET Wired Maus Optical Business Mouse Verd...
# 10  Logitech M705 Marathon Kabellose Maus, 2.4 GHz...
# 11  Funkmaus für Laptop, seenda Bluetooth Maus, LE...
# 12  Rii Maus mit Kabel, PC Maus kabelgebunden USB,...
# 13  QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 14  Logitech M500 PC-Maus mit Kabel, USB-Anschluss...
# 15  ECHTPower Vertikale Maus, Wiederaufladbare Erg...
# 16  INPHIC Maus Kabellos Wiederaufladbar, Leise 2....
# 17  TOPELEK Laptop Maus, PC Maus Schnurlos Maus Wi...
# 18  Holife Gaming Maus, 7200 DPI PC Maus mit RGB B...
# 19  PASONOMI Aktualisierung PC Maus Kabellose, LED...
# 20  HoLife PC Gaming Maus, [Neue Version] Gamer Ma...
#
#                                                   url             rating  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4,3 von 5 Sternen
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  4,2 von 5 Sternen
# 2   https://www.amazon.com/Logitech-M185-Maus-schn...  4,7 von 5 Sternen
# 3   https://www.amazon.com/Logitech-M185-Maus-schn...  4,7 von 5 Sternen
# 4   https://www.amazon.com/seenda-Laptop-Computer-...  4,6 von 5 Sternen
# 5   https://www.amazon.com/Logitech-B100-910-00335...  4,6 von 5 Sternen
# 6   https://www.amazon.com/gp/slredirect/picassoRe...  4,4 von 5 Sternen
# 7   https://www.amazon.com/Logitech-Kabellose-Verb...  4,6 von 5 Sternen
# 9   https://www.amazon.com/TeckNet-Verdrahtete-Erg...  4,5 von 5 Sternen
# 10  https://www.amazon.com/Logitech-Marathon-M705-...  4,6 von 5 Sternen
# 11  https://www.amazon.com/gp/slredirect/picassoRe...  4,7 von 5 Sternen
# 12  https://www.amazon.com/Rii-kabelgebunden-Optic...  4,5 von 5 Sternen
# 13  https://www.amazon.com/QZVOO-Funkm%C3%A4use-Co...  4,2 von 5 Sternen
# 14  https://www.amazon.com/Logitech-2229164-LGT-M5...  4,6 von 5 Sternen
# 15  https://www.amazon.com/ECHTPower-Vertikale-Wie...  4,5 von 5 Sternen
# 16  https://www.amazon.com/gp/slredirect/picassoRe...  4,4 von 5 Sternen
# 17  https://www.amazon.com/TOPELEK-Schnurlos-Nano-...  4,5 von 5 Sternen
# 18  https://www.amazon.com/Holife-Beleuchtung-Prog...  4,5 von 5 Sternen
# 19  https://www.amazon.com/PASONOMI-Aktualisierung...  4,3 von 5 Sternen
# 20  https://www.amazon.com/Version-Pr%C3%A4zision-...  4,4 von 5 Sternen
#
#    review_count   price
# 0         7.398  11,04
# 1           837   8,99
# 2        28.219   9,19
# 3        28.219   9,99
# 4           191   7,35
# 5         6.653   4,99
# 6         1.229   9,99
# 7         8.924  19,99
# 9         1.484  12,99
# 10       13.872  28,72
# 11        1.594  16,88
# 12          380   5,99
# 13          837   8,99
# 14        5.401  35,99
# 15        1.499  18,99
# 16       43.074   9,34
# 17        2.497   9,99
# 18        1.526  14,44
# 19        3.158  12,74
# 20        2.195  13,99

# %%
df["price"] = df["price"].replace({',':'.'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1   QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2   Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3   Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4   seenda Maus mit Kabel, PC Laptop Computer Maus...
# 5   Logitech B100 Maus mit Kabel, USB-Anschluss, 8...
# 6   Karrong Kabellos Maus Wiederaufladbar USB Funk...
# 7   Logitech M350 Pebble Kabellose Maus, Bluetooth...
# 9   TECKNET Wired Maus Optical Business Mouse Verd...
# 10  Logitech M705 Marathon Kabellose Maus, 2.4 GHz...
# 11  Funkmaus für Laptop, seenda Bluetooth Maus, LE...
# 12  Rii Maus mit Kabel, PC Maus kabelgebunden USB,...
# 13  QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 14  Logitech M500 PC-Maus mit Kabel, USB-Anschluss...
# 15  ECHTPower Vertikale Maus, Wiederaufladbare Erg...
#
#                                                   url             rating  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4,3 von 5 Sternen
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  4,2 von 5 Sternen
# 2   https://www.amazon.com/Logitech-M185-Maus-schn...  4,7 von 5 Sternen
# 3   https://www.amazon.com/Logitech-M185-Maus-schn...  4,7 von 5 Sternen
# 4   https://www.amazon.com/seenda-Laptop-Computer-...  4,6 von 5 Sternen
# 5   https://www.amazon.com/Logitech-B100-910-00335...  4,6 von 5 Sternen
# 6   https://www.amazon.com/gp/slredirect/picassoRe...  4,4 von 5 Sternen
# 7   https://www.amazon.com/Logitech-Kabellose-Verb...  4,6 von 5 Sternen
# 9   https://www.amazon.com/TeckNet-Verdrahtete-Erg...  4,5 von 5 Sternen
# 10  https://www.amazon.com/Logitech-Marathon-M705-...  4,6 von 5 Sternen
# 11  https://www.amazon.com/gp/slredirect/picassoRe...  4,7 von 5 Sternen
# 12  https://www.amazon.com/Rii-kabelgebunden-Optic...  4,5 von 5 Sternen
# 13  https://www.amazon.com/QZVOO-Funkm%C3%A4use-Co...  4,2 von 5 Sternen
# 14  https://www.amazon.com/Logitech-2229164-LGT-M5...  4,6 von 5 Sternen
# 15  https://www.amazon.com/ECHTPower-Vertikale-Wie...  4,5 von 5 Sternen
#
#    review_count   price
# 0         7.398  11.04
# 1           837   8.99
# 2        28.219   9.19
# 3        28.219   9.99
# 4           191   7.35
# 5         6.653   4.99
# 6         1.229   9.99
# 7         8.924  19.99
# 9         1.484  12.99
# 10       13.872  28.72
# 11        1.594  16.88
# 12          380   5.99
# 13          837   8.99
# 14        5.401  35.99
# 15        1.499  18.99

# %%
df["rating"] = df["rating"].replace({'von 5 Sternen':'/ 5'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1   QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2   Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3   Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4   seenda Maus mit Kabel, PC Laptop Computer Maus...
# 5   Logitech B100 Maus mit Kabel, USB-Anschluss, 8...
# 6   Karrong Kabellos Maus Wiederaufladbar USB Funk...
# 7   Logitech M350 Pebble Kabellose Maus, Bluetooth...
# 9   TECKNET Wired Maus Optical Business Mouse Verd...
# 10  Logitech M705 Marathon Kabellose Maus, 2.4 GHz...
# 11  Funkmaus für Laptop, seenda Bluetooth Maus, LE...
# 12  Rii Maus mit Kabel, PC Maus kabelgebunden USB,...
# 13  QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 14  Logitech M500 PC-Maus mit Kabel, USB-Anschluss...
# 15  ECHTPower Vertikale Maus, Wiederaufladbare Erg...
#
#                                                   url   rating review_count  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4,3 / 5        7.398
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  4,2 / 5          837
# 2   https://www.amazon.com/Logitech-M185-Maus-schn...  4,7 / 5       28.219
# 3   https://www.amazon.com/Logitech-M185-Maus-schn...  4,7 / 5       28.219
# 4   https://www.amazon.com/seenda-Laptop-Computer-...  4,6 / 5          191
# 5   https://www.amazon.com/Logitech-B100-910-00335...  4,6 / 5        6.653
# 6   https://www.amazon.com/gp/slredirect/picassoRe...  4,4 / 5        1.229
# 7   https://www.amazon.com/Logitech-Kabellose-Verb...  4,6 / 5        8.924
# 9   https://www.amazon.com/TeckNet-Verdrahtete-Erg...  4,5 / 5        1.484
# 10  https://www.amazon.com/Logitech-Marathon-M705-...  4,6 / 5       13.872
# 11  https://www.amazon.com/gp/slredirect/picassoRe...  4,7 / 5        1.594
# 12  https://www.amazon.com/Rii-kabelgebunden-Optic...  4,5 / 5          380
# 13  https://www.amazon.com/QZVOO-Funkm%C3%A4use-Co...  4,2 / 5          837
# 14  https://www.amazon.com/Logitech-2229164-LGT-M5...  4,6 / 5        5.401
# 15  https://www.amazon.com/ECHTPower-Vertikale-Wie...  4,5 / 5        1.499
#
#      price
# 0   11.04
# 1    8.99
# 2    9.19
# 3    9.99
# 4    7.35
# 5    4.99
# 6    9.99
# 7   19.99
# 9   12.99
# 10  28.72
# 11  16.88
# 12   5.99
# 13   8.99
# 14  35.99
# 15  18.99

# %%
df["rating"] = df["rating"].replace({'out of 5 stars':'/ 5'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1   QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2   Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3   Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4   seenda Maus mit Kabel, PC Laptop Computer Maus...
# 5   Logitech B100 Maus mit Kabel, USB-Anschluss, 8...
# 6   Karrong Kabellos Maus Wiederaufladbar USB Funk...
# 7   Logitech M350 Pebble Kabellose Maus, Bluetooth...
# 9   TECKNET Wired Maus Optical Business Mouse Verd...
# 10  Logitech M705 Marathon Kabellose Maus, 2.4 GHz...
# 11  Funkmaus für Laptop, seenda Bluetooth Maus, LE...
# 12  Rii Maus mit Kabel, PC Maus kabelgebunden USB,...
# 13  QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 14  Logitech M500 PC-Maus mit Kabel, USB-Anschluss...
# 15  ECHTPower Vertikale Maus, Wiederaufladbare Erg...
#
#                                                   url   rating review_count  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4,3 / 5        7.398
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  4,2 / 5          837
# 2   https://www.amazon.com/Logitech-M185-Maus-schn...  4,7 / 5       28.219
# 3   https://www.amazon.com/Logitech-M185-Maus-schn...  4,7 / 5       28.219
# 4   https://www.amazon.com/seenda-Laptop-Computer-...  4,6 / 5          191
# 5   https://www.amazon.com/Logitech-B100-910-00335...  4,6 / 5        6.653
# 6   https://www.amazon.com/gp/slredirect/picassoRe...  4,4 / 5        1.229
# 7   https://www.amazon.com/Logitech-Kabellose-Verb...  4,6 / 5        8.924
# 9   https://www.amazon.com/TeckNet-Verdrahtete-Erg...  4,5 / 5        1.484
# 10  https://www.amazon.com/Logitech-Marathon-M705-...  4,6 / 5       13.872
# 11  https://www.amazon.com/gp/slredirect/picassoRe...  4,7 / 5        1.594
# 12  https://www.amazon.com/Rii-kabelgebunden-Optic...  4,5 / 5          380
# 13  https://www.amazon.com/QZVOO-Funkm%C3%A4use-Co...  4,2 / 5          837
# 14  https://www.amazon.com/Logitech-2229164-LGT-M5...  4,6 / 5        5.401
# 15  https://www.amazon.com/ECHTPower-Vertikale-Wie...  4,5 / 5        1.499
#
#      price
# 0   11.04
# 1    8.99
# 2    9.19
# 3    9.99
# 4    7.35
# 5    4.99
# 6    9.99
# 7   19.99
# 9   12.99
# 10  28.72
# 11  16.88
# 12   5.99
# 13   8.99
# 14  35.99
# 15  18.99

# %%
df["rating"] = df["rating"].replace({',':'.'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1   QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2   Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3   Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4   seenda Maus mit Kabel, PC Laptop Computer Maus...
# 5   Logitech B100 Maus mit Kabel, USB-Anschluss, 8...
# 6   Karrong Kabellos Maus Wiederaufladbar USB Funk...
# 7   Logitech M350 Pebble Kabellose Maus, Bluetooth...
# 9   TECKNET Wired Maus Optical Business Mouse Verd...
# 10  Logitech M705 Marathon Kabellose Maus, 2.4 GHz...
# 11  Funkmaus für Laptop, seenda Bluetooth Maus, LE...
# 12  Rii Maus mit Kabel, PC Maus kabelgebunden USB,...
# 13  QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 14  Logitech M500 PC-Maus mit Kabel, USB-Anschluss...
# 15  ECHTPower Vertikale Maus, Wiederaufladbare Erg...
#
#                                                   url   rating review_count  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5        7.398
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5          837
# 2   https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5       28.219
# 3   https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5       28.219
# 4   https://www.amazon.com/seenda-Laptop-Computer-...  4.6 / 5          191
# 5   https://www.amazon.com/Logitech-B100-910-00335...  4.6 / 5        6.653
# 6   https://www.amazon.com/gp/slredirect/picassoRe...  4.4 / 5        1.229
# 7   https://www.amazon.com/Logitech-Kabellose-Verb...  4.6 / 5        8.924
# 9   https://www.amazon.com/TeckNet-Verdrahtete-Erg...  4.5 / 5        1.484
# 10  https://www.amazon.com/Logitech-Marathon-M705-...  4.6 / 5       13.872
# 11  https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5        1.594
# 12  https://www.amazon.com/Rii-kabelgebunden-Optic...  4.5 / 5          380
# 13  https://www.amazon.com/QZVOO-Funkm%C3%A4use-Co...  4.2 / 5          837
# 14  https://www.amazon.com/Logitech-2229164-LGT-M5...  4.6 / 5        5.401
# 15  https://www.amazon.com/ECHTPower-Vertikale-Wie...  4.5 / 5        1.499
#
#      price
# 0   11.04
# 1    8.99
# 2    9.19
# 3    9.99
# 4    7.35
# 5    4.99
# 6    9.99
# 7   19.99
# 9   12.99
# 10  28.72
# 11  16.88
# 12   5.99
# 13   8.99
# 14  35.99
# 15  18.99

# %%
### additional split function  df.price[0].split('$')[1] , df.rating[0].split(' ')[0] , https://pandas.pydata.org/docs/reference/api/pandas.Series.str.split.html

# %%
df_rc = df["review_count"].apply(lambda x: x.replace(',','.') )
display (df_rc)
df_rc_2 = pd.DataFrame(df_rc)
# Out:
# 0        7.398
# 1          837
# 2       28.219
# 3       28.219
# 4          191
#          ...
# 2124     2.731
# 2125     7.412
# 2126       282
# 2127        50
# 2129       381
# Name: review_count, Length: 1890, dtype: object

# %%
df_rc_2
# Out:
#      review_count
# 0           7.398
# 1             837
# 2          28.219
# 3          28.219
# 4             191
# ...           ...
# 2124        2.731
# 2125        7.412
# 2126          282
# 2127           50
# 2129          381
#
# [1890 rows x 1 columns]

# %%
df = df.drop(columns= "review_count")

# %%
df
# Out:
#                                                   title  \
# 0     INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1     QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2     Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3     Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4     seenda Maus mit Kabel, PC Laptop Computer Maus...
# ...                                                 ...
# 2124                               Apple Magic Keyboard
# 2125     Glorioso PC Racing Game GW-E Mouse Mat - White
# 2126                          Microsoft Arc Touch Mouse
# 2127  ITNRSIIET Ergonomic Mouse Mat Gel Wrist Rest G...
# 2129  Lenovo 530 Wireless Mouse Ambidextrous Nano US...
#
#                                                     url   rating   price
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  11.04
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5   8.99
# 2     https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.19
# 3     https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.99
# 4     https://www.amazon.com/seenda-Laptop-Computer-...  4.6 / 5   7.35
# ...                                                 ...      ...     ...
# 2124  https://www.amazon.com/-/en/MRMH2D-A-Apple-Mag...  4.8 / 5  131.77
# 2125  https://www.amazon.com/-/en/Glorioso-Racing-Ga...  4.4 / 5   34.90
# 2126  https://www.amazon.com/-/en/RVF-00050-Microsof...  4.1 / 5   52.90
# 2127  https://www.amazon.com/-/en/ITNRSIIET-Ergonomi...  4.7 / 5    7.99
# 2129  https://www.amazon.com/-/en/Wireless-Ambidextr...  4.4 / 5   28.52
#
# [1890 rows x 4 columns]

# %%
f_column = df_rc_2 ["review_count"]
df = pd.concat([df,f_column], axis = 1)
df
# Out:
#                                                   title  \
# 0     INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1     QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2     Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3     Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4     seenda Maus mit Kabel, PC Laptop Computer Maus...
# ...                                                 ...
# 2124                               Apple Magic Keyboard
# 2125     Glorioso PC Racing Game GW-E Mouse Mat - White
# 2126                          Microsoft Arc Touch Mouse
# 2127  ITNRSIIET Ergonomic Mouse Mat Gel Wrist Rest G...
# 2129  Lenovo 530 Wireless Mouse Ambidextrous Nano US...
#
#                                                     url   rating   price  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  11.04
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5   8.99
# 2     https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.19
# 3     https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.99
# 4     https://www.amazon.com/seenda-Laptop-Computer-...  4.6 / 5   7.35
# ...                                                 ...      ...     ...
# 2124  https://www.amazon.com/-/en/MRMH2D-A-Apple-Mag...  4.8 / 5  131.77
# 2125  https://www.amazon.com/-/en/Glorioso-Racing-Ga...  4.4 / 5   34.90
# 2126  https://www.amazon.com/-/en/RVF-00050-Microsof...  4.1 / 5   52.90
# 2127  https://www.amazon.com/-/en/ITNRSIIET-Ergonomi...  4.7 / 5    7.99
# 2129  https://www.amazon.com/-/en/Wireless-Ambidextr...  4.4 / 5   28.52
#
#      review_count
# 0           7.398
# 1             837
# 2          28.219
# 3          28.219
# 4             191
# ...           ...
# 2124        2.731
# 2125        7.412
# 2126          282
# 2127           50
# 2129          381
#
# [1890 rows x 5 columns]

# %%
df = df.rename(columns = {"price":"price €"})
df
# Out:
#                                                   title  \
# 0     INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1     QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2     Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3     Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4     seenda Maus mit Kabel, PC Laptop Computer Maus...
# ...                                                 ...
# 2124                               Apple Magic Keyboard
# 2125     Glorioso PC Racing Game GW-E Mouse Mat - White
# 2126                          Microsoft Arc Touch Mouse
# 2127  ITNRSIIET Ergonomic Mouse Mat Gel Wrist Rest G...
# 2129  Lenovo 530 Wireless Mouse Ambidextrous Nano US...
#
#                                                     url   rating price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  11.04
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5   8.99
# 2     https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.19
# 3     https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.99
# 4     https://www.amazon.com/seenda-Laptop-Computer-...  4.6 / 5   7.35
# ...                                                 ...      ...     ...
# 2124  https://www.amazon.com/-/en/MRMH2D-A-Apple-Mag...  4.8 / 5  131.77
# 2125  https://www.amazon.com/-/en/Glorioso-Racing-Ga...  4.4 / 5   34.90
# 2126  https://www.amazon.com/-/en/RVF-00050-Microsof...  4.1 / 5   52.90
# 2127  https://www.amazon.com/-/en/ITNRSIIET-Ergonomi...  4.7 / 5    7.99
# 2129  https://www.amazon.com/-/en/Wireless-Ambidextr...  4.4 / 5   28.52
#
#      review_count
# 0           7.398
# 1             837
# 2          28.219
# 3          28.219
# 4             191
# ...           ...
# 2124        2.731
# 2125        7.412
# 2126          282
# 2127           50
# 2129          381
#
# [1890 rows x 5 columns]

# %%
df = df.rename(columns = {"title":"product title"})
df
# Out:
#                                           product title  \
# 0     INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1     QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2     Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3     Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4     seenda Maus mit Kabel, PC Laptop Computer Maus...
# ...                                                 ...
# 2124                               Apple Magic Keyboard
# 2125     Glorioso PC Racing Game GW-E Mouse Mat - White
# 2126                          Microsoft Arc Touch Mouse
# 2127  ITNRSIIET Ergonomic Mouse Mat Gel Wrist Rest G...
# 2129  Lenovo 530 Wireless Mouse Ambidextrous Nano US...
#
#                                                     url   rating price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  11.04
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5   8.99
# 2     https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.19
# 3     https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.99
# 4     https://www.amazon.com/seenda-Laptop-Computer-...  4.6 / 5   7.35
# ...                                                 ...      ...     ...
# 2124  https://www.amazon.com/-/en/MRMH2D-A-Apple-Mag...  4.8 / 5  131.77
# 2125  https://www.amazon.com/-/en/Glorioso-Racing-Ga...  4.4 / 5   34.90
# 2126  https://www.amazon.com/-/en/RVF-00050-Microsof...  4.1 / 5   52.90
# 2127  https://www.amazon.com/-/en/ITNRSIIET-Ergonomi...  4.7 / 5    7.99
# 2129  https://www.amazon.com/-/en/Wireless-Ambidextr...  4.4 / 5   28.52
#
#      review_count
# 0           7.398
# 1             837
# 2          28.219
# 3          28.219
# 4             191
# ...           ...
# 2124        2.731
# 2125        7.412
# 2126          282
# 2127           50
# 2129          381
#
# [1890 rows x 5 columns]

# %%
df.loc[:, 'product'] = 'Mouse'

df.head(15)
# Out:
#                                         product title  \
# 0   INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1   QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2   Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3   Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4   seenda Maus mit Kabel, PC Laptop Computer Maus...
# 5   Logitech B100 Maus mit Kabel, USB-Anschluss, 8...
# 6   Karrong Kabellos Maus Wiederaufladbar USB Funk...
# 7   Logitech M350 Pebble Kabellose Maus, Bluetooth...
# 9   TECKNET Wired Maus Optical Business Mouse Verd...
# 10  Logitech M705 Marathon Kabellose Maus, 2.4 GHz...
# 11  Funkmaus für Laptop, seenda Bluetooth Maus, LE...
# 12  Rii Maus mit Kabel, PC Maus kabelgebunden USB,...
# 13  QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 14  Logitech M500 PC-Maus mit Kabel, USB-Anschluss...
# 15  ECHTPower Vertikale Maus, Wiederaufladbare Erg...
#
#                                                   url   rating price €  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  11.04
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5   8.99
# 2   https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.19
# 3   https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.99
# 4   https://www.amazon.com/seenda-Laptop-Computer-...  4.6 / 5   7.35
# 5   https://www.amazon.com/Logitech-B100-910-00335...  4.6 / 5   4.99
# 6   https://www.amazon.com/gp/slredirect/picassoRe...  4.4 / 5   9.99
# 7   https://www.amazon.com/Logitech-Kabellose-Verb...  4.6 / 5  19.99
# 9   https://www.amazon.com/TeckNet-Verdrahtete-Erg...  4.5 / 5  12.99
# 10  https://www.amazon.com/Logitech-Marathon-M705-...  4.6 / 5  28.72
# 11  https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  16.88
# 12  https://www.amazon.com/Rii-kabelgebunden-Optic...  4.5 / 5   5.99
# 13  https://www.amazon.com/QZVOO-Funkm%C3%A4use-Co...  4.2 / 5   8.99
# 14  https://www.amazon.com/Logitech-2229164-LGT-M5...  4.6 / 5  35.99
# 15  https://www.amazon.com/ECHTPower-Vertikale-Wie...  4.5 / 5  18.99
#
#    review_count product
# 0         7.398   Mouse
# 1           837   Mouse
# 2        28.219   Mouse
# 3        28.219   Mouse
# 4           191   Mouse
# 5         6.653   Mouse
# 6         1.229   Mouse
# 7         8.924   Mouse
# 9         1.484   Mouse
# 10       13.872   Mouse
# 11        1.594   Mouse
# 12          380   Mouse
# 13          837   Mouse
# 14        5.401   Mouse
# 15        1.499   Mouse

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1890 entries, 0 to 2129
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product title  1890 non-null   object
#  1   url            1890 non-null   object
#  2   rating         1890 non-null   object
#  3   price €        1890 non-null   object
#  4   review_count   1890 non-null   object
#  5   product        1890 non-null   object
# dtypes: object(6)
# memory usage: 103.4+ KB

# %%
#df["price"]= pd.to_numeric(df["price"])

# %%
df.to_csv('Mouse_sample_cleaned.csv')

# %%
df.to_excel('Mouse_sample_cleaned.xlsx')

# %%
df
# Out:
#                                           product title  \
# 0     INPHIC Bluetooth Maus, Silent wiederaufladbare...
# 1     QZVOO Kabellose Maus Kabellos Funkmaus Wireles...
# 2     Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 3     Logitech M185 Kabellose Maus, 2.4 GHz Verbindu...
# 4     seenda Maus mit Kabel, PC Laptop Computer Maus...
# ...                                                 ...
# 2124                               Apple Magic Keyboard
# 2125     Glorioso PC Racing Game GW-E Mouse Mat - White
# 2126                          Microsoft Arc Touch Mouse
# 2127  ITNRSIIET Ergonomic Mouse Mat Gel Wrist Rest G...
# 2129  Lenovo 530 Wireless Mouse Ambidextrous Nano US...
#
#                                                     url   rating price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.3 / 5  11.04
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  4.2 / 5   8.99
# 2     https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.19
# 3     https://www.amazon.com/Logitech-M185-Maus-schn...  4.7 / 5   9.99
# 4     https://www.amazon.com/seenda-Laptop-Computer-...  4.6 / 5   7.35
# ...                                                 ...      ...     ...
# 2124  https://www.amazon.com/-/en/MRMH2D-A-Apple-Mag...  4.8 / 5  131.77
# 2125  https://www.amazon.com/-/en/Glorioso-Racing-Ga...  4.4 / 5   34.90
# 2126  https://www.amazon.com/-/en/RVF-00050-Microsof...  4.1 / 5   52.90
# 2127  https://www.amazon.com/-/en/ITNRSIIET-Ergonomi...  4.7 / 5    7.99
# 2129  https://www.amazon.com/-/en/Wireless-Ambidextr...  4.4 / 5   28.52
#
#      review_count product
# 0           7.398   Mouse
# 1             837   Mouse
# 2          28.219   Mouse
# 3          28.219   Mouse
# 4             191   Mouse
# ...           ...     ...
# 2124        2.731   Mouse
# 2125        7.412   Mouse
# 2126          282   Mouse
# 2127           50   Mouse
# 2129          381   Mouse
#
# [1890 rows x 6 columns]
