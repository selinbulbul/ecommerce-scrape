# %%
import pandas as pd

# %%
df = pd.read_json("product_output.jsonl")

# %%
df
# Out:
#                                                    name product_summary  \
# 0     Wireless Lavalier Microphone 2.4G Dual-Channel...            None
# 1                                                  None            None
# 2                                                  None            None
# 3     Canon EOS 2000D (Rebel T7) DSLR Camera + 18-55...            None
# 4     Canon EOS 850D EF-S 18-55mm is STM Kit (Intern...            None
# ...                                                 ...             ...
# 2065  MOSHUSO Camera Mount Clamp with 360° Ballhead ...            None
# 2066                                               None            None
# 2067                                               None            None
# 2068                                               None            None
# 2069                                               None            None
#
#      product_tech_spec                                  product_addl_info  \
# ...

# %% [markdown]
# # PRICE

# %%
df_1 = df[(df["name"] == "None")]
df_1
# Out:
# Empty DataFrame
# Columns: [name, product_summary, product_tech_spec, product_addl_info, seller, seller_link, freq_bought, freq_bought_link, link_to_all_reviews]
# Index: []

# %%
df
# Out:
#                                                    name product_summary  \
# 0     Wireless Lavalier Microphone 2.4G Dual-Channel...            None
# 1                                                  None            None
# 2                                                  None            None
# 3     Canon EOS 2000D (Rebel T7) DSLR Camera + 18-55...            None
# 4     Canon EOS 850D EF-S 18-55mm is STM Kit (Intern...            None
# ...                                                 ...             ...
# 2065  MOSHUSO Camera Mount Clamp with 360° Ballhead ...            None
# 2066                                               None            None
# 2067                                               None            None
# 2068                                               None            None
# 2069                                               None            None
#
#      product_tech_spec                                  product_addl_info  \
# ...

# %%
df.dropna(subset=['name'])
# Out:
#                                                    name product_summary  \
# 0     Wireless Lavalier Microphone 2.4G Dual-Channel...            None
# 3     Canon EOS 2000D (Rebel T7) DSLR Camera + 18-55...            None
# 4     Canon EOS 850D EF-S 18-55mm is STM Kit (Intern...            None
# 6     Canon EOS 2000D DSLR Camera and EF-S 18-55 mm ...            None
# 9     Sony Boîtier ILC plein format 7 II uniquement ...            None
# ...                                                 ...             ...
# 2050     SAMTIAN 3960 Lux Bi-Color Photography Lighting            None
# 2054  Lowepro Toploader Zoom 55 AW II Camera Case fo...            None
# 2057  Neewer Extendable Camera Carbon Fiber Monopod ...            None
# 2064  Neewer 18 Pieces Metal Camera Lens Filter Ring...            None
# 2065  MOSHUSO Camera Mount Clamp with 360° Ballhead ...            None
#
#      product_tech_spec                                  product_addl_info  \
# ...

# %%
df = df.reset_index()
df
# Out:
#       level_0  index                                               name  \
# 0           0      0  Wireless Lavalier Microphone 2.4G Dual-Channel...
# 1           1      1                                               None
# 2           2      2                                               None
# 3           3      3  Canon EOS 2000D (Rebel T7) DSLR Camera + 18-55...
# 4           4      4  Canon EOS 850D EF-S 18-55mm is STM Kit (Intern...
# ...       ...    ...                                                ...
# 2065     2065   2065  MOSHUSO Camera Mount Clamp with 360° Ballhead ...
# 2066     2066   2066                                               None
# 2067     2067   2067                                               None
# 2068     2068   2068                                               None
# 2069     2069   2069                                               None
#
#      product_summary product_tech_spec  \
# 0               None              None
# ...

# %%
df
# Out:
#                                                    name product_summary  \
# 0     Wireless Lavalier Microphone 2.4G Dual-Channel...            None
# 1                                                  None            None
# 2                                                  None            None
# 3     Canon EOS 2000D (Rebel T7) DSLR Camera + 18-55...            None
# 4     Canon EOS 850D EF-S 18-55mm is STM Kit (Intern...            None
# ...                                                 ...             ...
# 2065  MOSHUSO Camera Mount Clamp with 360° Ballhead ...            None
# 2066                                               None            None
# 2067                                               None            None
# 2068                                               None            None
# 2069                                               None            None
#
#      product_tech_spec                                  product_addl_info  \
# ...

# %%
df = df.dropna(subset=['name'])

# %%
df
# Out:
#                                                    name product_summary  \
# 0     Wireless Lavalier Microphone 2.4G Dual-Channel...            None
# 3     Canon EOS 2000D (Rebel T7) DSLR Camera + 18-55...            None
# 4     Canon EOS 850D EF-S 18-55mm is STM Kit (Intern...            None
# 6     Canon EOS 2000D DSLR Camera and EF-S 18-55 mm ...            None
# 9     Sony Boîtier ILC plein format 7 II uniquement ...            None
# ...                                                 ...             ...
# 2050     SAMTIAN 3960 Lux Bi-Color Photography Lighting            None
# 2054  Lowepro Toploader Zoom 55 AW II Camera Case fo...            None
# 2057  Neewer Extendable Camera Carbon Fiber Monopod ...            None
# 2064  Neewer 18 Pieces Metal Camera Lens Filter Ring...            None
# 2065  MOSHUSO Camera Mount Clamp with 360° Ballhead ...            None
#
#      product_tech_spec                                  product_addl_info  \
# ...

# %%
#df["price"]= pd.to_numeric(df["price"])

# %%
df.to_csv('DSLR_product.csv')

# %%
df.to_excel('DSLR_product.xlsx')

# %%
df.to_json('DSLR_product.jsonl')
