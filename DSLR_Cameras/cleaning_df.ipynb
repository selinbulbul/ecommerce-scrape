# %%
import pandas as pd

# %%
df = pd.read_json("search_output.jsonl")

# %% [markdown]
# # PRICE

# %%
df.head()
# Out:
#                                                title  \
# 0  Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1  Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2  Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3  Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4  Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
#
#                                                  url             rating  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4,7 von 5 Sternen
# 1  https://www.amazon.com/gp/slredirect/picassoRe...  4,5 von 5 Sternen
# 2  https://www.amazon.com/Canon-4000D-Camera-18-5...  4,7 von 5 Sternen
# 3  https://www.amazon.com/Canon-Camera-2000D-18-5...  4,7 von 5 Sternen
# 4  https://www.amazon.com/Canon-850D-DSLR-Digital...  4,7 von 5 Sternen
#
#   review_count     price
# 0           23  284,00 €
# 1          211  194,00 €
# 2        1.637  438,00 €
# 3        1.284  417,60 €
# 4           28  849,00 €

# %%
df = df.dropna()
df.head()
# Out:
#                                                title  \
# 0  Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1  Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2  Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3  Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4  Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
#
#                                                  url             rating  \
# 0  https://www.amazon.com/gp/slredirect/picassoRe...  4,7 von 5 Sternen
# 1  https://www.amazon.com/gp/slredirect/picassoRe...  4,5 von 5 Sternen
# 2  https://www.amazon.com/Canon-4000D-Camera-18-5...  4,7 von 5 Sternen
# 3  https://www.amazon.com/Canon-Camera-2000D-18-5...  4,7 von 5 Sternen
# 4  https://www.amazon.com/Canon-850D-DSLR-Digital...  4,7 von 5 Sternen
#
#   review_count     price
# 0           23  284,00 €
# 1          211  194,00 €
# 2        1.637  438,00 €
# 3        1.284  417,60 €
# 4           28  849,00 €

# %%
df["price"] = df["price"].replace({'\€':''}, regex = True)
df.head(20)
# Out:
#                                                 title  \
# 0   Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1   Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2   Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3   Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4   Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# 5   Nikon D5600 Digital SLR im DX Format mit AF-P ...
# 6   Canon EOS 2000D DSLR Camera and EF-S 18-55 mm ...
# 7   Canon EOS 250D Digitalkamera - mit Objektiv EF...
# 8   Canon EOS M50 spiegellos Systemkamera (24,1 MP...
# 10  Pivo Tripod - 160 cm/5'3" ausziehbares Alumini...
# 11  Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 12  Canon EOS M50 Systemkamera spiegellos - mit Ob...
# 13  Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# 14  Panasonic Lumix DC-FZ82 Bridgekamera (18 Megap...
# 15  Neewer 3er Pack fortgeschritten 2,4G 660 LED B...
# 16  FEELWORLD F5 Pro 5.5 Inch Field Monitor 4K 192...
# 17  Feelworld FW759 7 Zoll Kamera DSLR Field Monit...
# 18  Feelworld LUT6 6-Zoll-DSLR-Kamera-Feldmonitor ...
# 19  Canon EOS 2000D Spiegelreflexkamera Gehäuse (2...
# 20  Comica CVM-VM20 Kamera Shotgun Mikrofon, Super...
#
#                                                   url             rating  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4,7 von 5 Sternen
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  4,5 von 5 Sternen
# 2   https://www.amazon.com/Canon-4000D-Camera-18-5...  4,7 von 5 Sternen
# 3   https://www.amazon.com/Canon-Camera-2000D-18-5...  4,7 von 5 Sternen
# 4   https://www.amazon.com/Canon-850D-DSLR-Digital...  4,7 von 5 Sternen
# 5   https://www.amazon.com/Nikon-D5600-AF-P-18-55-...  4,8 von 5 Sternen
# 6   https://www.amazon.com/Canon-2000D-Camera-18-5...  4,7 von 5 Sternen
# 7   https://www.amazon.com/Canon-Digitalkamera-Meg...  4,8 von 5 Sternen
# 8   https://www.amazon.com/Canon-EOS-wei%C3%9F-EF-...  4,6 von 5 Sternen
# 10  https://www.amazon.com/gp/slredirect/picassoRe...  4,7 von 5 Sternen
# 11  https://www.amazon.com/Canon-2000D-Spiegelrefl...  4,7 von 5 Sternen
# 12  https://www.amazon.com/Canon-EOS-schwarz-EF-M-...  4,8 von 5 Sternen
# 13  https://www.amazon.com/Canon-850D-DSLR-Digital...  4,8 von 5 Sternen
# 14  https://www.amazon.com/Panasonic-DC-FZ82EG-K-B...  4,5 von 5 Sternen
# 15  https://www.amazon.com/gp/slredirect/picassoRe...  4,4 von 5 Sternen
# 16  https://www.amazon.com/FEELWORLD-Monitor-1920x...  3,7 von 5 Sternen
# 17  https://www.amazon.com/Feelworld-Kamera-Monito...  4,4 von 5 Sternen
# 18  https://www.amazon.com/6-Zoll-DSLR-Kamera-Feld...  3,6 von 5 Sternen
# 19  https://www.amazon.com/Canon-EOS-2000D-Rebel-T...  4,7 von 5 Sternen
# 20  https://www.amazon.com/gp/slredirect/picassoRe...  4,6 von 5 Sternen
#
#    review_count      price
# 0            23    284,00
# 1           211    194,00
# 2         1.637    438,00
# 3         1.284    417,60
# 4            28    849,00
# 5           604    613,01
# 6           564    499,00
# 7           299    619,00
# 8            92    585,52
# 10          241     79,00
# 11        1.284    429,00
# 12          266    609,00
# 13           10  1.149,00
# 14        1.748    290,65
# 15           57    337,99
# 16           12    159,00
# 17          187     99,99
# 18            5    289,99
# 19        1.284    372,57
# 20           45    149,00

# %%
df["price"] = df["price"].replace({'\xa0':''}, regex = True)

# %%
df.loc[(df.price.str.find('.') == 1), 'price']
# Out:
# 13      1.149.00
# 38          9.00
# 50          8.95
# 65          8.69
# 92          5.49
#           ...
# 2026        6.79
# 2027        9.95
# 2034        9.99
# 2059        8.99
# 2068        5.79
# Name: price, Length: 130, dtype: object

# %%
df.loc[(df.price.str.find(',') == 1), 'price']
# Out:
# Series([], Name: price, dtype: object)

# %%
df["price"] = df["price"].replace({',':'.'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1   Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2   Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3   Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4   Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# 5   Nikon D5600 Digital SLR im DX Format mit AF-P ...
# 6   Canon EOS 2000D DSLR Camera and EF-S 18-55 mm ...
# 7   Canon EOS 250D Digitalkamera - mit Objektiv EF...
# 8   Canon EOS M50 spiegellos Systemkamera (24,1 MP...
# 10  Pivo Tripod - 160 cm/5'3" ausziehbares Alumini...
# 11  Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 12  Canon EOS M50 Systemkamera spiegellos - mit Ob...
# 13  Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# 14  Panasonic Lumix DC-FZ82 Bridgekamera (18 Megap...
# 15  Neewer 3er Pack fortgeschritten 2,4G 660 LED B...
#
#                                                   url             rating  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4,7 von 5 Sternen
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  4,5 von 5 Sternen
# 2   https://www.amazon.com/Canon-4000D-Camera-18-5...  4,7 von 5 Sternen
# 3   https://www.amazon.com/Canon-Camera-2000D-18-5...  4,7 von 5 Sternen
# 4   https://www.amazon.com/Canon-850D-DSLR-Digital...  4,7 von 5 Sternen
# 5   https://www.amazon.com/Nikon-D5600-AF-P-18-55-...  4,8 von 5 Sternen
# 6   https://www.amazon.com/Canon-2000D-Camera-18-5...  4,7 von 5 Sternen
# 7   https://www.amazon.com/Canon-Digitalkamera-Meg...  4,8 von 5 Sternen
# 8   https://www.amazon.com/Canon-EOS-wei%C3%9F-EF-...  4,6 von 5 Sternen
# 10  https://www.amazon.com/gp/slredirect/picassoRe...  4,7 von 5 Sternen
# 11  https://www.amazon.com/Canon-2000D-Spiegelrefl...  4,7 von 5 Sternen
# 12  https://www.amazon.com/Canon-EOS-schwarz-EF-M-...  4,8 von 5 Sternen
# 13  https://www.amazon.com/Canon-850D-DSLR-Digital...  4,8 von 5 Sternen
# 14  https://www.amazon.com/Panasonic-DC-FZ82EG-K-B...  4,5 von 5 Sternen
# 15  https://www.amazon.com/gp/slredirect/picassoRe...  4,4 von 5 Sternen
#
#    review_count     price
# 0            23    284.00
# 1           211    194.00
# 2         1.637    438.00
# 3         1.284    417.60
# 4            28    849.00
# 5           604    613.01
# 6           564    499.00
# 7           299    619.00
# 8            92    585.52
# 10          241     79.00
# 11        1.284    429.00
# 12          266    609.00
# 13           10  1.149.00
# 14        1.748    290.65
# 15           57    337.99

# %%
df["rating"] = df["rating"].replace({'von 5 Sternen':'/ 5'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1   Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2   Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3   Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4   Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# 5   Nikon D5600 Digital SLR im DX Format mit AF-P ...
# 6   Canon EOS 2000D DSLR Camera and EF-S 18-55 mm ...
# 7   Canon EOS 250D Digitalkamera - mit Objektiv EF...
# 8   Canon EOS M50 spiegellos Systemkamera (24,1 MP...
# 10  Pivo Tripod - 160 cm/5'3" ausziehbares Alumini...
# 11  Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 12  Canon EOS M50 Systemkamera spiegellos - mit Ob...
# 13  Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# 14  Panasonic Lumix DC-FZ82 Bridgekamera (18 Megap...
# 15  Neewer 3er Pack fortgeschritten 2,4G 660 LED B...
#
#                                                   url   rating review_count  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4,7 / 5           23
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  4,5 / 5          211
# 2   https://www.amazon.com/Canon-4000D-Camera-18-5...  4,7 / 5        1.637
# 3   https://www.amazon.com/Canon-Camera-2000D-18-5...  4,7 / 5        1.284
# 4   https://www.amazon.com/Canon-850D-DSLR-Digital...  4,7 / 5           28
# 5   https://www.amazon.com/Nikon-D5600-AF-P-18-55-...  4,8 / 5          604
# 6   https://www.amazon.com/Canon-2000D-Camera-18-5...  4,7 / 5          564
# 7   https://www.amazon.com/Canon-Digitalkamera-Meg...  4,8 / 5          299
# 8   https://www.amazon.com/Canon-EOS-wei%C3%9F-EF-...  4,6 / 5           92
# 10  https://www.amazon.com/gp/slredirect/picassoRe...  4,7 / 5          241
# 11  https://www.amazon.com/Canon-2000D-Spiegelrefl...  4,7 / 5        1.284
# 12  https://www.amazon.com/Canon-EOS-schwarz-EF-M-...  4,8 / 5          266
# 13  https://www.amazon.com/Canon-850D-DSLR-Digital...  4,8 / 5           10
# 14  https://www.amazon.com/Panasonic-DC-FZ82EG-K-B...  4,5 / 5        1.748
# 15  https://www.amazon.com/gp/slredirect/picassoRe...  4,4 / 5           57
#
#         price
# 0     284.00
# 1     194.00
# 2     438.00
# 3     417.60
# 4     849.00
# 5     613.01
# 6     499.00
# 7     619.00
# 8     585.52
# 10     79.00
# 11    429.00
# 12    609.00
# 13  1.149.00
# 14    290.65
# 15    337.99

# %%
df["rating"] = df["rating"].replace({'out of 5 stars':'/ 5'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1   Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2   Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3   Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4   Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# 5   Nikon D5600 Digital SLR im DX Format mit AF-P ...
# 6   Canon EOS 2000D DSLR Camera and EF-S 18-55 mm ...
# 7   Canon EOS 250D Digitalkamera - mit Objektiv EF...
# 8   Canon EOS M50 spiegellos Systemkamera (24,1 MP...
# 10  Pivo Tripod - 160 cm/5'3" ausziehbares Alumini...
# 11  Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 12  Canon EOS M50 Systemkamera spiegellos - mit Ob...
# 13  Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# 14  Panasonic Lumix DC-FZ82 Bridgekamera (18 Megap...
# 15  Neewer 3er Pack fortgeschritten 2,4G 660 LED B...
#
#                                                   url   rating review_count  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4,7 / 5           23
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  4,5 / 5          211
# 2   https://www.amazon.com/Canon-4000D-Camera-18-5...  4,7 / 5        1.637
# 3   https://www.amazon.com/Canon-Camera-2000D-18-5...  4,7 / 5        1.284
# 4   https://www.amazon.com/Canon-850D-DSLR-Digital...  4,7 / 5           28
# 5   https://www.amazon.com/Nikon-D5600-AF-P-18-55-...  4,8 / 5          604
# 6   https://www.amazon.com/Canon-2000D-Camera-18-5...  4,7 / 5          564
# 7   https://www.amazon.com/Canon-Digitalkamera-Meg...  4,8 / 5          299
# 8   https://www.amazon.com/Canon-EOS-wei%C3%9F-EF-...  4,6 / 5           92
# 10  https://www.amazon.com/gp/slredirect/picassoRe...  4,7 / 5          241
# 11  https://www.amazon.com/Canon-2000D-Spiegelrefl...  4,7 / 5        1.284
# 12  https://www.amazon.com/Canon-EOS-schwarz-EF-M-...  4,8 / 5          266
# 13  https://www.amazon.com/Canon-850D-DSLR-Digital...  4,8 / 5           10
# 14  https://www.amazon.com/Panasonic-DC-FZ82EG-K-B...  4,5 / 5        1.748
# 15  https://www.amazon.com/gp/slredirect/picassoRe...  4,4 / 5           57
#
#         price
# 0     284.00
# 1     194.00
# 2     438.00
# 3     417.60
# 4     849.00
# 5     613.01
# 6     499.00
# 7     619.00
# 8     585.52
# 10     79.00
# 11    429.00
# 12    609.00
# 13  1.149.00
# 14    290.65
# 15    337.99

# %%
df["rating"] = df["rating"].replace({',':'.'}, regex = True)
df.head(15)
# Out:
#                                                 title  \
# 0   Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1   Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2   Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3   Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4   Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# 5   Nikon D5600 Digital SLR im DX Format mit AF-P ...
# 6   Canon EOS 2000D DSLR Camera and EF-S 18-55 mm ...
# 7   Canon EOS 250D Digitalkamera - mit Objektiv EF...
# 8   Canon EOS M50 spiegellos Systemkamera (24,1 MP...
# 10  Pivo Tripod - 160 cm/5'3" ausziehbares Alumini...
# 11  Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 12  Canon EOS M50 Systemkamera spiegellos - mit Ob...
# 13  Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# 14  Panasonic Lumix DC-FZ82 Bridgekamera (18 Megap...
# 15  Neewer 3er Pack fortgeschritten 2,4G 660 LED B...
#
#                                                   url   rating review_count  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5           23
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  4.5 / 5          211
# 2   https://www.amazon.com/Canon-4000D-Camera-18-5...  4.7 / 5        1.637
# 3   https://www.amazon.com/Canon-Camera-2000D-18-5...  4.7 / 5        1.284
# 4   https://www.amazon.com/Canon-850D-DSLR-Digital...  4.7 / 5           28
# 5   https://www.amazon.com/Nikon-D5600-AF-P-18-55-...  4.8 / 5          604
# 6   https://www.amazon.com/Canon-2000D-Camera-18-5...  4.7 / 5          564
# 7   https://www.amazon.com/Canon-Digitalkamera-Meg...  4.8 / 5          299
# 8   https://www.amazon.com/Canon-EOS-wei%C3%9F-EF-...  4.6 / 5           92
# 10  https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5          241
# 11  https://www.amazon.com/Canon-2000D-Spiegelrefl...  4.7 / 5        1.284
# 12  https://www.amazon.com/Canon-EOS-schwarz-EF-M-...  4.8 / 5          266
# 13  https://www.amazon.com/Canon-850D-DSLR-Digital...  4.8 / 5           10
# 14  https://www.amazon.com/Panasonic-DC-FZ82EG-K-B...  4.5 / 5        1.748
# 15  https://www.amazon.com/gp/slredirect/picassoRe...  4.4 / 5           57
#
#         price
# 0     284.00
# 1     194.00
# 2     438.00
# 3     417.60
# 4     849.00
# 5     613.01
# 6     499.00
# 7     619.00
# 8     585.52
# 10     79.00
# 11    429.00
# 12    609.00
# 13  1.149.00
# 14    290.65
# 15    337.99

# %%
### additional split function  df.price[0].split('$')[1] , df.rating[0].split(' ')[0] , https://pandas.pydata.org/docs/reference/api/pandas.Series.str.split.html

# %%
df_rc = df["review_count"].apply(lambda x: x.replace(',','.') )
display (df_rc)
df_rc_2 = pd.DataFrame(df_rc)
# Out:
# 0          23
# 1         211
# 2       1.637
# 3       1.284
# 4          28
#         ...
# 2064      458
# 2065      252
# 2066        2
# 2067      247
# 2068        7
# Name: review_count, Length: 1933, dtype: object

# %%
df_rc_2
# Out:
#      review_count
# 0              23
# 1             211
# 2           1.637
# 3           1.284
# 4              28
# ...           ...
# 2064          458
# 2065          252
# 2066            2
# 2067          247
# 2068            7
#
# [1933 rows x 1 columns]

# %%
df = df.drop(columns= "review_count")

# %%
df
# Out:
#                                                   title  \
# 0     Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1     Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2     Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3     Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4     Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# ...                                                 ...
# 2064  Neewer 18 Piece Metallic Camera Lens Filter Ri...
# 2065  MOSHUSO Camera Mount Clamp with 360° Ball Head...
# 2066  Andoer W49 A7 Mini Interlock Camera LED Panel ...
# 2067                             Cullmann Malaga Series
# 2068  sourcing map Pack of 5 Plastic Dgital DSLR Cam...
#
#                                                     url   rating    price
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  284.00
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  4.5 / 5  194.00
# 2     https://www.amazon.com/Canon-4000D-Camera-18-5...  4.7 / 5  438.00
# 3     https://www.amazon.com/Canon-Camera-2000D-18-5...  4.7 / 5  417.60
# 4     https://www.amazon.com/Canon-850D-DSLR-Digital...  4.7 / 5  849.00
# ...                                                 ...      ...      ...
# 2064  https://www.amazon.com/-/en/Neewer-Metallic-Ca...  4.7 / 5    22.99
# 2065  https://www.amazon.com/-/en/MOSHUSO-Camera-Mou...  4.7 / 5    11.99
# 2066  https://www.amazon.com/-/en/W49-A7-Mini-Interl...  5.0 / 5    13.99
# 2067  https://www.amazon.com/-/en/90363-Cullmann-Mal...  4.5 / 5    33.90
# 2068  https://www.amazon.com/-/en/sourcing-Plastic-D...  4.6 / 5     5.79
#
# [1933 rows x 4 columns]

# %%
f_column = df_rc_2 ["review_count"]
df = pd.concat([df,f_column], axis = 1)
df
# Out:
#                                                   title  \
# 0     Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1     Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2     Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3     Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4     Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# ...                                                 ...
# 2064  Neewer 18 Piece Metallic Camera Lens Filter Ri...
# 2065  MOSHUSO Camera Mount Clamp with 360° Ball Head...
# 2066  Andoer W49 A7 Mini Interlock Camera LED Panel ...
# 2067                             Cullmann Malaga Series
# 2068  sourcing map Pack of 5 Plastic Dgital DSLR Cam...
#
#                                                     url   rating    price  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  284.00
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  4.5 / 5  194.00
# 2     https://www.amazon.com/Canon-4000D-Camera-18-5...  4.7 / 5  438.00
# 3     https://www.amazon.com/Canon-Camera-2000D-18-5...  4.7 / 5  417.60
# 4     https://www.amazon.com/Canon-850D-DSLR-Digital...  4.7 / 5  849.00
# ...                                                 ...      ...      ...
# 2064  https://www.amazon.com/-/en/Neewer-Metallic-Ca...  4.7 / 5    22.99
# 2065  https://www.amazon.com/-/en/MOSHUSO-Camera-Mou...  4.7 / 5    11.99
# 2066  https://www.amazon.com/-/en/W49-A7-Mini-Interl...  5.0 / 5    13.99
# 2067  https://www.amazon.com/-/en/90363-Cullmann-Mal...  4.5 / 5    33.90
# 2068  https://www.amazon.com/-/en/sourcing-Plastic-D...  4.6 / 5     5.79
#
#      review_count
# 0              23
# 1             211
# 2           1.637
# 3           1.284
# 4              28
# ...           ...
# 2064          458
# 2065          252
# 2066            2
# 2067          247
# 2068            7
#
# [1933 rows x 5 columns]

# %%
df = df.rename(columns = {"price":"price €"})
df
# Out:
#                                                   title  \
# 0     Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1     Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2     Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3     Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4     Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# ...                                                 ...
# 2064  Neewer 18 Piece Metallic Camera Lens Filter Ri...
# 2065  MOSHUSO Camera Mount Clamp with 360° Ball Head...
# 2066  Andoer W49 A7 Mini Interlock Camera LED Panel ...
# 2067                             Cullmann Malaga Series
# 2068  sourcing map Pack of 5 Plastic Dgital DSLR Cam...
#
#                                                     url   rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  284.00
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  4.5 / 5  194.00
# 2     https://www.amazon.com/Canon-4000D-Camera-18-5...  4.7 / 5  438.00
# 3     https://www.amazon.com/Canon-Camera-2000D-18-5...  4.7 / 5  417.60
# 4     https://www.amazon.com/Canon-850D-DSLR-Digital...  4.7 / 5  849.00
# ...                                                 ...      ...      ...
# 2064  https://www.amazon.com/-/en/Neewer-Metallic-Ca...  4.7 / 5    22.99
# 2065  https://www.amazon.com/-/en/MOSHUSO-Camera-Mou...  4.7 / 5    11.99
# 2066  https://www.amazon.com/-/en/W49-A7-Mini-Interl...  5.0 / 5    13.99
# 2067  https://www.amazon.com/-/en/90363-Cullmann-Mal...  4.5 / 5    33.90
# 2068  https://www.amazon.com/-/en/sourcing-Plastic-D...  4.6 / 5     5.79
#
#      review_count
# 0              23
# 1             211
# 2           1.637
# 3           1.284
# 4              28
# ...           ...
# 2064          458
# 2065          252
# 2066            2
# 2067          247
# 2068            7
#
# [1933 rows x 5 columns]

# %%
df = df.rename(columns = {"title":"product title"})
df
# Out:
#                                           product title  \
# 0     Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1     Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2     Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3     Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4     Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# ...                                                 ...
# 2064  Neewer 18 Piece Metallic Camera Lens Filter Ri...
# 2065  MOSHUSO Camera Mount Clamp with 360° Ball Head...
# 2066  Andoer W49 A7 Mini Interlock Camera LED Panel ...
# 2067                             Cullmann Malaga Series
# 2068  sourcing map Pack of 5 Plastic Dgital DSLR Cam...
#
#                                                     url   rating  price €  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5  284.00
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  4.5 / 5  194.00
# 2     https://www.amazon.com/Canon-4000D-Camera-18-5...  4.7 / 5  438.00
# 3     https://www.amazon.com/Canon-Camera-2000D-18-5...  4.7 / 5  417.60
# 4     https://www.amazon.com/Canon-850D-DSLR-Digital...  4.7 / 5  849.00
# ...                                                 ...      ...      ...
# 2064  https://www.amazon.com/-/en/Neewer-Metallic-Ca...  4.7 / 5    22.99
# 2065  https://www.amazon.com/-/en/MOSHUSO-Camera-Mou...  4.7 / 5    11.99
# 2066  https://www.amazon.com/-/en/W49-A7-Mini-Interl...  5.0 / 5    13.99
# 2067  https://www.amazon.com/-/en/90363-Cullmann-Mal...  4.5 / 5    33.90
# 2068  https://www.amazon.com/-/en/sourcing-Plastic-D...  4.6 / 5     5.79
#
#      review_count
# 0              23
# 1             211
# 2           1.637
# 3           1.284
# 4              28
# ...           ...
# 2064          458
# 2065          252
# 2066            2
# 2067          247
# 2068            7
#
# [1933 rows x 5 columns]

# %%
df.loc[:, 'product'] = 'DSLR_Camera'

df.head(15)
# Out:
#                                         product title  \
# 0   Hollyland Lark 150 Lavalier Funkmikrofon mit L...
# 1   Omegon Fotomontierung Mini Track LX3 N - Reise...
# 2   Canon EOS 4000D DSLR Camera and EF-S 18-55 mm ...
# 3   Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 4   Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# 5   Nikon D5600 Digital SLR im DX Format mit AF-P ...
# 6   Canon EOS 2000D DSLR Camera and EF-S 18-55 mm ...
# 7   Canon EOS 250D Digitalkamera - mit Objektiv EF...
# 8   Canon EOS M50 spiegellos Systemkamera (24,1 MP...
# 10  Pivo Tripod - 160 cm/5'3" ausziehbares Alumini...
# 11  Canon EOS 2000D Spiegelreflexkamera - mit Obje...
# 12  Canon EOS M50 Systemkamera spiegellos - mit Ob...
# 13  Canon EOS 850D DSLR Digitalkamera Gehäuse - mi...
# 14  Panasonic Lumix DC-FZ82 Bridgekamera (18 Megap...
# 15  Neewer 3er Pack fortgeschritten 2,4G 660 LED B...
#
#                                                   url   rating    price €  \
# 0   https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5    284.00
# 1   https://www.amazon.com/gp/slredirect/picassoRe...  4.5 / 5    194.00
# 2   https://www.amazon.com/Canon-4000D-Camera-18-5...  4.7 / 5    438.00
# 3   https://www.amazon.com/Canon-Camera-2000D-18-5...  4.7 / 5    417.60
# 4   https://www.amazon.com/Canon-850D-DSLR-Digital...  4.7 / 5    849.00
# 5   https://www.amazon.com/Nikon-D5600-AF-P-18-55-...  4.8 / 5    613.01
# 6   https://www.amazon.com/Canon-2000D-Camera-18-5...  4.7 / 5    499.00
# 7   https://www.amazon.com/Canon-Digitalkamera-Meg...  4.8 / 5    619.00
# 8   https://www.amazon.com/Canon-EOS-wei%C3%9F-EF-...  4.6 / 5    585.52
# 10  https://www.amazon.com/gp/slredirect/picassoRe...  4.7 / 5     79.00
# 11  https://www.amazon.com/Canon-2000D-Spiegelrefl...  4.7 / 5    429.00
# 12  https://www.amazon.com/Canon-EOS-schwarz-EF-M-...  4.8 / 5    609.00
# 13  https://www.amazon.com/Canon-850D-DSLR-Digital...  4.8 / 5  1.149.00
# 14  https://www.amazon.com/Panasonic-DC-FZ82EG-K-B...  4.5 / 5    290.65
# 15  https://www.amazon.com/gp/slredirect/picassoRe...  4.4 / 5    337.99
#
#    review_count      product
# 0            23  DSLR_Camera
# 1           211  DSLR_Camera
# 2         1.637  DSLR_Camera
# 3         1.284  DSLR_Camera
# 4            28  DSLR_Camera
# 5           604  DSLR_Camera
# 6           564  DSLR_Camera
# 7           299  DSLR_Camera
# 8            92  DSLR_Camera
# 10          241  DSLR_Camera
# 11        1.284  DSLR_Camera
# 12          266  DSLR_Camera
# 13           10  DSLR_Camera
# 14        1.748  DSLR_Camera
# 15           57  DSLR_Camera

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1933 entries, 0 to 2068
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product title  1933 non-null   object
#  1   url            1933 non-null   object
#  2   rating         1933 non-null   object
#  3   price €        1933 non-null   object
#  4   review_count   1933 non-null   object
#  5   product        1933 non-null   object
# dtypes: object(6)
# memory usage: 105.7+ KB

# %%
#df["price"]= pd.to_numeric(df["price"])

# %%
df.to_csv('DSLR_sample_cleaned.csv')

# %%
df.to_excel('DSLR_sample_cleaned.xlsx')

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
